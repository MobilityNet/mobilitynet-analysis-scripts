# %% [markdown]
# ## Template to get started with data exploration
#
# The other notebooks show the results of existing analysis. Most of the resulting code has been moved from the notebooks to the associated python modules, in order to showcase the results. But that makes it harder to experiment with the data and come up with new analyses. This is particularly true because the current data structures that store the data are a little complicated. Maybe after we switch to xarrays in the future, we will no longer need this!
#
# But for now, users can use this exploration template and plug in their code/analyses here. And finally, they can put the code into a module for re-use elsewhere

# %% [markdown]
# ## Set up the dependencies

# %%
# for reading and validating data
import emeval.input.spec_details as eisd
import emeval.input.phone_view as eipv
import emeval.input.eval_view as eiev

# %%
# Visualization helpers
import emeval.viz.phone_view as ezpv
import emeval.viz.eval_view as ezev

# %%
# For plots
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# For maps
import folium
import branca.element as bre

# %%
# For easier debugging while working on modules
import importlib

# %%
importlib.reload(eipv)
# Out:
# <module 'emeval.input.phone_view' from '/Users/shankari/e-mission/e-mission-eval-public-data/emeval/input/phone_view.py'>

# %% [markdown]
# ## The spec
#
# The spec defines what experiments were done, and over which time ranges. Once the experiment is complete, most of the structure is read back from the data, but we use the spec to validate that it all worked correctly. The spec also contains the ground truth for the legs. Here, we read the spec for the trip to UC Berkeley.

# %%
DATASTORE_URL = "http://cardshark.cs.berkeley.edu"
AUTHOR_EMAIL = "shankari@eecs.berkeley.edu"
sd = eisd.SpecDetails(DATASTORE_URL, AUTHOR_EMAIL, "unimodal_trip_car_bike_mtv_la")
# Out:
# About to retrieve messages using {'user': 'shankari@eecs.berkeley.edu', 'key_list': ['config/evaluation_spec'], 'start_time': 0, 'end_time': 1564459676}
# response = <Response [200]>
# Found 11 entries
# After iterating over 11 entries, entry found
# Found spec = Round trip car and bike trip in the South Bay
# Evaluation ran from 2019-07-19T17:00:00-07:00 -> 2019-07-30T17:00:00-07:00

# %% [markdown]
# ## The views
#
# There are two main views for the data - the phone view and the evaluation view.

# %% [markdown]
# ### Phone view
#
# In the phone view, the phone is primary, and then there is a tree that you can traverse to get the data that you want. Traversing that tree typically involves nested for loops; here's an example of loading the phone view and traversing it. You can replace the print statements with real code. When you are ready to check this in, please move the function to one of the python modules so that we can invoke it more generally

# %%
pv = eipv.PhoneView(sd)
# Out:
# -------------------- About to read transitions from server --------------------
# Reading data for android phones
# Loading transitions for phone ucb-sdb-android-1
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563580800, 'end_time': 1564531200}
# response = <Response [200]>
# Found 38 entries
# Loading transitions for phone ucb-sdb-android-2
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563580800, 'end_time': 1564531200}
# response = <Response [200]>
# Found 38 entries
# Loading transitions for phone ucb-sdb-android-3
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563580800, 'end_time': 1564531200}
# response = <Response [200]>
# Found 38 entries
# Loading transitions for phone ucb-sdb-android-4
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563580800, 'end_time': 1564531200}
# response = <Response [200]>
# Found 38 entries
# Reading data for ios phones
# Loading transitions for phone ucb-sdb-ios-1
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563580800, 'end_time': 1564531200}
# response = <Response [200]>
# Found 332 entries
# Loading transitions for phone ucb-sdb-ios-2
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563580800, 'end_time': 1564531200}
# response = <Response [200]>
# Found 38 entries
# Loading transitions for phone ucb-sdb-ios-3
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563580800, 'end_time': 1564531200}
# response = <Response [200]>
# Found 38 entries
# Loading transitions for phone ucb-sdb-ios-4
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563580800, 'end_time': 1564531200}
# response = <Response [200]>
# Found 38 entries
# -------------------- About to fill calibration ranges --------------------
# Processing data for android phones
# Processing transitions for phone ucb-sdb-android-1
# Filtered 38 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-2
# Filtered 38 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-3
# Filtered 38 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-4
# Filtered 38 total -> 0 calibration transitions
# Processing data for ios phones
# Processing transitions for phone ucb-sdb-ios-1
# Filtered 332 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-ios-2
# Filtered 38 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-ios-3
# Filtered 38 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-ios-4
# Filtered 38 total -> 0 calibration transitions
# Processing data for android phones
# ---------- ucb-sdb-android-1
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges of duration [] for phone ucb-sdb-android-1
# ---------- ucb-sdb-android-2
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges of duration [] for phone ucb-sdb-android-2
# ---------- ucb-sdb-android-3
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges of duration [] for phone ucb-sdb-android-3
# ---------- ucb-sdb-android-4
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges of duration [] for phone ucb-sdb-android-4
# Processing data for ios phones
# ---------- ucb-sdb-ios-1
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges of duration [] for phone ucb-sdb-ios-1
# ---------- ucb-sdb-ios-2
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges of duration [] for phone ucb-sdb-ios-2
# ---------- ucb-sdb-ios-3
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges of duration [] for phone ucb-sdb-ios-3
# ---------- ucb-sdb-ios-4
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges of duration [] for phone ucb-sdb-ios-4
# -------------------- About to fill evaluation ranges --------------------
# Processing data for android phones
# Processing transitions for phone ucb-sdb-android-1
# Filtered 38 total -> 6 calibration transitions
# Processing transitions for phone ucb-sdb-android-2
# Filtered 38 total -> 6 calibration transitions
# Processing transitions for phone ucb-sdb-android-3
# Filtered 38 total -> 6 calibration transitions
# Processing transitions for phone ucb-sdb-android-4
# Filtered 38 total -> 6 calibration transitions
# Processing data for ios phones
# Processing transitions for phone ucb-sdb-ios-1
# Filtered 332 total -> 6 calibration transitions
# Processing transitions for phone ucb-sdb-ios-2
# Filtered 38 total -> 6 calibration transitions
# Processing transitions for phone ucb-sdb-ios-3
# Filtered 38 total -> 6 calibration transitions
# Processing transitions for phone ucb-sdb-ios-4
# Filtered 38 total -> 6 calibration transitions
# Processing data for android phones
# ('START_EVALUATION_PERIOD', 'fixed:ACCURACY_CONTROL', 1564274314.703, 1564274314.707)
# ('STOP_EVALUATION_PERIOD', 'fixed:ACCURACY_CONTROL', 1564282393.38, 1564282393.429)
# ('START_EVALUATION_PERIOD', 'fixed:ACCURACY_CONTROL', 1564334117.292, 1564334117.295)
# ('STOP_EVALUATION_PERIOD', 'fixed:ACCURACY_CONTROL', 1564343045.844, 1564343045.9)
# ('START_EVALUATION_PERIOD', 'fixed:ACCURACY_CONTROL', 1564351305.631, 1564351305.633)
# ('STOP_EVALUATION_PERIOD', 'fixed:ACCURACY_CONTROL', 1564360156.337, 1564360156.392)
# All ranges are complete, nothing to change
# {'fixed:ACCURACY_CONTROL'}
# Found 3 ranges for phone ucb-sdb-android-1
# ('START_EVALUATION_PERIOD', 'HAHFDC v/s HAMFDC:HAHFDC', 1564274304.964, 1564274304.968)
# ('STOP_EVALUATION_PERIOD', 'HAHFDC v/s HAMFDC:HAHFDC', 1564282402.797, 1564282402.886)
# ('START_EVALUATION_PERIOD', 'HAHFDC v/s HAMFDC:HAHFDC', 1564334125.757, 1564334125.764)
# ('STOP_EVALUATION_PERIOD', 'HAHFDC v/s HAMFDC:HAHFDC', 1564343114.995, 1564343115.071)
# ('START_EVALUATION_PERIOD', 'HAHFDC v/s HAMFDC:HAHFDC', 1564351292.699, 1564351292.705)
# ('STOP_EVALUATION_PERIOD', 'HAHFDC v/s HAMFDC:HAHFDC', 1564360115.721, 1564360115.769)
# All ranges are complete, nothing to change
# {'HAHFDC v/s HAMFDC:HAHFDC'}
# Found 3 ranges for phone ucb-sdb-android-2
# ('START_EVALUATION_PERIOD', 'HAHFDC v/s HAMFDC:HAMFDC', 1564274288.317, 1564274288.319)
# ('STOP_EVALUATION_PERIOD', 'HAHFDC v/s HAMFDC:HAMFDC', 1564282423.016, 1564282423.072)
# ('START_EVALUATION_PERIOD', 'HAHFDC v/s HAMFDC:HAMFDC', 1564334097.326, 1564334097.33)
# ('STOP_EVALUATION_PERIOD', 'HAHFDC v/s HAMFDC:HAMFDC', 1564343025.354, 1564343025.406)
# ('START_EVALUATION_PERIOD', 'HAHFDC v/s HAMFDC:HAMFDC', 1564351277.476, 1564351277.477)
# ('STOP_EVALUATION_PERIOD', 'HAHFDC v/s HAMFDC:HAMFDC', 1564360134.114, 1564360134.181)
# All ranges are complete, nothing to change
# {'HAHFDC v/s HAMFDC:HAMFDC'}
# Found 3 ranges for phone ucb-sdb-android-3
# ('START_EVALUATION_PERIOD', 'fixed:POWER_CONTROL', 1564274294.641, 1564274294.643)
# ('STOP_EVALUATION_PERIOD', 'fixed:POWER_CONTROL', 1564282430.409, 1564282430.466)
# ('START_EVALUATION_PERIOD', 'fixed:POWER_CONTROL', 1564334109.335, 1564334109.339)
# ('START_EVALUATION_PERIOD', 'fixed:POWER_CONTROL', 1564274275.916, 1564274276.021558)
# ('STOP_EVALUATION_PERIOD', 'fixed:POWER_CONTROL', 1564282331.795, 1564282332.15351)
# ('START_EVALUATION_PERIOD', 'fixed:POWER_CONTROL', 1564334069.022, 1564334069.1049929)
# ('STOP_EVALUATION_PERIOD', 'fixed:POWER_CONTROL', 1564343007.324, 1564343007.721693)
# ('START_EVALUATION_PERIOD', 'fixed:POWER_CONTROL', 1564351193.165, 1564351193.2504249)
# ('STOP_EVALUATION_PERIOD', 'fixed:POWER_CONTROL', 1564360033.509, 1564360033.887364)
# All ranges are complete, nothing to change
# {'fixed:POWER_CONTROL'}
# Found 3 ranges for phone ucb-sdb-ios-4
# Processing data for android phones
# Processing data for ios phones
# -------------------- About to fill evaluation trips --------------------
# Processing data for android phones
# Processing data for ios phones
# Lengths (accuracy, power, eval) = (2, 2, 2)
# keys (accuracy, power, eval) = (dict_keys(['android', 'ios']), dict_keys(['android', 'ios']), dict_keys(['android', 'ios']))
# eval_phone_keys (android, ios) = (dict_keys(['ucb-sdb-android-2', 'ucb-sdb-android-3']), dict_keys(['ucb-sdb-ios-2', 'ucb-sdb-ios-3']))
#
# All ranges are complete, nothing to change
# set()
# android: Found 0 trips for evaluation fixed:ACCURACY_CONTROL_0
#
#
# All ranges are complete, nothing to change
# set()
# android: Found 0 trips for evaluation fixed:ACCURACY_CONTROL_1
#
#
# All ranges are complete, nothing to change
# set()
# android: Found 0 trips for evaluation fixed:ACCURACY_CONTROL_2
#
# ('START_EVALUATION_TRIP', 'suburb_city_driving_weekend', 1564274334.097, 1564274334.143985)
# ('STOP_EVALUATION_TRIP', 'suburb_city_driving_weekend', 1564275296.5, 1564275296.504297)
# ('START_EVALUATION_TRIP', 'suburb_bicycling', 1564279157.404, 1564279157.435039)
# ('STOP_EVALUATION_TRIP', 'suburb_bicycling', 1564280457.454, 1564280457.464819)
# All ranges are complete, nothing to change
# {'suburb_city_driving_weekend', 'suburb_bicycling'}
# ios: Found 2 trips for evaluation fixed:ACCURACY_CONTROL_0
# ('suburb_city_driving_weekend_0', 962.3603119850159, <Arrow [2019-07-27T17:38:54.143985-07:00]>, <Arrow [2019-07-27T17:54:56.504297-07:00]>)
# ('suburb_bicycling_0', 1300.0297799110413, <Arrow [2019-07-27T18:59:17.435039-07:00]>, <Arrow [2019-07-27T19:20:57.464819-07:00]>)
# ('START_EVALUATION_TRIP', 'suburb_city_driving_weekend', 1564334343.713, 1564334343.776588)
# ('STOP_EVALUATION_TRIP', 'suburb_city_driving_weekend', 1564335144.075, 1564335144.0807219)
# ('START_EVALUATION_TRIP', 'suburb_bicycling', 1564339686.632, 1564339686.675345)
# ('STOP_EVALUATION_TRIP', 'suburb_bicycling', 1564340984.813, 1564340984.8298311)
# All ranges are complete, nothing to change
# {'suburb_city_driving_weekend', 'suburb_bicycling'}
# ios: Found 2 trips for evaluation fixed:ACCURACY_CONTROL_1
# ('suburb_city_driving_weekend_0', 800.3041338920593, <Arrow [2019-07-28T10:19:03.776588-07:00]>, <Arrow [2019-07-28T10:32:24.080722-07:00]>)
# ('suburb_bicycling_0', 1298.1544861793518, <Arrow [2019-07-28T11:48:06.675345-07:00]>, <Arrow [2019-07-28T12:09:44.829831-07:00]>)
# ('START_EVALUATION_TRIP', 'suburb_city_driving_weekend', 1564351324.911, 1564351324.965219)
# ('STOP_EVALUATION_TRIP', 'suburb_city_driving_weekend', 1564352210.52, 1564352210.532115)
# ('START_EVALUATION_TRIP', 'suburb_bicycling', 1564356822.001, 1564356822.064345)
# ('STOP_EVALUATION_TRIP', 'suburb_bicycling', 1564358080.307, 1564358080.320724)
# All ranges are complete, nothing to change
# {'suburb_city_driving_weekend', 'suburb_bicycling'}
# ios: Found 2 trips for evaluation fixed:ACCURACY_CONTROL_2
# ('suburb_city_driving_weekend_0', 885.5668959617615, <Arrow [2019-07-28T15:02:04.965219-07:00]>, <Arrow [2019-07-28T15:16:50.532115-07:00]>)
# ('suburb_bicycling_0', 1258.2563791275024, <Arrow [2019-07-28T16:33:42.064345-07:00]>, <Arrow [2019-07-28T16:54:40.320724-07:00]>)
# -------------------- About to fill in evaluation sections --------------------
# ('START_EVALUATION_SECTION', 'walk_start', 1564274334.164, 1564274334.1926432)
# ('STOP_EVALUATION_SECTION', 'walk_start', 1564274403.167, 1564274403.3032)
# ('START_EVALUATION_SECTION', 'suburb_city_driving_weekend', 1564274403.168, 1564274403.318182)
# ('STOP_EVALUATION_SECTION', 'suburb_city_driving_weekend', 1564275146.671, 1564275146.823849)
# ('START_EVALUATION_SECTION', 'walk_start', 1564275146.672, 1564275146.843096)
# ('STOP_EVALUATION_SECTION', 'walk_start', 1564275296.359, 1564275296.450234)
# All ranges are complete, nothing to change
# {'walk_start', 'suburb_city_driving_weekend'}
# ios: Found 3 sections for evaluation suburb_city_driving_weekend_0
# ('walk_start_0', 69.1105568408966, <Arrow [2019-07-27T17:38:54.192643-07:00]>, <Arrow [2019-07-27T17:40:03.303200-07:00]>)
# ('suburb_city_driving_weekend_0', 743.5056669712067, <Arrow [2019-07-27T17:40:03.318182-07:00]>, <Arrow [2019-07-27T17:52:26.823849-07:00]>)
# ('walk_start_1', 149.6071379184723, <Arrow [2019-07-27T17:52:26.843096-07:00]>, <Arrow [2019-07-27T17:54:56.450234-07:00]>)
# ('START_EVALUATION_SECTION', 'walk_start', 1564279157.454, 1564279157.495898)
# ('STOP_EVALUATION_SECTION', 'walk_start', 1564279266.482, 1564279266.611826)
# ('START_EVALUATION_SECTION', 'suburb_bicycling', 1564279266.482, 1564279266.626976)
# ('STOP_EVALUATION_SECTION', 'suburb_bicycling', 1564280430.855, 1564280431.0447721)
# ('START_EVALUATION_SECTION', 'walk_start', 1564280430.858, 1564280431.060968)
# ('STOP_EVALUATION_SECTION', 'walk_start', 1564280457.294, 1564280457.402429)
# All ranges are complete, nothing to change
# {'walk_start', 'suburb_bicycling'}
# ('START_EVALUATION_SECTION', 'suburb_city_driving_weekend', 1564351473.255, 1564351473.431247)
# ('STOP_EVALUATION_SECTION', 'suburb_city_driving_weekend', 1564352106.152, 1564352106.261671)
# ('START_EVALUATION_SECTION', 'walk_start', 1564352106.154, 1564352106.274094)
# ('STOP_EVALUATION_SECTION', 'walk_start', 1564352210.414, 1564352210.4803581)
# All ranges are complete, nothing to change
# {'walk_start', 'suburb_city_driving_weekend'}
# ios: Found 3 sections for evaluation suburb_city_driving_weekend_0
# ('walk_start_0', 148.38958406448364, <Arrow [2019-07-28T15:02:05.023067-07:00]>, <Arrow [2019-07-28T15:04:33.412651-07:00]>)
# ('suburb_city_driving_weekend_0', 632.8304240703583, <Arrow [2019-07-28T15:04:33.431247-07:00]>, <Arrow [2019-07-28T15:15:06.261671-07:00]>)
# ('walk_start_1', 104.20626401901245, <Arrow [2019-07-28T15:15:06.274094-07:00]>, <Arrow [2019-07-28T15:16:50.480358-07:00]>)
# ('START_EVALUATION_SECTION', 'walk_start', 1564356822.09, 1564356822.1187859)
# ('STOP_EVALUATION_SECTION', 'walk_start', 1564356889.402, 1564356889.523539)
# ('START_EVALUATION_SECTION', 'suburb_bicycling', 1564356889.403, 1564356889.550396)
# ('STOP_EVALUATION_SECTION', 'suburb_bicycling', 1564358050.089, 1564358050.176182)
# ('START_EVALUATION_SECTION', 'walk_start', 1564358050.09, 1564358050.1955462)
# ('STOP_EVALUATION_SECTION', 'walk_start', 1564358080.215, 1564358080.2698169)
# All ranges are complete, nothing to change
# {'walk_start', 'suburb_bicycling'}
# ios: Found 3 sections for evaluation suburb_bicycling_0
# ('walk_start_0', 67.4047532081604, <Arrow [2019-07-28T16:33:42.118786-07:00]>, <Arrow [2019-07-28T16:34:49.523539-07:00]>)
# ('suburb_bicycling_0', 1160.6257860660553, <Arrow [2019-07-28T16:34:49.550396-07:00]>, <Arrow [2019-07-28T16:54:10.176182-07:00]>)
# ('walk_start_1', 30.074270725250244, <Arrow [2019-07-28T16:54:10.195546-07:00]>, <Arrow [2019-07-28T16:54:40.269817-07:00]>)
# -------------------- About to copy trip and section ranges --------------------
# dict_keys(['fixed:ACCURACY_CONTROL_0', 'fixed:ACCURACY_CONTROL_1', 'fixed:ACCURACY_CONTROL_2'])
# Before copying found 1/2 phones with ground truth for experiment of size 3
# Uncopied ground truth of length 2 on found on phone ios
# Ground truthed trip ranges = [{'trip_id': 'suburb_city_driving_weekend_0', 'trip_id_base': 'suburb_city_driving_weekend', 'trip_run': 0, 'start_ts': 1564274334.143985, 'end_ts': 1564275296.504297, 'duration': 962.3603119850159, 'evaluation_section_ranges': [{'trip_id': 'walk_start_0', 'trip_id_base': 'walk_start', 'trip_run': 0, 'start_ts': 1564274334.1926432, 'end_ts': 1564274403.3032, 'duration': 69.1105568408966}, {'trip_id': 'suburb_city_driving_weekend_0', 'trip_id_base': 'suburb_city_driving_weekend', 'trip_run': 0, 'start_ts': 1564274403.318182, 'end_ts': 1564275146.823849, 'duration': 743.5056669712067}, {'trip_id': 'walk_start_1', 'trip_id_base': 'walk_start', 'trip_run': 1, 'start_ts': 1564275146.843096, 'end_ts': 1564275296.450234, 'duration': 149.6071379184723}]}, {'trip_id': 'suburb_bicycling_0', 'trip_id_base': 'suburb_bicycling', 'trip_run': 0, 'start_ts': 1564279157.435039, 'end_ts': 1564280457.464819, 'duration': 1300.0297799110413, 'evaluation_section_ranges': [{'trip_id': 'walk_start_0', 'trip_id_base': 'walk_start', 'trip_run': 0, 'start_ts': 1564279157.495898, 'end_ts': 1564279266.611826, 'duration': 109.1159279346466}, {'trip_id': 'suburb_bicycling_0', 'trip_id_base': 'suburb_bicycling', 'trip_run': 0, 'start_ts': 1564279266.626976, 'end_ts': 1564280431.0447721, 'duration': 1164.4177961349487}, {'trip_id': 'walk_start_1', 'trip_id_base': 'walk_start', 'trip_run': 1, 'start_ts': 1564280431.060968, 'end_ts': 1564280457.402429, 'duration': 26.341461181640625}]}]
# Copying 2 ranges to android, fixed:ACCURACY_CONTROL_0
# After copying found 2/2 phones with ground truth for experiment of size 3
# Before copying found 1/2 phones with ground truth for experiment of size 3
# Uncopied ground truth of length 2 on found on phone ios
# Ground truthed trip ranges = [{'trip_id': 'suburb_city_driving_weekend_0', 'trip_id_base': 'suburb_city_driving_weekend', 'trip_run': 0, 'start_ts': 1564334343.776588, 'end_ts': 1564335144.0807219, 'duration': 800.3041338920593, 'evaluation_section_ranges': [{'trip_id': 'walk_start_0', 'trip_id_base': 'walk_start', 'trip_run': 0, 'start_ts': 1564334343.849936, 'end_ts': 1564334441.1367059, 'duration': 97.28676986694336}, {'trip_id': 'suburb_city_driving_weekend_0', 'trip_id_base': 'suburb_city_driving_weekend', 'trip_run': 0, 'start_ts': 1564334441.1543741, 'end_ts': 1564335067.707838, 'duration': 626.553463935852}, {'trip_id': 'walk_start_1', 'trip_id_base': 'walk_start', 'trip_run': 1, 'start_ts': 1564335067.72556, 'end_ts': 1564335144.027879, 'duration': 76.3023190498352}]}, {'trip_id': 'suburb_bicycling_0', 'trip_id_base': 'suburb_bicycling', 'trip_run': 0, 'start_ts': 1564339686.675345, 'end_ts': 1564340984.8298311, 'duration': 1298.1544861793518, 'evaluation_section_ranges': [{'trip_id': 'walk_start_0', 'trip_id_base': 'walk_start', 'trip_run': 0, 'start_ts': 1564339686.740189, 'end_ts': 1564339729.558238, 'duration': 42.81804895401001}, {'trip_id': 'suburb_bicycling_0', 'trip_id_base': 'suburb_bicycling', 'trip_run': 0, 'start_ts': 1564339729.5745811, 'end_ts': 1564340956.4001331, 'duration': 1226.8255519866943}, {'trip_id': 'walk_start_1', 'trip_id_base': 'walk_start', 'trip_run': 1, 'start_ts': 1564340956.420092, 'end_ts': 1564340984.770471, 'duration': 28.35037899017334}]}]
# Copying 2 ranges to android, fixed:ACCURACY_CONTROL_1
# After copying found 2/2 phones with ground truth for experiment of size 3
# Before copying found 1/2 phones with ground truth for experiment of size 3
# Uncopied ground truth of length 2 on found on phone ios
# Ground truthed trip ranges = [{'trip_id': 'suburb_city_driving_weekend_0', 'trip_id_base': 'suburb_city_driving_weekend', 'trip_run': 0, 'start_ts': 1564351324.965219, 'end_ts': 1564352210.532115, 'duration': 885.5668959617615, 'evaluation_section_ranges': [{'trip_id': 'walk_start_0', 'trip_id_base': 'walk_start', 'trip_run': 0, 'start_ts': 1564351325.023067, 'end_ts': 1564351473.412651, 'duration': 148.38958406448364}, {'trip_id': 'suburb_city_driving_weekend_0', 'trip_id_base': 'suburb_city_driving_weekend', 'trip_run': 0, 'start_ts': 1564351473.431247, 'end_ts': 1564352106.261671, 'duration': 632.8304240703583}, {'trip_id': 'walk_start_1', 'trip_id_base': 'walk_start', 'trip_run': 1, 'start_ts': 1564352106.274094, 'end_ts': 1564352210.4803581, 'duration': 104.20626401901245}]}, {'trip_id': 'suburb_bicycling_0', 'trip_id_base': 'suburb_bicycling', 'trip_run': 0, 'start_ts': 1564356822.064345, 'end_ts': 1564358080.320724, 'duration': 1258.2563791275024, 'evaluation_section_ranges': [{'trip_id': 'walk_start_0', 'trip_id_base': 'walk_start', 'trip_run': 0, 'start_ts': 1564356822.1187859, 'end_ts': 1564356889.523539, 'duration': 67.4047532081604}, {'trip_id': 'suburb_bicycling_0', 'trip_id_base': 'suburb_bicycling', 'trip_run': 0, 'start_ts': 1564356889.550396, 'end_ts': 1564358050.176182, 'duration': 1160.6257860660553}, {'trip_id': 'walk_start_1', 'trip_id_base': 'walk_start', 'trip_run': 1, 'start_ts': 1564358050.1955462, 'end_ts': 1564358080.2698169, 'duration': 30.074270725250244}]}]
# Copying 2 ranges to android, fixed:ACCURACY_CONTROL_2
# After copying found 2/2 phones with ground truth for experiment of size 3
# dict_keys(['ucb-sdb-android-1', 'ucb-sdb-android-2', 'ucb-sdb-android-3', 'ucb-sdb-android-4'])
# Found accuracy control, skipping copy
# android: Copying ucb-sdb-android-2 accuracy trips to 2, before = 0
# ('suburb_city_driving_weekend_0', 962.3603119850159, <Arrow [2019-07-27T17:38:54.143985-07:00]>, <Arrow [2019-07-27T17:54:56.504297-07:00]>)
# ('suburb_bicycling_0', 1300.0297799110413, <Arrow [2019-07-27T18:59:17.435039-07:00]>, <Arrow [2019-07-27T19:20:57.464819-07:00]>)
# android: Copying ucb-sdb-android-2 accuracy trips to 2, before = 0
# ('suburb_city_driving_weekend_0', 800.3041338920593, <Arrow [2019-07-28T10:19:03.776588-07:00]>, <Arrow [2019-07-28T10:32:24.080722-07:00]>)
# ('suburb_bicycling_0', 1298.1544861793518, <Arrow [2019-07-28T11:48:06.675345-07:00]>, <Arrow [2019-07-28T12:09:44.829831-07:00]>)
# android: Copying ucb-sdb-android-2 accuracy trips to 2, before = 0
# ('suburb_city_driving_weekend_0', 885.5668959617615, <Arrow [2019-07-28T15:02:04.965219-07:00]>, <Arrow [2019-07-28T15:16:50.532115-07:00]>)
# ('suburb_bicycling_0', 1258.2563791275024, <Arrow [2019-07-28T16:33:42.064345-07:00]>, <Arrow [2019-07-28T16:54:40.320724-07:00]>)
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1564274314.707, 'end_time': 1564282393.429}
# response = <Response [200]>
# Found 7 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1564334117.295, 'end_time': 1564343045.9}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1564351305.633, 'end_time': 1564360156.392}
# response = <Response [200]>
# Found 9 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1564274304.968, 'end_time': 1564282402.886}
# response = <Response [200]>
# Found 10 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1564334125.764, 'end_time': 1564343115.071}
# response = <Response [200]>
# Found 15 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1564351292.705, 'end_time': 1564360115.769}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1564274288.319, 'end_time': 1564282423.072}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1564334097.33, 'end_time': 1564343025.406}
# response = <Response [200]>
# Found 17 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1564351277.477, 'end_time': 1564360134.181}
# response = <Response [200]>
# Found 9 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1564274294.643, 'end_time': 1564282430.466}
# response = <Response [200]>
# Found 7 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1564334109.339, 'end_time': 1564343036.862}
# response = <Response [200]>
# Found 9 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1564351263.931, 'end_time': 1564360071.417}
# response = <Response [200]>
# Found 7 entries
# Processing data for ios phones
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1564274247.275763, 'end_time': 1564282290.729272}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1564333996.5363011, 'end_time': 1564342975.472409}
# response = <Response [200]>
# Found 18 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1564351246.07085, 'end_time': 1564359997.0496612}
# response = <Response [200]>
# Found 19 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1564274252.429922, 'end_time': 1564282305.5882301}
# response = <Response [200]>
# Found 31 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1564334014.759484, 'end_time': 1564342987.826695}
# response = <Response [200]>
# Found 29 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1564351227.1936831, 'end_time': 1564360024.574613}
# response = <Response [200]>
# Found 31 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1564274265.212364, 'end_time': 1564282322.549677}
# response = <Response [200]>
# Found 31 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1564334084.0051398, 'end_time': 1564342996.99437}
# response = <Response [200]>
# Found 29 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1564351207.910284, 'end_time': 1564360053.314023}
# response = <Response [200]>
# Found 30 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1564274276.021558, 'end_time': 1564282332.15351}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1564334069.1049929, 'end_time': 1564343007.721693}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1564351193.2504249, 'end_time': 1564360033.887364}
# response = <Response [200]>
# Found 12 entries
# -------------------- About to fill in location information --------------------
# Processing data for android phones
# Processing data for ios phones
# Processing data for android phones
# About to retrieve data for ucb-sdb-android-1 from 1564274314.707 -> 1564282393.429
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1564274314.707, 'end_time': 1564282393.429}
# response = <Response [200]>
# Found 4680 entries
# Retrieved 4680 entries with timestamps [1564274315.5, 1564274317, 1564274318, 1564274319, 1564274320, 1564274321, 1564274322, 1564274323, 1564274324, 1564274325]...
# About to retrieve data for ucb-sdb-android-1 from 1564282393 -> 1564282393.429
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1564282393, 'end_time': 1564282393.429}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1564282393]...
# About to retrieve data for ucb-sdb-android-1 from 1564334117.295 -> 1564343045.9
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1564334117.295, 'end_time': 1564343045.9}
# response = <Response [200]>
# Found 5675 entries
# Retrieved 5675 entries with timestamps [1564334117.66, 1564334121, 1564334122, 1564334123, 1564334124, 1564334125, 1564334126, 1564334127, 1564334128, 1564334129]...
# About to retrieve data for ucb-sdb-android-1 from 1564343046 -> 1564343045.9
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1564343046, 'end_time': 1564343045.9}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-1 from 1564351305.633 -> 1564360156.392
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1564351305.633, 'end_time': 1564360156.392}
# response = <Response [200]>
# Found 7924 entries
# Retrieved 7924 entries with timestamps [1564344449, 1564351311, 1564351312, 1564351313, 1564351314, 1564351315, 1564351316, 1564351317, 1564351318, 1564351319]...
# About to retrieve data for ucb-sdb-android-1 from 1564360156 -> 1564360156.392
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1564360156, 'end_time': 1564360156.392}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-2 from 1564274304.968 -> 1564282402.886
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1564274304.968, 'end_time': 1564282402.886}
# response = <Response [200]>
# Found 1868 entries
# Retrieved 1868 entries with timestamps [1564274558.354, 1564274558.727, 1564274564.028, 1564274565, 1564274566, 1564274567, 1564274568, 1564274569, 1564274570, 1564274571]...
# About to retrieve data for ucb-sdb-android-2 from 1564280652 -> 1564282402.886
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1564280652, 'end_time': 1564282402.886}
# response = <Response [200]>
# Found 15 entries
# Retrieved 15 entries with timestamps [1564280638, 1564280639, 1564280640, 1564280641, 1564280642, 1564280643, 1564280644, 1564280645, 1564280646, 1564280647]...
# About to retrieve data for ucb-sdb-android-2 from 1564280652 -> 1564282402.886
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1564280652, 'end_time': 1564282402.886}
# response = <Response [200]>
# Found 15 entries
# Retrieved 15 entries with timestamps [1564280638, 1564280639, 1564280640, 1564280641, 1564280642, 1564280643, 1564280644, 1564280645, 1564280646, 1564280647]...
# About to retrieve data for ucb-sdb-android-2 from 1564334125.764 -> 1564343115.071
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1564334125.764, 'end_time': 1564343115.071}
# response = <Response [200]>
# Found 1807 entries
# Retrieved 1807 entries with timestamps [1564334483, 1564282348, 1564334538, 1564334539, 1564334540, 1564334541, 1564334542, 1564334543, 1564334544, 1564334545]...
# About to retrieve data for ucb-sdb-android-2 from 1564341168 -> 1564343115.071
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1564341168, 'end_time': 1564343115.071}
# response = <Response [200]>
# Found 4 entries
# Retrieved 4 entries with timestamps [1564341165, 1564341166, 1564341167, 1564341168]...
# About to retrieve data for ucb-sdb-android-2 from 1564341168 -> 1564343115.071
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1564341168, 'end_time': 1564343115.071}
# response = <Response [200]>
# Found 4 entries
# Retrieved 4 entries with timestamps [1564341165, 1564341166, 1564341167, 1564341168]...
# About to retrieve data for ucb-sdb-android-2 from 1564351292.705 -> 1564360115.769
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1564351292.705, 'end_time': 1564360115.769}
# response = <Response [200]>
# Found 2108 entries
# Retrieved 2108 entries with timestamps [1564351559, 1564340608, 1564351626, 1564351627, 1564351628, 1564351629, 1564351630, 1564351631, 1564351632, 1564351633]...
# About to retrieve data for ucb-sdb-android-2 from 1564358443 -> 1564360115.769
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1564358443, 'end_time': 1564360115.769}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1564358443]...
# About to retrieve data for ucb-sdb-android-3 from 1564274288.319 -> 1564282423.072
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1564274288.319, 'end_time': 1564282423.072}
# response = <Response [200]>
# Found 95 entries
# Retrieved 95 entries with timestamps [1564274778.389, 1564274778.389, 1564274795, 1564274812.987, 1564274819, 1564274844.433, 1564274875, 1564274907.723, 1564274938.773, 1564274965]...
# About to retrieve data for ucb-sdb-android-3 from 1564280683 -> 1564282423.072
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1564280683, 'end_time': 1564282423.072}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1564280683]...
# About to retrieve data for ucb-sdb-android-3 from 1564334097.33 -> 1564343025.406
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1564334097.33, 'end_time': 1564343025.406}
# response = <Response [200]>
# Found 119 entries
# Retrieved 119 entries with timestamps [1564334507.338, 1564334507.338, 1564334515, 1564334538.756, 1564334569.758, 1564334604.698, 1564334611, 1564334634, 1564334640.312, 1564334665]...
# About to retrieve data for ucb-sdb-android-3 from 1564341146 -> 1564343025.406
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1564341146, 'end_time': 1564343025.406}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-3 from 1564351277.477 -> 1564360134.181
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1564351277.477, 'end_time': 1564360134.181}
# response = <Response [200]>
# Found 88 entries
# Retrieved 88 entries with timestamps [1564351556, 1564343213, 1564351624.625, 1564351655.257, 1564351690, 1564351720, 1564351750, 1564351780, 1564351810, 1564351839]...
# About to retrieve data for ucb-sdb-android-3 from 1564358257.713 -> 1564360134.181
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1564358257.713, 'end_time': 1564360134.181}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1564358257.713]...
# About to retrieve data for ucb-sdb-android-4 from 1564274294.643 -> 1564282430.466
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1564274294.643, 'end_time': 1564282430.466}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-4 from 1564334109.339 -> 1564343036.862
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1564334109.339, 'end_time': 1564343036.862}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-4 from 1564351263.931 -> 1564360071.417
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1564351263.931, 'end_time': 1564360071.417}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# Processing data for ios phones
# About to retrieve data for ucb-sdb-ios-1 from 1564274247.275763 -> 1564282290.729272
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/location'], 'start_time': 1564274247.275763, 'end_time': 1564282290.729272}
# response = <Response [200]>
# Found 2459 entries
# Retrieved 2459 entries with timestamps [1564274243.652639, 1564274247.567023, 1564274247.576466, 1564274249.99164, 1564274249.9998722, 1564274250.9998431, 1564274251.9998622, 1564274252.9998202, 1564274254.9997473, 1564274255.9997168]...
# About to retrieve data for ucb-sdb-ios-1 from 1564282281.9955974 -> 1564282290.729272
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/location'], 'start_time': 1564282281.9955974, 'end_time': 1564282290.729272}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1564282281.9955974]...
# About to retrieve data for ucb-sdb-ios-1 from 1564333996.5363011 -> 1564342975.472409
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/location'], 'start_time': 1564333996.5363011, 'end_time': 1564342975.472409}
# response = <Response [200]>
# Found 2574 entries
# Retrieved 2574 entries with timestamps [1564333996.796725, 1564333998.411439, 1564333998.7605991, 1564334000.0397015, 1564334001.0372047, 1564334002.0346103, 1564334003.0323296, 1564334004.030233, 1564334005.0279303, 1564334007.0244765]...
# About to retrieve data for ucb-sdb-ios-1 from 1564342965.9946914 -> 1564342975.472409
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/location'], 'start_time': 1564342965.9946914, 'end_time': 1564342975.472409}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1564342965.9946914]...
# About to retrieve data for ucb-sdb-ios-1 from 1564351246.07085 -> 1564359997.0496612
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/location'], 'start_time': 1564351246.07085, 'end_time': 1564359997.0496612}
# response = <Response [200]>
# Found 2214 entries
# Retrieved 2214 entries with timestamps [1564351245.890137, 1564351251.02554, 1564351252.0238216, 1564351253.022198, 1564351254.0206494, 1564351255.0192485, 1564351257.0167162, 1564351258.0155365, 1564351259.0144756, 1564351261.0124218]...
# ...
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/motion_activity'], 'start_time': 1564351246.07085, 'end_time': 1564359997.0496612}
# response = <Response [200]>
# Found 472 entries
# Retrieved 472 entries with timestamps [1564351283.6382508, 1564351323.8419127, 1564351326.3507926, 1564351471.793641, 1564351564.5028896, 1564351577.031905, 1564351597.0661352, 1564351617.101654, 1564351629.6283417, 1564351682.2153893]...
# About to retrieve data for ucb-sdb-ios-1 from 1564359606.3683307 -> 1564359997.0496612
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/motion_activity'], 'start_time': 1564359606.3683307, 'end_time': 1564359997.0496612}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1564359606.3683307]...
# About to retrieve data for ucb-sdb-ios-2 from 1564274252.429922 -> 1564282305.5882301
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/motion_activity'], 'start_time': 1564274252.429922, 'end_time': 1564282305.5882301}
# response = <Response [200]>
# Found 257 entries
# Retrieved 257 entries with timestamps [1564274267.3556867, 1564274341.7022724, 1564274401.7022734, 1564274551.5464954, 1564274606.5464952, 1564274616.546495, 1564274641.546495, 1564274701.546495, 1564274731.5464954, 1564274888.5077243]...
# About to retrieve data for ucb-sdb-ios-2 from 1564282267.5252838 -> 1564282305.5882301
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': 
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/motion_activity'], 'start_time': 1564360049.6726303, 'end_time': 1564360053.314023}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1564360049.6726303]...
# About to retrieve data for ucb-sdb-ios-4 from 1564274276.021558 -> 1564282332.15351
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/motion_activity'], 'start_time': 1564274276.021558, 'end_time': 1564282332.15351}
# response = <Response [200]>
# Found 243 entries
# Retrieved 243 entries with timestamps [1564274288.6357331, 1564274293.6357331, 1564274343.6357334, 1564274438.6357336, 1564274568.6357331, 1564274603.6357336, 1564274673.6357334, 1564274758.684916, 1564274797.4722486, 1564274835.013862]...
# About to retrieve data for ucb-sdb-ios-4 from 1564282332.075515 -> 1564282332.15351
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/motion_activity'], 'start_time': 1564282332.075515, 'end_time': 1564282332.15351}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1564282332.075515]...
# About to retrieve data for ucb-sdb-ios-4 from 1564334069.1049929 -> 1564343007.721693
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/motion_activity'], 'start_time': 1564334069.1049929, 'end_time': 1564343007.721693}
# response = <Response [200]>
# Found 192 entries
# Retrieved 192 entries with timestamps [1564334156.9572866, 1564334159.5107808, 1564334246.4367895, 1564334296.6510048, 1564334436.6510048, 1564334561.6510043, 1564334591.6510043, 1564334811.6510043, 1564334880.665307, 1564335093.390451]...
# About to retrieve data for ucb-sdb-ios-4 from 1564342922.0445738 -> 1564343007.721693
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/motion_activity'], 'start_time': 1564342922.0445738, 'end_time': 1564343007.721693}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1564342922.0445738]...
# About to retrieve data for ucb-sdb-ios-4 from 1564351193.2504249 -> 1564360033.887364
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/motion_activity'], 'start_time': 1564351193.2504249, 'end_time': 1564360033.887364}
# response = <Response [200]>
# Found 275 entries
# Retrieved 275 entries with timestamps [1564351196.5442877, 1564351206.6440516, 1564351210.383542, 1564351211.8839521, 1564351260.100387, 1564351335.1003873, 1564351470.100387, 1564352125.1003876, 1564352379.9423804, 1564352469.94238]...
# About to retrieve data for ucb-sdb-ios-4 from 1564360033.793456 -> 1564360033.887364
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/motion_activity'], 'start_time': 1564360033.793456, 'end_time': 1564360033.887364}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1564360033.793456]...
# -------------------- About to fill in transition information --------------------
# Processing data for android phones
# Processing data for ios phones
# Processing data for android phones
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['statemachine/transition'], 'start_time': 1564274314.707, 'end_time': 1564282393.429}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['statemachine/transition'], 'start_time': 1564334117.295, 'end_time': 1564343045.9}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['statemachine/transition'], 'start_time': 1564351305.633, 'end_time': 1564360156.392}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1564274304.968, 'end_time': 1564282402.886}
# response = <Response [200]>
# Found 6 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1564334125.764, 'end_time': 1564343115.071}
# response = <Response [200]>
# Found 12 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1564351292.705, 'end_time': 1564360115.769}
# response = <Response [200]>
# Found 6 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1564274288.319, 'end_time': 1564282423.072}
# response = <Response [200]>
# Found 8 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1564334097.33, 'end_time': 1564343025.406}
# response = <Response [200]>
# Found 12 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1564351277.477, 'end_time': 1564360134.181}
# response = <Response [200]>
# Found 6 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1564274294.643, 'end_time': 1564282430.466}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1564334109.339, 'end_time': 1564343036.862}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1564351263.931, 'end_time': 1564360071.417}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# Processing data for ios phones
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1564274247.275763, 'end_time': 1564282290.729272}
# response = <Response [200]>
# Found 18 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1564333996.5363011, 'end_time': 1564342975.472409}
# response = <Response [200]>
# Found 15 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1564351246.07085, 'end_time': 1564359997.0496612}
# response = <Response [200]>
# Found 17 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1564274252.429922, 'end_time': 1564282305.5882301}
# response = <Response [200]>
# Found 27 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1564334014.759484, 'end_time': 1564342987.826695}
# response = <Response [200]>
# Found 25 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1564351227.1936831, 'end_time': 1564360024.574613}
# response = <Response [200]>
# Found 27 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1564274265.212364, 'end_time': 1564282322.549677}
# response = <Response [200]>
# Found 27 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1564334084.0051398, 'end_time': 1564342996.99437}
# response = <Response [200]>
# Found 25 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1564351207.910284, 'end_time': 1564360053.314023}
# response = <Response [200]>
# Found 26 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1564274276.021558, 'end_time': 1564282332.15351}
# response = <Response [200]>
# Found 8 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1564334069.1049929, 'end_time': 1564343007.721693}
# response = <Response [200]>
# Found 8 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1564351193.2504249, 'end_time': 1564360033.887364}
# response = <Response [200]>
# Found 10 entries
# transition has not been processed, creating ts -> fmt_time
# -------------------- About to select trip specific ranges --------------------
# Filling label ucb-sdb-android-1 for OS android
# Filling label ucb-sdb-android-2 for OS android
# Filling label ucb-sdb-android-3 for OS android
# Filling label ucb-sdb-android-4 for OS android
# Filling label ucb-sdb-ios-1 for OS ios
# Filling label ucb-sdb-ios-2 for OS ios
# Filling label ucb-sdb-ios-3 for OS ios
# Filling label ucb-sdb-ios-4 for OS ios
# -------------------- Done populating information from server --------------------

# %%
for phone_os, phone_map in pv.map().items():
    print(15 * "=*")
    print(phone_os, phone_map.keys())
    for phone_label, phone_detail_map in phone_map.items():
        print(4 * ' ', 15 * "-*")
        print(4 * ' ', phone_label, phone_detail_map.keys())
        # this spec does not have any calibration ranges, but evaluation ranges are actually cooler
        for r in phone_detail_map["evaluation_ranges"]:
            print(8 * ' ', 30 * "=")
            print(8 * ' ',r.keys())
            print(8 * ' ',r["trip_id"], r["eval_common_trip_id"], r["eval_role"], len(r["evaluation_trip_ranges"]))
            for tr in r["evaluation_trip_ranges"]:
                print(12 * ' ', 30 * "-")
                print(12 * ' ',tr["trip_id"], tr.keys())
                for sr in tr["evaluation_section_ranges"]:
                    print(16 * ' ', 30 * "~")
                    print(16 * ' ',sr["trip_id"], sr.keys())
# Out:
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# android dict_keys(['ucb-sdb-android-1', 'ucb-sdb-android-2', 'ucb-sdb-android-3', 'ucb-sdb-android-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          fixed:ACCURACY_CONTROL_0 HAHFDC v/s HAMFDC accuracy_control_0 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 19    time
# 20    time
# 21    time
# 22    time
# 23    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 1444    time
# 1445    time
# 1446    time
# 1447    time
# 1448    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          fixed:ACCURACY_CONTROL_1 HAHFDC v/s HAMFDC accuracy_control_1 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 232    time
# 233    time
# 234    time
# 235    time
# 236    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 2314    time
# 2315    time
# 2316    time
# 2317    time
# 2318    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          fixed:ACCURACY_CONTROL_2 HAHFDC v/s HAMFDC accuracy_control_2 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 15    time
# 16    time
# 17    time
# 18    time
# 19    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 4777    time
# 4778    time
# 4779    time
# 4780    time
# 4781    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          HAHFDC v/s HAMFDC:HAHFDC_0 HAHFDC v/s HAMFDC HAHFDC_0 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 0    time
# 1    time
# 2    time
# 3    time
# 4    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 732    time
# 733    time
# 734    time
# 735    time
# 736    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          HAHFDC v/s HAMFDC:HAHFDC_1 HAHFDC v/s HAMFDC HAHFDC_1 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 0    time
# 2    time
# 3    time
# 4    time
# 5    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 819    time
# 820    time
# 821    time
# 822    time
# 823    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          HAHFDC v/s HAMFDC:HAHFDC_2 HAHFDC v/s HAMFDC HAHFDC_2 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 0    time
# 2    time
# 3    time
# 4    time
# 5    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 836    time
# 838    time
# 839    time
# 840    time
# 841    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          HAHFDC v/s HAMFDC:HAMFDC_0 HAHFDC v/s HAMFDC HAMFDC_0 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 0    time
# 1    time
# 2    time
# 3    time
# 4    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 51    time
# 52    time
# 53    time
# 54    time
# 55    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          HAHFDC v/s HAMFDC:HAMFDC_1 HAHFDC v/s HAMFDC HAMFDC_1 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 0    time
# 1    time
# 2    time
# 3    time
# 4    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 52    time
# 54    time
# 55    time
# 56    time
# 57    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          HAHFDC v/s HAMFDC:HAMFDC_2 HAHFDC v/s HAMFDC HAMFDC_2 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 0    time
# 2    time
# 3    time
# 4    time
# 5    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 33    time
# 35    time
# 36    time
# 37    time
# 38    time
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-4 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          fixed:POWER_CONTROL_0 HAHFDC v/s HAMFDC power_control_0 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          fixed:POWER_CONTROL_1 HAHFDC v/s HAMFDC power_control_1 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          fixed:POWER_CONTROL_2 HAHFDC v/s HAMFDC power_control_2 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# ios dict_keys(['ucb-sdb-ios-1', 'ucb-sdb-ios-2', 'ucb-sdb-ios-3', 'ucb-sdb-ios-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          fixed:ACCURACY_CONTROL_0 HAHFDC v/s MAHFDC accuracy_control_0 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 51    distance
# 52    distance
# 53    distance
# 54    distance
# 55    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 1249    distance
# 1250    distance
# 1251    distance
# 1252    distance
# 1253    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          fixed:ACCURACY_CONTROL_1 HAHFDC v/s MAHFDC accuracy_control_1 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 168    distance
# 169    distance
# 170    distance
# 171    distance
# 172    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 1390    distance
# 1391    distance
# 1392    distance
# 1393    distance
# 1394    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          fixed:ACCURACY_CONTROL_2 HAHFDC v/s MAHFDC accuracy_control_2 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 60    distance
# 61    distance
# 62    distance
# 63    distance
# 64    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 1078    distance
# 1079    distance
# 1080    distance
# 1081    distance
# 1082    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          HAHFDC v/s MAHFDC:HAHFDC_0 HAHFDC v/s MAHFDC HAHFDC_0 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 0    distance
# 1    distance
# 2    distance
# 3    distance
# 4    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 307    distance
# 308    distance
# 309    distance
# 310    distance
# 311    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          HAHFDC v/s MAHFDC:HAHFDC_1 HAHFDC v/s MAHFDC HAHFDC_1 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 0    distance
# 1    distance
# 2    distance
# 3    distance
# 4    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 542    distance
# 543    distance
# 544    distance
# 545    distance
# 546    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          HAHFDC v/s MAHFDC:HAHFDC_2 HAHFDC v/s MAHFDC HAHFDC_2 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 0    distance
# 1    distance
# 2    distance
# 3    distance
# 4    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 556    distance
# 557    distance
# 558    distance
# 559    distance
# 560    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          HAHFDC v/s MAHFDC:MAHFDC_0 HAHFDC v/s MAHFDC MAHFDC_0 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 5    distance
# 6    distance
# 7    distance
# 8    distance
# 9    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          HAHFDC v/s MAHFDC:MAHFDC_1 HAHFDC v/s MAHFDC MAHFDC_1 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 0    distance
# 1    distance
# 2    distance
# 3    distance
# 4    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 107    distance
# 108    distance
# 109    distance
# 110    distance
# 111    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          HAHFDC v/s MAHFDC:MAHFDC_2 HAHFDC v/s MAHFDC MAHFDC_2 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 0    distance
# 1    distance
# 2    distance
# 3    distance
# 4    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
# 111    distance
# 112    distance
# 113    distance
# 114    distance
# 115    distance
# Name: filter, dtype: object
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-4 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          fixed:POWER_CONTROL_0 HAHFDC v/s MAHFDC power_control_0 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          fixed:POWER_CONTROL_1 HAHFDC v/s MAHFDC power_control_1 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'eval_common_trip_id', 'eval_role', 'evaluation_trip_ranges', 'battery_entries', 'battery_df', 'location_entries', 'location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          fixed:POWER_CONTROL_2 HAHFDC v/s MAHFDC power_control_2 2
#              ------------------------------
#              suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_city_driving_weekend_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#              ------------------------------
#              suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'evaluation_section_ranges', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  suburb_bicycling_0 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                  walk_start_1 dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_df', 'location_df', 'motion_activity_df', 'transition_df'])

# %%
pv.map()["android"]["ucb-sdb-android-1"]["evaluation_ranges"][0]["evaluation_trip_ranges"]
# Out:
# []

# %%
len(pv.map()["ios"]["ucb-sdb-ios-1"]["evaluation_ranges"][0]["evaluation_trip_ranges"])
# Out:
# 3

# %% [markdown]
# ### Eval view
#
# In the eval view, the experiment is primary, and then there is a similar tree that you can traverse to get the data that you want. Traversing that tree typically involves nested for loops; here's an example of manipulating the phone view and traversing it. You can replace the print statements with real code. When you are ready to check this in, please move the function to one of the python modules so that we can invoke it more generally

# %%
importlib.reload(eiev)
# Out:
# <module 'emeval.input.eval_view' from '/Users/shankari/e-mission/e-mission-eval-public-data/emeval/input/eval_view.py'>

# %%
ev = eiev.EvaluationView()
ev.from_view_eval_trips(pv, "", "")

# %%
perfect_run = {}
flawed_but_fixed_run = {}
to_be_fixed_run = {}

for phone_os, eval_map in ev.map("evaluation").items():
    print(15 * "=*")
    print(phone_os, eval_map.keys())
    for (curr_calibrate, curr_calibrate_trip_map) in eval_map.items():
        print(4 * ' ', 15 * "-*")
        print(4 * ' ', curr_calibrate, curr_calibrate_trip_map.keys())
        for trip_id, trip_map in curr_calibrate_trip_map.items():
            print(8 * ' ', 30 * "=")
            print(8 * ' ', trip_id, trip_map.keys())
            perfect_run[phone_os] = trip_map["accuracy_control_0"]
            print(perfect_run["android"]["location_df"].head())
            flawed_but_fixed_run[phone_os] = trip_map["accuracy_control_0"]
            to_be_fixed_run[phone_os] = trip_map["accuracy_control_2"]

# %%
import arrow

# %%
fmt = lambda ts: arrow.get(ts).to("America/Los_Angeles")
fmts = lambda s: ("%s -> %s" % (fmt(s["start_ts"]), fmt(s["end_ts"])))
pr = perfect_run["ios"]
ffr = flawed_but_fixed_run["ios"]
tbfr = to_be_fixed_run["ios"]
for psr, ffsr, tbfsr in zip(pr["evaluation_section_ranges"],
                            ffr["evaluation_section_ranges"],
                            tbfr["evaluation_section_ranges"]):
    print("%s start:\n perfect %s,\n ffr     %s,\n tbfr    %s" % 
            (psr["trip_id_base"], fmts(psr), fmts(ffsr), fmts(tbfsr)))

# %%
flawed_but_fixed_run["ios"]["location_df"].head()

# %%
flawed_but_fixed_run["android"]["location_df"].head()

# %% [markdown]
# ### Ground truth
#
# The ground truth is stored in the spec, and we can retrieve it from there. Once we have retrieved the trip, there are many possible analyses using them. Please see `get_concat_trajectories` for an example.

# %% [markdown]
# ### For trips
#
# Using the phone view as an example

# %%
for phone_os, phone_map in pv.map().items():
    print(15 * "=*")
    print(phone_os, phone_map.keys())
    for phone_label, phone_detail_map in phone_map.items():
        print(4 * ' ', 15 * "-*")
        print(4 * ' ', phone_label, phone_detail_map["role"], phone_detail_map.keys())
        # this spec does not have any calibration ranges, but evaluation ranges are actually cooler
        for r in phone_detail_map["evaluation_ranges"]:
            print(8 * ' ', 30 * "=")
            print(8 * ' ',r.keys())
            print(8 * ' ',r["trip_id"], r["eval_common_trip_id"], r["eval_role"], len(r["evaluation_trip_ranges"]))
            for tr in r["evaluation_trip_ranges"]:
                print(12 * ' ', 30 * "-")
                print(12 * ' ',tr["trip_id"], tr.keys())
                # I am not printing the actual trajectories since that would be too long, only displaying modes
                gt_trip = sd.get_ground_truth_for_trip(tr["trip_id_base"])
                print(12 * ' ', eisd.SpecDetails.get_concat_trajectories(gt_trip)["properties"])

# %% [markdown]
# ## For sections
#
# Using the eval view as an example

# %%
for phone_os, eval_map in ev.map("evaluation").items():
    print(15 * "=*")
    print(phone_os, eval_map.keys())
    for (curr_calibrate, curr_calibrate_trip_map) in phone_map.items():
        print(4 * ' ', 15 * "-*")
        print(4 * ' ', curr_calibrate, curr_calibrate_trip_map.keys())
        for r in phone_detail_map["evaluation_ranges"]:
            print(8 * ' ', 30 * "=")
            print(8 * ' ',r.keys())
            print(8 * ' ',r["trip_id"], r["eval_common_trip_id"], r["eval_role"], len(r["evaluation_trip_ranges"]))
            for tr in r["evaluation_trip_ranges"]:
                print(12 * ' ', 30 * "-")
                print(12 * ' ',tr["trip_id"], tr.keys())
                for sr in tr["evaluation_section_ranges"]:
                    print(16 * ' ', 30 * "-")
                    gt_leg = sd.get_ground_truth_for_leg(sr["trip_id_base"])
                    print(16 * ' ', sr["trip_id"], gt_leg["mode"], sr.keys())

# %% [markdown]
# ### Work with a single trip
#
# You can also work with the details of a single trip - here, we look at the battery drain across phones for the third repetition. Code inspired by `plot_all_power_drain`

# %%
ifig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,5))
for phone_os, phone_map in pv.map().items():
    print(15 * "=*")
    print(phone_os, phone_map.keys())
    for phone_label, phone_detail_map in phone_map.items():
        print(4 * ' ', 15 * "-*")
        print(4 * ' ', phone_label, phone_detail_map["role"], phone_detail_map.keys())
        curr_range = phone_detail_map["evaluation_ranges"][2]
        print(8 * ' ',r["trip_id"], r["eval_common_trip_id"], r["eval_role"], len(r["evaluation_trip_ranges"]))
        battery_df = curr_range["battery_df"]
        battery_df.plot(x="hr", y="battery_level_pct", ax=ax,
                        label="%s (%s)" % (phone_label, phone_detail_map["role"]), ylim=(0,100))

# %% [markdown]
# ### Work with a single leg
#
# You can also work with the details of a single leg. This is not likely to be useful for power estimates because there are so few points, but it is going to be easier to work with trajectory estimates

# %%
third_repetition = pv.map()["ios"]["ucb-sdb-ios-1"]["evaluation_ranges"][2]; third_repetition["trip_id"]

# %%
bart_leg = third_repetition["evaluation_trip_ranges"][0]["evaluation_section_ranges"][4]; bart_leg["trip_id"]

# %%
gt_leg = sd.get_ground_truth_for_leg(bart_leg["trip_id_base"]); gt_leg["id"]

# %% [markdown]
# #### Display the leg
#
# Note the layer control on the map that allows you to toggle the lines separately

# %%
curr_map = folium.Map()
gt_leg_gj = sd.get_geojson_for_leg(gt_leg)
sensed_section_gj = ezpv.get_geojson_for_leg(bart_leg)
gt_leg_gj_feature = folium.GeoJson(gt_leg_gj, name="ground_truth")
sensed_leg_gj_feature = folium.GeoJson(sensed_section_gj, name="sensed_values")
curr_map.add_child(gt_leg_gj_feature)
curr_map.add_child(sensed_leg_gj_feature)
curr_map.fit_bounds(sensed_leg_gj_feature.get_bounds())
folium.LayerControl().add_to(curr_map)
curr_map

# %%
importlib.reload(eisd)

# %% [markdown]
# #### Display the leg with points
#
# In this case, the points are in a separate layer so they can be toggled indepdendently of the underlying lines

# %%
curr_map = folium.Map()
gt_leg_gj = sd.get_geojson_for_leg(gt_leg)
# print(gt_leg_gj)
sensed_section_gj = ezpv.get_geojson_for_leg(bart_leg)
# print(sensed_section_gj)
gt_leg_gj_feature = folium.GeoJson(gt_leg_gj, name="ground_truth")
# gt_leg_gj_points = ezpv.get_point_markers(gt_leg_gj[2], name="ground_truth_points", color="green")
sensed_leg_gj_feature = folium.GeoJson(sensed_section_gj, name="sensed_values")
sensed_leg_gj_points = ezpv.get_point_markers(sensed_section_gj, name="sensed_points", color="red")
curr_map.add_child(gt_leg_gj_feature)
# curr_map.add_child(gt_leg_gj_points)
curr_map.add_child(sensed_leg_gj_feature)
curr_map.add_child(sensed_leg_gj_points)
curr_map.fit_bounds(sensed_leg_gj_feature.get_bounds())
folium.LayerControl().add_to(curr_map)
curr_map

# %%
bart_leg["location_df"].iloc[60:70]

# %%
fig = bre.Figure()
bart_leg = flawed_but_fixed_run[0]["evaluation_trip_ranges"][0]["evaluation_section_ranges"][4]
fig.add_subplot(1, 2, 1).add_child(ezpv.display_map_detail_from_df(bart_leg["location_df"].iloc[-3:]))
bart_leg = flawed_but_fixed_run[1]["evaluation_trip_ranges"][0]["evaluation_section_ranges"][4]
fig.add_subplot(1, 2, 2).add_child(ezpv.display_map_detail_from_df(bart_leg["location_df"].iloc[-3:]))
