# %% [markdown]
# ## Stationary calibration
#
# This notebook contains the results of calibrating the 4 phones when configured next to each other with the same settings and placed next to each other in the same bookcase.

# %%
# for reading and validating data
import emeval.input.spec_details as eisd
import emeval.input.phone_view as eipv
import emeval.input.eval_view as eiev

# %%
# Visualization helpers
import emeval.viz.phone_view as ezpv
import emeval.viz.eval_view as ezev

# %%
# For plots
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# For maps
import branca.element as bre

# %%
import pandas as pd
import numpy as np
import scipy.interpolate as sci

# %% [markdown]
# ## Load and validate data
#
# The first issue to note is that we actually have two specs here. The first spec is the checked in `evaluation.spec.sample`, which defines calibration for both stationary and moving instances, and some evaluation trips. However, while starting with the calibration, we noticed some inconsistencies between the power curves. So in order to be more consistent, I defined a second, calibration-only spec `examples/calibration.only.json`, which essentially repeats the calibration experiments multiple times.
#
# After that, I returned to the first set of experiments for the moving calibration and the evaluation.

# %%
DATASTORE_URL = "http://cardshark.cs.berkeley.edu"
AUTHOR_EMAIL = "shankari@eecs.berkeley.edu"
sd_hf = eisd.SpecDetails(DATASTORE_URL, AUTHOR_EMAIL, "sfba_hf_calibration_stationary_only")
sd_mf = eisd.SpecDetails(DATASTORE_URL, AUTHOR_EMAIL, "sfba_med_freq_calibration_stationary_only")
# Out:
# About to retrieve messages using {'user': 'shankari@eecs.berkeley.edu', 'key_list': ['config/evaluation_spec'], 'start_time': 0, 'end_time': 1566365438}
# response = <Response [200]>
# Found 11 entries
# After iterating over 11 entries, entry found
# Found spec = Calibration for high frequencies only
# Evaluation ran from 2019-06-12T00:00:00-07:00 -> 2019-09-30T00:00:00-07:00
# About to retrieve messages using {'user': 'shankari@eecs.berkeley.edu', 'key_list': ['config/evaluation_spec'], 'start_time': 0, 'end_time': 1566365439}
# response = <Response [200]>
# Found 11 entries
# After iterating over 11 entries, entry found
# Found spec = Calibration for medium frequencies only
# Evaluation ran from 2019-07-18T00:00:00-07:00 -> 2019-09-30T00:00:00-07:00

# %%
pv_hf = eipv.PhoneView(sd_hf)
# Out:
# -------------------- About to read transitions from server --------------------
# Reading data for android phones
# Loading transitions for phone ucb-sdb-android-1
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['manual/evaluation_transition'], 'start_time': 1560322800, 'end_time': 1569826800}
# response = <Response [200]>
# Found 106 entries
# Loading transitions for phone ucb-sdb-android-2
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['manual/evaluation_transition'], 'start_time': 1560322800, 'end_time': 1569826800}
# response = <Response [200]>
# Found 86 entries
# Loading transitions for phone ucb-sdb-android-3
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['manual/evaluation_transition'], 'start_time': 1560322800, 'end_time': 1569826800}
# response = <Response [200]>
# Found 86 entries
# Loading transitions for phone ucb-sdb-android-4
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['manual/evaluation_transition'], 'start_time': 1560322800, 'end_time': 1569826800}
# response = <Response [200]>
# Found 86 entries
# Reading data for ios phones
# Loading transitions for phone ucb-sdb-ios-1
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['manual/evaluation_transition'], 'start_time': 1560322800, 'end_time': 1569826800}
# response = <Response [200]>
# Found 510 entries
# Loading transitions for phone ucb-sdb-ios-2
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['manual/evaluation_transition'], 'start_time': 1560322800, 'end_time': 1569826800}
# response = <Response [200]>
# Found 92 entries
# Loading transitions for phone ucb-sdb-ios-3
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['manual/evaluation_transition'], 'start_time': 1560322800, 'end_time': 1569826800}
# response = <Response [200]>
# Found 91 entries
# Loading transitions for phone ucb-sdb-ios-4
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['manual/evaluation_transition'], 'start_time': 1560322800, 'end_time': 1569826800}
# response = <Response [200]>
# Found 88 entries
# -------------------- About to fill calibration ranges --------------------
# Processing data for android phones
# Processing transitions for phone ucb-sdb-android-1
# Filtered 106 total -> 20 calibration transitions
# Processing transitions for phone ucb-sdb-android-2
# Filtered 86 total -> 20 calibration transitions
# Processing transitions for phone ucb-sdb-android-3
# Filtered 86 total -> 20 calibration transitions
# Processing transitions for phone ucb-sdb-android-4
# Filtered 86 total -> 20 calibration transitions
# Processing data for ios phones
# Processing transitions for phone ucb-sdb-ios-1
# Filtered 510 total -> 20 calibration transitions
# Processing transitions for phone ucb-sdb-ios-2
# Filtered 92 total -> 20 calibration transitions
# Processing transitions for phone ucb-sdb-ios-3
# Filtered 91 total -> 20 calibration transitions
# Processing transitions for phone ucb-sdb-ios-4
# Filtered 88 total -> 20 calibration transitions
# Processing data for android phones
# ---------- ucb-sdb-android-1
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560405169, 1560405169)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560453771, 1560453771)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560463523, 1560463523)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560525050, 1560525050)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560538052, 1560538052)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560603684, 1560603684)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560665721, 1560665721)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560722362, 1560722362)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560742839, 1560742839)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560795491, 1560795491)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560804485, 1560804485)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560845900, 1560845900)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560872200, 1560872200)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560915075, 1560915075)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560923342, 1560923342)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560966141, 1560966141)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564291253.299, 1564291253.301)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564322509.214, 1564322509.254)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564378191.877, 1564378191.879)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564431524.072, 1564431524.109)
# All ranges are complete, nothing to change
# {'10m_balanced_accuracy_high_frequency_stationary', 'best_high_accuracy_high_frequency_stationary', '100m_lowpwr_accuracy_high_frequency_stationary'}
# Found 10 ranges of duration [48602, 61527, 65632, 56641, 52652, 41415, 42875, 42799, 31255.952999830246, 53332.23000001907] for phone ucb-sdb-android-1
# ---------- ucb-sdb-android-2
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560405203, 1560405203)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560453817, 1560453817)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560463541, 1560463541)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560525163, 1560525163)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560538079, 1560538079)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560603727, 1560603727)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560665749, 1560665749)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560722409, 1560722409)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560742867, 1560742867)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560795517, 1560795517)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560804506, 1560804506)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560845915, 1560845915)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560872225, 1560872225)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560915091, 1560915091)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560923361, 1560923361)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560966141, 1560966141)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564291261.379, 1564291261.38)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564322534.204, 1564322534.258)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564378202.236, 1564378202.238)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564431535.1, 1564431535.147)
# All ranges are complete, nothing to change
# {'10m_balanced_accuracy_high_frequency_stationary', 'best_high_accuracy_high_frequency_stationary', '100m_lowpwr_accuracy_high_frequency_stationary'}
# Found 10 ranges of duration [48614, 61622, 65648, 56660, 52650, 41409, 42866, 42780, 31272.877999782562, 53332.90900015831] for phone ucb-sdb-android-2
# ---------- ucb-sdb-android-3
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560405245, 1560405245)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560453851, 1560453851)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560463576, 1560463576)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560525128, 1560525128)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560538099, 1560538099)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560603758, 1560603758)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560665775, 1560665775)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560722456, 1560722456)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560742889, 1560742889)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560795532, 1560795532)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560804526, 1560804526)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560845963, 1560845963)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560872251, 1560872251)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560915106, 1560915106)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560923383, 1560923383)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560966141, 1560966141)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564291272.426, 1564291272.43)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564322583.706, 1564322583.745)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564378215.22, 1564378215.221)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564431562.489, 1564431562.546)
# All ranges are complete, nothing to change
# {'10m_balanced_accuracy_high_frequency_stationary', 'best_high_accuracy_high_frequency_stationary', '100m_lowpwr_accuracy_high_frequency_stationary'}
# Found 10 ranges of duration [48606, 61552, 65659, 56681, 52643, 41437, 42855, 42758, 31311.314999818802, 53347.325000047684] for phone ucb-sdb-android-3
# ---------- ucb-sdb-android-4
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560405288, 1560405288)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560453880, 1560453880)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560463599, 1560463599)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560525163, 1560525163)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560538133, 1560538133)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560603781, 1560603781)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560665801, 1560665801)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560722494, 1560722494)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560742920, 1560742920)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560795552, 1560795552)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560804550, 1560804550)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560845983, 1560845983)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560872269, 1560872269)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560915128, 1560915128)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560923408, 1560923408)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560966191, 1560966191)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564291280.64, 1564291280.643)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564322619.779, 1564322619.839)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564378227.702, 1564378227.703)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564431577.441, 1564431577.476)
# All ranges are complete, nothing to change
# {'10m_balanced_accuracy_high_frequency_stationary', 'best_high_accuracy_high_frequency_stationary', '100m_lowpwr_accuracy_high_frequency_stationary'}
# Found 10 ranges of duration [48592, 61564, 65648, 56693, 52632, 41433, 42859, 42783, 31339.196000099182, 53349.77300000191] for phone ucb-sdb-android-4
# Processing data for ios phones
# ---------- ucb-sdb-ios-1
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560405345, 1560405345)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560453573, 1560453573)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560463418, 1560463418)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560524922, 1560524922)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560537950, 1560537950)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560603575, 1560603575)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560665619, 1560665619)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560722240, 1560722240)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560742749, 1560742749)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560795403, 1560795403)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560804398, 1560804398)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560845830, 1560845830)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560872058, 1560872058)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560914996, 1560914996)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560923261, 1560923261)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560966078, 1560966078)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564291205.898, 1564291206.023632)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564322408.302, 1564322408.762954)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564378145.19, 1564378145.303485)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564431421.144, 1564431421.715102)
# All ranges are complete, nothing to change
# {'10m_balanced_accuracy_high_frequency_stationary', 'best_high_accuracy_high_frequency_stationary', '100m_lowpwr_accuracy_high_frequency_stationary'}
# Found 10 ranges of duration [48228, 61504, 65625, 56621, 52654, 41432, 42938, 42817, 31202.739321947098, 53276.411617040634] for phone ucb-sdb-ios-1
# ---------- ucb-sdb-ios-2
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560405416, 1560405416)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560453746, 1560453746)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560463439, 1560463439)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560524970, 1560524970)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560537988, 1560537988)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560603597, 1560603597)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560665644, 1560665644)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560722276, 1560722276)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560742774, 1560742774)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560795420, 1560795420)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560804421, 1560804421)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560845846, 1560845846)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560872075, 1560872075)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560915011, 1560915011)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560923276, 1560923276)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560966090, 1560966090)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564291218.488, 1564291218.581701)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564322438.294, 1564322438.768781)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564378158.114, 1564378158.220645)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564431449.852, 1564431450.28168)
# All ranges are complete, nothing to change
# {'10m_balanced_accuracy_high_frequency_stationary', 'best_high_accuracy_high_frequency_stationary', '100m_lowpwr_accuracy_high_frequency_stationary'}
# Found 10 ranges of duration [48330, 61531, 65609, 56632, 52646, 41425, 42936, 42814, 31220.187079906464, 53292.06103515625] for phone ucb-sdb-ios-2
# ---------- ucb-sdb-ios-3
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560405472, 1560405472)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560453746, 1560453746)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560463469, 1560463469)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560525005, 1560525005)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560538007, 1560538007)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560603620, 1560603620)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560665671, 1560665671)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560722309, 1560722309)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560742794, 1560742794)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560795454, 1560795454)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560804451, 1560804451)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560845868, 1560845868)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560872093, 1560872093)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560915031, 1560915031)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560923294, 1560923294)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560966106, 1560966106)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564291230.177, 1564291230.281981)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564322475.497, 1564322476.0091171)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564378167.402, 1564378167.563998)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564431475.126, 1564431475.683368)
# All ranges are complete, nothing to change
# {'10m_balanced_accuracy_high_frequency_stationary', 'best_high_accuracy_high_frequency_stationary', '100m_lowpwr_accuracy_high_frequency_stationary'}
# Found 10 ranges of duration [48274, 61536, 65613, 56638, 52660, 41417, 42938, 42812, 31245.7271361351, 53308.11936998367] for phone ucb-sdb-ios-3
# ---------- ucb-sdb-ios-4
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560405537, 1560405537)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560453746, 1560453746)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560463497, 1560463497)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560525021, 1560525021)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560538023, 1560538023)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560603639, 1560603639)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560665697, 1560665697)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_high_frequency_stationary', 1560722338, 1560722338)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560742813, 1560742813)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560795467, 1560795467)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560804466, 1560804466)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560845881, 1560845881)
# ('START_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560872173, 1560872173)
# ('STOP_CALIBRATION_PERIOD', '10m_balanced_accuracy_high_frequency_stationary', 1560915055, 1560915055)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560923312, 1560923312)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1560966119, 1560966119)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564291244.294, 1564291244.4502602)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564322497.113, 1564322497.6183472)
# ('START_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564378178.91, 1564378179.059332)
# ('STOP_CALIBRATION_PERIOD', '100m_lowpwr_accuracy_high_frequency_stationary', 1564431490.022, 1564431490.494556)
# All ranges are complete, nothing to change
# {'10m_balanced_accuracy_high_frequency_stationary', 'best_high_accuracy_high_frequency_stationary', '100m_lowpwr_accuracy_high_frequency_stationary'}
# Found 10 ranges of duration [48209, 61524, 65616, 56641, 52654, 41415, 42882, 42807, 31253.168087005615, 53311.435224056244] for phone ucb-sdb-ios-4
# -------------------- About to fill evaluation ranges --------------------
# Processing data for android phones
# Processing transitions for phone ucb-sdb-android-1
# Filtered 106 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-2
# Filtered 86 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-3
# Filtered 86 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-4
# Filtered 86 total -> 0 calibration transitions
# Processing data for ios phones
# Processing transitions for phone ucb-sdb-ios-1
# Filtered 510 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-ios-2
# Filtered 92 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-ios-3
# Filtered 91 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-ios-4
# Filtered 88 total -> 0 calibration transitions
# Processing data for android phones
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-android-1
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-android-2
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-android-3
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-android-4
# Processing data for ios phones
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-ios-1
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-ios-2
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-ios-3
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-ios-4
# Processing data for android phones
# Processing data for ios phones
# -------------------- About to fill evaluation trips --------------------
# Processing data for android phones
# Processing data for ios phones
# Lengths (accuracy, power, eval) = (2, 2, 2)
# keys (accuracy, power, eval) = (dict_keys(['android', 'ios']), dict_keys(['android', 'ios']), dict_keys(['android', 'ios']))
# eval_phone_keys (android, ios) = (dict_keys(['ucb-sdb-android-2', 'ucb-sdb-android-3']), dict_keys(['ucb-sdb-ios-2', 'ucb-sdb-ios-3']))
# -------------------- About to fill in evaluation sections --------------------
# -------------------- About to copy trip and section ranges --------------------
# dict_keys(['ucb-sdb-android-1', 'ucb-sdb-android-2', 'ucb-sdb-android-3', 'ucb-sdb-android-4'])
# Found accuracy control, skipping copy
# dict_keys(['ucb-sdb-ios-1', 'ucb-sdb-ios-2', 'ucb-sdb-ios-3', 'ucb-sdb-ios-4'])
# Found accuracy control, skipping copy
# -------------------- About to fill in battery information --------------------
# Processing data for android phones
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1560405169, 'end_time': 1560453771}
# response = <Response [200]>
# Found 14 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1560463523, 'end_time': 1560525050}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1560538052, 'end_time': 1560603684}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1560665721, 'end_time': 1560722362}
# response = <Response [200]>
# Found 14 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1560742839, 'end_time': 1560795491}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1560804485, 'end_time': 1560845900}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1560872200, 'end_time': 1560915075}
# response = <Response [200]>
# Found 14 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1560923342, 'end_time': 1560966141}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1564291253.301, 'end_time': 1564322509.254}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1564378191.879, 'end_time': 1564431524.109}
# response = <Response [200]>
# Found 7 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1560405203, 'end_time': 1560453817}
# response = <Response [200]>
# Found 14 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1560463541, 'end_time': 1560525163}
# Got ConnectionError error ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer')), retrying
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1560538079, 'end_time': 1560603727}
# response = <Response [200]>
# Found 14 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1560665749, 'end_time': 1560722409}
# response = <Response [200]>
# Found 14 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1560742867, 'end_time': 1560795517}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1560804506, 'end_time': 1560845915}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1560872225, 'end_time': 1560915091}
# response = <Response [200]>
# Found 14 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1560923361, 'end_time': 1560966141}
# response = <Response [200]>
# Found 10 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1564291261.38, 'end_time': 1564322534.258}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1564378202.238, 'end_time': 1564431535.147}
# response = <Response [200]>
# Found 15 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1560405245, 'end_time': 1560453851}
# response = <Response [200]>
# Found 14 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1560463576, 'end_time': 1560525128}
# response = <Response [200]>
# Found 14 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1560538099, 'end_time': 1560603758}
# response = <Response [200]>
# Found 16 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1560665775, 'end_time': 1560722456}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1560742889, 'end_time': 1560795532}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1560804526, 'end_time': 1560845963}
# response = <Response [200]>
# Found 14 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1560872251, 'end_time': 1560915106}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1560923383, 'end_time': 1560966141}
# response = <Response [200]>
# Found 10 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1564291272.43, 'end_time': 1564322583.745}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1564378215.221, 'end_time': 1564431562.546}
# response = <Response [200]>
# Found 15 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1560405288, 'end_time': 1560453880}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1560463599, 'end_time': 1560525163}
# response = <Response [200]>
# Found 14 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1560538133, 'end_time': 1560603781}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1560665801, 'end_time': 1560722494}
# response = <Response [200]>
# Found 14 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1560742920, 'end_time': 1560795552}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1560804550, 'end_time': 1560845983}
# response = <Response [200]>
# Found 18 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1560872269, 'end_time': 1560915128}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1560923408, 'end_time': 1560966191}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1564291280.643, 'end_time': 1564322619.839}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1564378227.703, 'end_time': 1564431577.476}
# response = <Response [200]>
# Found 13 entries
# Processing data for ios phones
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1560405345, 'end_time': 1560453573}
# response = <Response [200]>
# Found 49 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1560463418, 'end_time': 1560524922}
# response = <Response [200]>
# Found 47 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1560537950, 'end_time': 1560603575}
# response = <Response [200]>
# Found 42 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1560665619, 'end_time': 1560722240}
# response = <Response [200]>
# Found 36 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1560742749, 'end_time': 1560795403}
# response = <Response [200]>
# Found 36 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1560804398, 'end_time': 1560845830}
# response = <Response [200]>
# Found 30 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1560872058, 'end_time': 1560914996}
# response = <Response [200]>
# Found 31 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1560923261, 'end_time': 1560966078}
# response = <Response [200]>
# Found 30 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1564291206.023632, 'end_time': 1564322408.762954}
# response = <Response [200]>
# Found 25 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1564378145.303485, 'end_time': 1564431421.715102}
# response = <Response [200]>
# Found 35 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1560405416, 'end_time': 1560453746}
# response = <Response [200]>
# Found 28 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1560463439, 'end_time': 1560524970}
# response = <Response [200]>
# Found 77 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1560537988, 'end_time': 1560603597}
# response = <Response [200]>
# Found 64 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1560665644, 'end_time': 1560722276}
# response = <Response [200]>
# Found 55 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1560742774, 'end_time': 1560795420}
# response = <Response [200]>
# Found 75 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1560804421, 'end_time': 1560845846}
# response = <Response [200]>
# Found 74 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1560872075, 'end_time': 1560915011}
# response = <Response [200]>
# Found 74 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1560923276, 'end_time': 1560966090}
# response = <Response [200]>
# Found 43 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1564291218.581701, 'end_time': 1564322438.768781}
# response = <Response [200]>
# Found 25 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1564378158.220645, 'end_time': 1564431450.28168}
# response = <Response [200]>
# Found 33 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1560405472, 'end_time': 1560453746}
# response = <Response [200]>
# Found 54 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1560463469, 'end_time': 1560525005}
# response = <Response [200]>
# Found 58 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1560538007, 'end_time': 1560603620}
# response = <Response [200]>
# Found 54 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1560665671, 'end_time': 1560722309}
# response = <Response [200]>
# Found 45 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1560742794, 'end_time': 1560795454}
# response = <Response [200]>
# Found 54 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1560804451, 'end_time': 1560845868}
# response = <Response [200]>
# Found 53 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1560872093, 'end_time': 1560915031}
# response = <Response [200]>
# Found 55 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1560923294, 'end_time': 1560966106}
# response = <Response [200]>
# Found 36 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1564291230.281981, 'end_time': 1564322476.0091171}
# response = <Response [200]>
# Found 25 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1564378167.563998, 'end_time': 1564431475.683368}
# response = <Response [200]>
# Found 31 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1560405537, 'end_time': 1560453746}
# response = <Response [200]>
# Found 48 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1560463497, 'end_time': 1560525021}
# response = <Response [200]>
# Found 58 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1560538023, 'end_time': 1560603639}
# response = <Response [200]>
# Found 54 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1560665697, 'end_time': 1560722338}
# response = <Response [200]>
# Found 44 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1560742813, 'end_time': 1560795467}
# response = <Response [200]>
# Found 52 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1560804466, 'end_time': 1560845881}
# response = <Response [200]>
# Found 52 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1560872173, 'end_time': 1560915055}
# response = <Response [200]>
# Found 53 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1560923312, 'end_time': 1560966119}
# response = <Response [200]>
# Found 36 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1564291244.4502602, 'end_time': 1564322497.6183472}
# response = <Response [200]>
# Found 25 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1564378179.059332, 'end_time': 1564431490.494556}
# response = <Response [200]>
# Found 33 entries
# Processing data for android phones
# Processing data for ios phones
# -------------------- About to fill in location information --------------------
# Processing data for android phones
# About to retrieve data for ucb-sdb-android-1 from 1560405169 -> 1560453771
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1560405169, 'end_time': 1560453771}
# response = <Response [200]>
# Found 9848 entries
# Retrieved 9848 entries with timestamps [1560405173.399, 1560405174, 1560405175, 1560405176, 1560405177, 1560405178, 1560405179, 1560405180, 1560405181, 1560405182]...
# About to retrieve data for ucb-sdb-android-1 from 1560453770.986 -> 1560453771
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1560453770.986, 'end_time': 1560453771}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1560453771]...
# About to retrieve data for ucb-sdb-android-1 from 1560405169 -> 1560453771
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/filtered_location'], 'start_time': 1560405169, 'end_time': 1560453771}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-1 from 1560463523 -> 1560525050
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1560463523, 'end_time': 1560525050}
# response = <Response [200]>
# Found 6615 entries
# Retrieved 6615 entries with timestamps [1560463525.511, 1560463529, 1560463530, 1560463531, 1560463532, 1560463533, 1560463534, 1560463535, 1560463536, 1560463537]...
# About to retrieve data for ucb-sdb-android-1 from 1560525049.807 -> 1560525050
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1560525049.807, 'end_time': 1560525050}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1560525050]...
# About to retrieve data for ucb-sdb-android-1 from 1560463523 -> 1560525050
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/filtered_location'], 'start_time': 1560463523, 'end_time': 1560525050}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-1 from 1560538052 -> 1560603684
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1560538052, 'end_time': 1560603684}
# response = <Response [200]>
# Found 6065 entries
# Retrieved 6065 entries with timestamps [1560538053.932, 1560538057, 1560538058, 1560538059, 1560538058.943, 1560538060, 1560538061, 1560538062, 1560538063, 1560538064]...
# About to retrieve data for ucb-sdb-android-1 from 1560603683.524 -> 1560603684
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1560603683.524, 'end_time': 1560603684}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1560603684]...
# About to retrieve data for ucb-sdb-android-1 from 1560538052 -> 1560603684
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/filtered_location'], 'start_time': 1560538052, 'end_time': 1560603684}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-1 from 1560665721 -> 1560722362
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1560665721, 'end_time': 1560722362}
# response = <Response [200]>
# Found 7659 entries
# Retrieved 7659 entries with timestamps [1560665722.473, 1560665726, 1560665727, 1560665727.484, 1560665728, 1560665729, 1560665730, 1560665731, 1560665732, 1560665733]...
# About to retrieve data for ucb-sdb-android-1 from 1560722361.346 -> 1560722362
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1560722361.346, 'end_time': 1560722362}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1560722361]...
# About to retrieve data for ucb-sdb-android-1 from 1560665721 -> 1560722362
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/filtered_location'], 'start_time': 1560665721, 'end_time': 1560722362}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-1 from 1560742839 -> 1560795491
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1560742839, 'end_time': 1560795491}
# response = <Response [200]>
# Found 82 entries
# Retrieved 82 entries with timestamps [1560742841.409, 1560742850.525, 1560742850.54, 1560742874.517, 1560743080.425, 1560743151.553, 1560743151.614, 1560743452.558, 1560743452.616, 1560743509.576]...
# About to retrieve data for ucb-sdb-android-1 from 1560795489.163 -> 1560795491
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1560795489.163, 'end_time': 1560795491}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1560795489.08]...
# About to retrieve data for ucb-sdb-android-1 from 1560742839 -> 1560795491
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/filtered_location'], 'start_time': 1560742839, 'end_time': 1560795491}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-1 from 1560804485 -> 1560845900
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1560804485, 'end_time': 1560845900}
# response = <Response [200]>
# Found 67 entries
# Retrieved 67 entries with timestamps [1560804486.784, 1560804498.882, 1560804498.9, 1560804519.282, 1560804760.217, 1560804799.932, 1560804800.003, 1560805100.955, 1560805101.04, 1560805147.09]...
# About to retrieve data for ucb-sdb-android-1 from 1560845896.013 -> 1560845900
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1560845896.013, 'end_time': 1560845900}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1560845895.902]...
# About to retrieve data for ucb-sdb-android-1 from 1560804485 -> 1560845900
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/filtered_location'], 'start_time': 1560804485, 'end_time': 1560845900}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-1 from 1560872200 -> 1560915075
# ...
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1560463576, 'end_time': 1560525128}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1560538099, 'end_time': 1560603758}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1560665775, 'end_time': 1560722456}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1560742889, 'end_time': 1560795532}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1560804526, 'end_time': 1560845963}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1560872251, 'end_time': 1560915106}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1560923383, 'end_time': 1560966141}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1564291272.43, 'end_time': 1564322583.745}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1564378215.221, 'end_time': 1564431562.546}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1560405288, 'end_time': 1560453880}
# response = <Response [200]>
# Found 2 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1560463599, 'end_time': 1560525163}
# response = <Response [200]>
# Found 2 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1560538133, 'end_time': 1560603781}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1560665801, 'end_time': 1560722494}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1560742920, 'end_time': 1560795552}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1560804550, 'end_time': 1560845983}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1560872269, 'end_time': 1560915128}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1560923408, 'end_time': 1560966191}
# response = <Response [200]>
# Found 2 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1564291280.643, 'end_time': 1564322619.839}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1564378227.703, 'end_time': 1564431577.476}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# Processing data for ios phones
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1560405345, 'end_time': 1560453573}
# response = <Response [200]>
# Found 42 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1560463418, 'end_time': 1560524922}
# response = <Response [200]>
# Found 44 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1560537950, 'end_time': 1560603575}
# response = <Response [200]>
# Found 41 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1560665619, 'end_time': 1560722240}
# response = <Response [200]>
# Found 35 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1560742749, 'end_time': 1560795403}
# response = <Response [200]>
# Found 35 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1560804398, 'end_time': 1560845830}
# response = <Response [200]>
# Found 29 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1560872058, 'end_time': 1560914996}
# response = <Response [200]>
# Found 29 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1560923261, 'end_time': 1560966078}
# response = <Response [200]>
# Found 29 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1564291206.023632, 'end_time': 1564322408.762954}
# response = <Response [200]>
# Found 23 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1564378145.303485, 'end_time': 1564431421.715102}
# response = <Response [200]>
# Found 33 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1560405416, 'end_time': 1560453746}
# response = <Response [200]>
# Found 24 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1560463439, 'end_time': 1560524970}
# response = <Response [200]>
# Found 70 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1560537988, 'end_time': 1560603597}
# response = <Response [200]>
# Found 57 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1560665644, 'end_time': 1560722276}
# response = <Response [200]>
# Found 47 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1560742774, 'end_time': 1560795420}
# response = <Response [200]>
# Found 64 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1560804421, 'end_time': 1560845846}
# response = <Response [200]>
# Found 59 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1560872075, 'end_time': 1560915011}
# response = <Response [200]>
# Found 61 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1560923276, 'end_time': 1560966090}
# response = <Response [200]>
# Found 38 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1564291218.581701, 'end_time': 1564322438.768781}
# response = <Response [200]>
# Found 23 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1564378158.220645, 'end_time': 1564431450.28168}
# response = <Response [200]>
# Found 31 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1560405472, 'end_time': 1560453746}
# response = <Response [200]>
# Found 47 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1560463469, 'end_time': 1560525005}
# response = <Response [200]>
# Found 54 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1560538007, 'end_time': 1560603620}
# response = <Response [200]>
# Found 48 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1560665671, 'end_time': 1560722309}
# response = <Response [200]>
# Found 40 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1560742794, 'end_time': 1560795454}
# response = <Response [200]>
# Found 47 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1560804451, 'end_time': 1560845868}
# response = <Response [200]>
# Found 42 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1560872093, 'end_time': 1560915031}
# response = <Response [200]>
# Found 42 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1560923294, 'end_time': 1560966106}
# response = <Response [200]>
# Found 32 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1564291230.281981, 'end_time': 1564322476.0091171}
# response = <Response [200]>
# Found 23 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1564378167.563998, 'end_time': 1564431475.683368}
# response = <Response [200]>
# Found 29 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1560405537, 'end_time': 1560453746}
# response = <Response [200]>
# Found 41 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1560463497, 'end_time': 1560525021}
# response = <Response [200]>
# Found 53 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1560538023, 'end_time': 1560603639}
# response = <Response [200]>
# Found 49 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1560665697, 'end_time': 1560722338}
# response = <Response [200]>
# Found 39 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1560742813, 'end_time': 1560795467}
# response = <Response [200]>
# Found 44 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1560804466, 'end_time': 1560845881}
# response = <Response [200]>
# Found 40 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1560872173, 'end_time': 1560915055}
# response = <Response [200]>
# Found 45 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1560923312, 'end_time': 1560966119}
# response = <Response [200]>
# Found 32 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1564291244.4502602, 'end_time': 1564322497.6183472}
# response = <Response [200]>
# Found 23 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1564378179.059332, 'end_time': 1564431490.494556}
# response = <Response [200]>
# Found 31 entries
# transition has not been processed, creating ts -> fmt_time
# Processing data for android phones
# Processing data for ios phones
# -------------------- About to select trip specific ranges --------------------
# Filling label ucb-sdb-android-1 for OS android
# Filling label ucb-sdb-android-2 for OS android
# Filling label ucb-sdb-android-3 for OS android
# Filling label ucb-sdb-android-4 for OS android
# Filling label ucb-sdb-ios-1 for OS ios
# Filling label ucb-sdb-ios-2 for OS ios
# Filling label ucb-sdb-ios-3 for OS ios
# Filling label ucb-sdb-ios-4 for OS ios
# -------------------- Done populating information from server --------------------

# %%
pv_mf = eipv.PhoneView(sd_mf)
# Out:
# -------------------- About to read transitions from server --------------------
# Reading data for android phones
# Loading transitions for phone ucb-sdb-android-1
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563433200, 'end_time': 1569826800}
# response = <Response [200]>
# Found 70 entries
# Loading transitions for phone ucb-sdb-android-2
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563433200, 'end_time': 1569826800}
# response = <Response [200]>
# Found 58 entries
# Loading transitions for phone ucb-sdb-android-3
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563433200, 'end_time': 1569826800}
# response = <Response [200]>
# Found 58 entries
# Loading transitions for phone ucb-sdb-android-4
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563433200, 'end_time': 1569826800}
# response = <Response [200]>
# Found 58 entries
# Reading data for ios phones
# Loading transitions for phone ucb-sdb-ios-1
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563433200, 'end_time': 1569826800}
# response = <Response [200]>
# Found 472 entries
# Loading transitions for phone ucb-sdb-ios-2
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563433200, 'end_time': 1569826800}
# response = <Response [200]>
# Found 60 entries
# Loading transitions for phone ucb-sdb-ios-3
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563433200, 'end_time': 1569826800}
# response = <Response [200]>
# Found 58 entries
# Loading transitions for phone ucb-sdb-ios-4
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563433200, 'end_time': 1569826800}
# response = <Response [200]>
# Found 58 entries
# -------------------- About to fill calibration ranges --------------------
# Processing data for android phones
# Processing transitions for phone ucb-sdb-android-1
# Filtered 70 total -> 16 calibration transitions
# Processing transitions for phone ucb-sdb-android-2
# Filtered 58 total -> 16 calibration transitions
# Processing transitions for phone ucb-sdb-android-3
# Filtered 58 total -> 16 calibration transitions
# Processing transitions for phone ucb-sdb-android-4
# Filtered 58 total -> 16 calibration transitions
# Processing data for ios phones
# Processing transitions for phone ucb-sdb-ios-1
# Filtered 472 total -> 16 calibration transitions
# Processing transitions for phone ucb-sdb-ios-2
# Filtered 60 total -> 16 calibration transitions
# Processing transitions for phone ucb-sdb-ios-3
# Filtered 58 total -> 16 calibration transitions
# Processing transitions for phone ucb-sdb-ios-4
# Filtered 58 total -> 16 calibration transitions
# Processing data for android phones
# ---------- ucb-sdb-android-1
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563764613.22, 1563764613.222)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563788085.722, 1563788085.749)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563863231.363, 1563863231.367)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563890199.422, 1563890199.48)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563944815.917, 1563944815.921)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563973553.011, 1563973553.057)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564443134.949, 1564443134.955)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564468618.107, 1564468618.167)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564474170.236, 1564474170.237)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564515390.883, 1564515390.942)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564550647.97, 1564550647.975)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564577871.587, 1564577871.628)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565459507.692, 1565459507.694)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565497156.397, 1565497156.436)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566326171.84, 1566326171.842)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566365176.254, 1566365176.313)
# All ranges are complete, nothing to change
# {'100m_balanced_accuracy_medium_freq_stationary', 'best_high_accuracy_medium_freq_stationary'}
# Found 8 ranges of duration [23472.527000188828, 26968.112999916077, 28737.135999917984, 25483.212000131607, 41220.704999923706, 27223.65300011635, 37648.742000103, 39004.47099995613] for phone ucb-sdb-android-1
# ---------- ucb-sdb-android-2
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563764643.839, 1563764643.841)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563788093.839, 1563788093.89)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563863242.739, 1563863242.745)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563890205.11, 1563890205.16)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563944837.095, 1563944837.097)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563973569.127, 1563973569.17)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564443147.663, 1564443147.669)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564468645.947, 1564468646.02)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564474182.089, 1564474182.091)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564515413.142, 1564515413.202)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564550657.979, 1564550657.986)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564577879.486, 1564577879.533)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565459518.79, 1565459518.792)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565497182.485, 1565497182.525)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566326188.775, 1566326188.776)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566365199.666, 1566365199.723)
# All ranges are complete, nothing to change
# {'100m_balanced_accuracy_medium_freq_stationary', 'best_high_accuracy_medium_freq_stationary'}
# Found 8 ranges of duration [23450.049000024796, 26962.41500020027, 28732.073000192642, 25498.351000070572, 41231.11099982262, 27221.546999931335, 37663.733000040054, 39010.9470000267] for phone ucb-sdb-android-2
# ---------- ucb-sdb-android-3
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563764686.3, 1563764686.301)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563788105.529, 1563788105.544)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563863272.654, 1563863272.656)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563890214.712, 1563890214.77)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563944862.978, 1563944862.98)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563973599.101, 1563973599.147)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564443166.382, 1564443166.388)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564468671.373, 1564468671.403)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564474191.645, 1564474191.646)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564515433.559, 1564515433.591)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564550670.61, 1564550670.614)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564577887.971, 1564577888.013)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565459530.103, 1565459530.106)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565497200.792, 1565497200.84)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566326206.041, 1566326206.045)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566365226.001, 1566365226.053)
# All ranges are complete, nothing to change
# {'100m_balanced_accuracy_medium_freq_stationary', 'best_high_accuracy_medium_freq_stationary'}
# Found 8 ranges of duration [23419.2429997921, 26942.114000082016, 28736.167000055313, 25505.015000104904, 41241.94500017166, 27217.398999929428, 37670.733999967575, 39020.007999897] for phone ucb-sdb-android-3
# ---------- ucb-sdb-android-4
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563764729.725, 1563764729.726)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563788112.947, 1563788112.969)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563863286.924, 1563863286.928)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563890220.941, 1563890220.992)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563944882.312, 1563944882.313)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563973623.388, 1563973623.433)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564443181.441, 1564443181.446)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564468681.774, 1564468681.838)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564474204.114, 1564474204.118)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564515446.692, 1564515446.726)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564550690.071, 1564550690.075)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564577897.858, 1564577897.905)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565459546.895, 1565459546.897)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565497217.456, 1565497217.501)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566326223.28, 1566326223.286)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566365244.668, 1566365244.737)
# All ranges are complete, nothing to change
# {'100m_balanced_accuracy_medium_freq_stationary', 'best_high_accuracy_medium_freq_stationary'}
# Found 8 ranges of duration [23383.243000030518, 26934.0640001297, 28741.120000123978, 25500.391999959946, 41242.608000040054, 27207.829999923706, 37670.603999853134, 39021.450999975204] for phone ucb-sdb-android-4
# Processing data for ios phones
# ---------- ucb-sdb-ios-1
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563764431.854, 1563764432.001042)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563788038.663, 1563788038.733817)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563863188.466, 1563863188.598661)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563890157.577, 1563890158.048438)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563944726.821, 1563944726.909893)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563973422.83, 1563973423.3017302)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564443051.023, 1564443051.118357)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564468553.417, 1564468553.824141)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564474123.768, 1564474123.936163)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564515316.893, 1564515317.5011601)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564550585.037, 1564550585.184926)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564577823.36, 1564577823.817019)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565459444.937, 1565459445.018568)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565497082.314, 1565497082.7905369)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566326069.276, 1566326069.359354)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566365107.943, 1566365108.456779)
# All ranges are complete, nothing to change
# {'100m_balanced_accuracy_medium_freq_stationary', 'best_high_accuracy_medium_freq_stationary'}
# Found 8 ranges of duration [23606.732775211334, 26969.449777126312, 28696.391837120056, 25502.705784082413, 41193.5649971962, 27238.63209295273, 37637.77196884155, 39039.09742498398] for phone ucb-sdb-ios-1
# ---------- ucb-sdb-ios-2
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563764493.88, 1563764493.97196)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563788050.809, 1563788050.872571)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563863200.198, 1563863200.2893429)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563890167.144, 1563890167.611793)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563944748.355, 1563944748.4612122)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563973443.111, 1563973443.5124102)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564443070.814, 1564443070.914775)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564468569.815, 1564468570.2842422)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564474133.01, 1564474133.11743)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564515335.99, 1564515336.478229)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564550599.623, 1564550599.708209)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564577837.327, 1564577837.754926)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565459463.527, 1565459463.64622)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565497103.379, 1565497103.782407)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566326095.854, 1566326095.941084)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566365122.719, 1566365123.160764)
# All ranges are complete, nothing to change
# {'100m_balanced_accuracy_medium_freq_stationary', 'best_high_accuracy_medium_freq_stationary'}
# Found 8 ranges of duration [23556.900610923767, 26967.32245016098, 28695.051198005676, 25499.369467258453, 41203.36079907417, 27238.046716928482, 37640.13618707657, 39027.21968007088] for phone ucb-sdb-ios-2
# ---------- ucb-sdb-ios-3
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563764533.076, 1563764533.214622)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563788061.933, 1563788061.999584)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563863210.89, 1563863211.0520248)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563890177.684, 1563890178.148947)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563944770.573, 1563944770.673845)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563973483.636, 1563973484.065419)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564443090.185, 1564443090.27934)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564468588.937, 1564468589.342068)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564474143.542, 1564474143.693054)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564515362.049, 1564515362.49302)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564550612.396, 1564550613.085412)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564577847.659, 1564577848.093852)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565459478.469, 1565459478.577074)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565497122.785, 1565497123.246423)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566326117.62, 1566326117.702869)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566365139.516, 1566365139.9554238)
# All ranges are complete, nothing to change
# {'100m_balanced_accuracy_medium_freq_stationary', 'best_high_accuracy_medium_freq_stationary'}
# Found 8 ranges of duration [23528.784961938858, 26967.096922159195, 28713.391573905945, 25499.06272792816, 41218.79996609688, 27235.0084400177, 37644.669348955154, 39022.252554893494] for phone ucb-sdb-ios-3
# ---------- ucb-sdb-ios-4
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563764579.569, 1563764579.704987)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1563788072.553, 1563788072.625461)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563863221.315, 1563863221.463701)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563890191.622, 1563890192.1354408)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563944788.843, 1563944788.946683)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1563973523.655, 1563973524.094161)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564443113.888, 1564443113.994324)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1564468604.798, 1564468605.239407)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564474155.761, 1564474155.932115)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564515377.469, 1564515377.928055)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564550627.559, 1564550627.6688051)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1564577862.896, 1564577863.398086)
# ('START_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565459490.057, 1565459490.136774)
# ('STOP_CALIBRATION_PERIOD', 'best_high_accuracy_medium_freq_stationary', 1565497134.495, 1565497135.015895)
# ('START_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566326146.447, 1566326146.542737)
# ('STOP_CALIBRATION_PERIOD', '100m_balanced_accuracy_medium_freq_stationary', 1566365158.309, 1566365158.8372478)
# All ranges are complete, nothing to change
# {'100m_balanced_accuracy_medium_freq_stationary', 'best_high_accuracy_medium_freq_stationary'}
# Found 8 ranges of duration [23492.92047405243, 26970.671739816666, 28735.147478103638, 25491.245083093643, 41221.99593997002, 27235.72928094864, 37644.87912082672, 39012.29451084137] for phone ucb-sdb-ios-4
# -------------------- About to fill evaluation ranges --------------------
# Processing data for android phones
# Processing transitions for phone ucb-sdb-android-1
# Filtered 70 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-2
# Filtered 58 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-3
# Filtered 58 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-4
# Filtered 58 total -> 0 calibration transitions
# Processing data for ios phones
# Processing transitions for phone ucb-sdb-ios-1
# Filtered 472 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-ios-2
# Filtered 60 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-ios-3
# Filtered 58 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-ios-4
# Filtered 58 total -> 0 calibration transitions
# Processing data for android phones
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-android-1
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-android-2
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-android-3
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-android-4
# Processing data for ios phones
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-ios-1
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-ios-2
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-ios-3
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-ios-4
# Processing data for android phones
# Processing data for ios phones
# -------------------- About to fill evaluation trips --------------------
# Processing data for android phones
# Processing data for ios phones
# Lengths (accuracy, power, eval) = (2, 2, 2)
# keys (accuracy, power, eval) = (dict_keys(['android', 'ios']), dict_keys(['android', 'ios']), dict_keys(['android', 'ios']))
# eval_phone_keys (android, ios) = (dict_keys(['ucb-sdb-android-2', 'ucb-sdb-android-3']), dict_keys(['ucb-sdb-ios-2', 'ucb-sdb-ios-3']))
# -------------------- About to fill in evaluation sections --------------------
# -------------------- About to copy trip and section ranges --------------------
# dict_keys(['ucb-sdb-android-1', 'ucb-sdb-android-2', 'ucb-sdb-android-3', 'ucb-sdb-android-4'])
# Found accuracy control, skipping copy
# dict_keys(['ucb-sdb-ios-1', 'ucb-sdb-ios-2', 'ucb-sdb-ios-3', 'ucb-sdb-ios-4'])
# Found accuracy control, skipping copy
# -------------------- About to fill in battery information --------------------
# Processing data for android phones
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1563764613.222, 'end_time': 1563788085.749}
# response = <Response [200]>
# Found 10 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1563863231.367, 'end_time': 1563890199.48}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1563944815.921, 'end_time': 1563973553.057}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1564443134.955, 'end_time': 1564468618.167}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1564474170.237, 'end_time': 1564515390.942}
# response = <Response [200]>
# Found 15 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1564550647.975, 'end_time': 1564577871.628}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1565459507.694, 'end_time': 1565497156.436}
# response = <Response [200]>
# Found 10 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1566326171.842, 'end_time': 1566365176.313}
# response = <Response [200]>
# Found 15 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1563764643.841, 'end_time': 1563788093.89}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1563863242.745, 'end_time': 1563890205.16}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1563944837.097, 'end_time': 1563973569.17}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1564443147.669, 'end_time': 1564468646.02}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1564474182.091, 'end_time': 1564515413.202}
# response = <Response [200]>
# Found 17 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1564550657.986, 'end_time': 1564577879.533}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1565459518.792, 'end_time': 1565497182.525}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1566326188.776, 'end_time': 1566365199.723}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1563764686.301, 'end_time': 1563788105.544}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1563863272.656, 'end_time': 1563890214.77}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1563944862.98, 'end_time': 1563973599.147}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1564443166.388, 'end_time': 1564468671.403}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1564474191.646, 'end_time': 1564515433.591}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1564550670.614, 'end_time': 1564577888.013}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1565459530.106, 'end_time': 1565497200.84}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1566326206.045, 'end_time': 1566365226.053}
# response = <Response [200]>
# Found 9 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1563764729.726, 'end_time': 1563788112.969}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1563863286.928, 'end_time': 1563890220.992}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1563944882.313, 'end_time': 1563973623.433}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1564443181.446, 'end_time': 1564468681.838}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1564474204.118, 'end_time': 1564515446.726}
# response = <Response [200]>
# Found 17 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1564550690.075, 'end_time': 1564577897.905}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1565459546.897, 'end_time': 1565497217.501}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1566326223.286, 'end_time': 1566365244.737}
# response = <Response [200]>
# Found 13 entries
# Processing data for ios phones
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1563764432.001042, 'end_time': 1563788038.733817}
# response = <Response [200]>
# Found 17 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1563863188.598661, 'end_time': 1563890158.048438}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1563944726.909893, 'end_time': 1563973423.3017302}
# response = <Response [200]>
# Found 23 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1564443051.118357, 'end_time': 1564468553.824141}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1564474123.936163, 'end_time': 1564515317.5011601}
# response = <Response [200]>
# Found 29 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1564550585.184926, 'end_time': 1564577823.817019}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1565459445.018568, 'end_time': 1565497082.7905369}
# response = <Response [200]>
# Found 29 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1566326069.359354, 'end_time': 1566365108.456779}
# response = <Response [200]>
# Found 29 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1563764493.97196, 'end_time': 1563788050.872571}
# response = <Response [200]>
# Found 17 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1563863200.2893429, 'end_time': 1563890167.611793}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1563944748.4612122, 'end_time': 1563973443.5124102}
# response = <Response [200]>
# Found 23 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1564443070.914775, 'end_time': 1564468570.2842422}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1564474133.11743, 'end_time': 1564515336.478229}
# response = <Response [200]>
# Found 29 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1564550599.708209, 'end_time': 1564577837.754926}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1565459463.64622, 'end_time': 1565497103.782407}
# response = <Response [200]>
# Found 29 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1566326095.941084, 'end_time': 1566365123.160764}
# response = <Response [200]>
# Found 32 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1563764533.214622, 'end_time': 1563788061.999584}
# response = <Response [200]>
# Found 17 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1563863211.0520248, 'end_time': 1563890178.148947}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1563944770.673845, 'end_time': 1563973484.065419}
# response = <Response [200]>
# Found 23 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1564443090.27934, 'end_time': 1564468589.342068}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1564474143.693054, 'end_time': 1564515362.49302}
# response = <Response [200]>
# Found 29 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1564550613.085412, 'end_time': 1564577848.093852}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1565459478.577074, 'end_time': 1565497123.246423}
# response = <Response [200]>
# Found 29 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1566326117.702869, 'end_time': 1566365139.9554238}
# response = <Response [200]>
# Found 29 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1563764579.704987, 'end_time': 1563788072.625461}
# response = <Response [200]>
# Found 17 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1563863221.463701, 'end_time': 1563890192.1354408}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1563944788.946683, 'end_time': 1563973524.094161}
# response = <Response [200]>
# Found 23 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1564443113.994324, 'end_time': 1564468605.239407}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1564474155.932115, 'end_time': 1564515377.928055}
# response = <Response [200]>
# Found 29 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1564550627.6688051, 'end_time': 1564577863.398086}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1565459490.136774, 'end_time': 1565497135.015895}
# response = <Response [200]>
# Found 29 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1566326146.542737, 'end_time': 1566365158.8372478}
# response = <Response [200]>
# Found 29 entries
# Processing data for android phones
# Processing data for ios phones
# -------------------- About to fill in location information --------------------
# Processing data for android phones
# About to retrieve data for ucb-sdb-android-1 from 1563764613.222 -> 1563788085.749
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563764613.222, 'end_time': 1563788085.749}
# response = <Response [200]>
# Found 168 entries
# Retrieved 168 entries with timestamps [1563764613.606, 1563764644.291, 1563764674.987, 1563764705.957, 1563764736.179, 1563764766, 1563764796, 1563764825.861, 1563764855.919, 1563764886]...
# About to retrieve data for ucb-sdb-android-1 from 1563788084.699 -> 1563788085.749
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563788084.699, 'end_time': 1563788085.749}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563788084]...
# About to retrieve data for ucb-sdb-android-1 from 1563764613.222 -> 1563788085.749
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/filtered_location'], 'start_time': 1563764613.222, 'end_time': 1563788085.749}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-1 from 1563863231.367 -> 1563890199.48
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563863231.367, 'end_time': 1563890199.48}
# response = <Response [200]>
# Found 47 entries
# Retrieved 47 entries with timestamps [1563863232.6, 1563863346.246, 1563863401.187, 1563863537.206, 1563863648.247, 1563863949.236, 1563864068.216, 1563864250.291, 1563864518.245, 1563864551.187]...
# About to retrieve data for ucb-sdb-android-1 from 1563890196.991 -> 1563890199.48
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563890196.991, 'end_time': 1563890199.48}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563890196.885]...
# About to retrieve data for ucb-sdb-android-1 from 1563863231.367 -> 1563890199.48
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/filtered_location'], 'start_time': 1563863231.367, 'end_time': 1563890199.48}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-1 from 1563944815.921 -> 1563973553.057
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563944815.921, 'end_time': 1563973553.057}
# response = <Response [200]>
# Found 33 entries
# Retrieved 33 entries with timestamps [1563944816.22, 1563944861.652, 1563944934.133, 1563945032.645, 1563945117.603, 1563945418.65, 1563945718.715, 1563945775.632, 1563946018.824, 1563946320.353]...
# About to retrieve data for ucb-sdb-android-1 from 1563973528.835 -> 1563973553.057
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563973528.835, 'end_time': 1563973553.057}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563973528.77]...
# About to retrieve data for ucb-sdb-android-1 from 1563944815.921 -> 1563973553.057
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/filtered_location'], 'start_time': 1563944815.921, 'end_time': 1563973553.057}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-1 from 1564443134.955 -> 1564468618.167
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1564443134.955, 'end_time': 1564468618.167}
# response = <Response [200]>
# Found 32 entries
# Retrieved 32 entries with timestamps [1564443136.218, 1564443283.212, 1564443437.233, 1564443668.177, 1564443738.205, 1564443835.234, 1564444039.225, 1564444122.229, 1564444340.267, 1564444387.182]...
# About to retrieve data for ucb-sdb-android-1 from 1564468615.268 -> 1564468618.167
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1564468615.268, 'end_time': 1564468618.167}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1564468615.211]...
# About to retrieve data for ucb-sdb-android-1 from 1564443134.955 -> 1564468618.167
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/filtered_location'], 'start_time': 1564443134.955, 'end_time': 1564468618.167}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-1 from 1564474170.237 -> 1564515390.942
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1564474170.237, 'end_time': 1564515390.942}
# response = <Response [200]>
# Found 399 entries
# Retrieved 399 entries with timestamps [1564474171.46, 1564474203.494, 1564474236, 1564474267, 1564474293.644, 1564474326, 1564474357, 1564474387, 1564474416, 1564474448]...
# About to retrieve data for ucb-sdb-android-1 from 1564515388.535 -> 1564515390.942
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1564515388.535, 'end_time': 1564515390.942}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1564515388.436]...
# About to retrieve data for ucb-sdb-android-1 from 1564474170.237 -> 1564515390.942
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/filtered_location'], 'start_time': 1564474170.237, 'end_time': 1564515390.942}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-1 from 1564550647.975 -> 1564577871.628
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1564550647.975, 'end_time': 1564577871.628}
# response = <Response [200]>
# Found 169 entries
# Retrieved 169 entries with timestamps [1564550649.236, 1564550679.39, 1564550710.73, 1564550740.757, 1564550771.521, 1564550804, 1564550834, 1564550861.937, 1564550894, 1564550923]...
# About to retrieve data for ucb-sdb-android-1 from 1564577868.062 -> 1564577871.628
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1564577868.062, 'end_time': 1564577871.628}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1564577868.014]...
# About to retrieve data for ucb-sdb-android-1 from 1564550647.975 -> 1564577871.628
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/filtered_location'], 'start_time': 1564550647.975, 'end_time': 1564577871.628}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-1 from 1565459507.694 -> 1565497156.436
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1565459507.694, 'end_time': 1565497156.436}
# response = <Response [200]>
# Found 242 entries
# Retrieved 242 entries with timestamps [1565459507.917, 1565459520, 1565459539.64, 1565459555, 1565459569.677, 1565459584, 1565459599.708, 1565459610, 1565459630.453, 1565459660.702]...
# About to retrieve data for ucb-sdb-android-1 from 1565497154.127 -> 1565497156.436
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1565497154.127, 'end_time': 1565497156.436}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1565497154.048]...
# About to retrieve data for ucb-sdb-android-1 from 1565459507.694 -> 1565497156.436
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/filtered_location'], 'start_time': 1565459507.694, 'end_time': 1565497156.436}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-1 from 1566326171.842 -> 1566365176.313
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1566326171.842, 'end_time': 1566365176.313}
# response = <Response [200]>
# Found 76 entries
# Retrieved 76 entries with timestamps [1566326172.11, 1566326339.682, 1566326464.653, 1566326764.711, 1566327065.649, 1566327180.691, 1566327366.732, 1566327668.545, 1566327758.627, 1566327976.621]...
# About to retrieve data for ucb-sdb-android-1 from 1566365173.355 -> 1566365176.313
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1566365173.355, 'end_time': 1566365176.313}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1566365173.248]...
# About to retrieve data for ucb-sdb-android-1 from 1566326171.842 -> 1566365176.313
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/filtered_location'], 'start_time': 1566326171.842, 'end_time': 1566365176.313}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-2 from 1563764643.841 -> 1563788093.89
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563764643.841, 'end_time': 1563788093.89}
# response = <Response [200]>
# Found 169 entries
# Retrieved 169 entries with timestamps [1563764645.1, 1563764679, 1563764710, 1563764739, 1563764766.674, 1563764797.422, 1563764827.862, 1563764859, 1563764889, 1563764919]...
# About to retrieve data for ucb-sdb-android-2 from 1563788091.076 -> 1563788093.89
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563788091.076, 'end_time': 1563788093.89}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563788090.985]...
# About to retrieve data for ucb-sdb-android-2 from 1563764643.841 -> 1563788093.89
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/filtered_location'], 'start_time': 1563764643.841, 'end_time': 1563788093.89}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-2 from 1563863242.745 -> 1563890205.16
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563863242.745, 'end_time': 1563890205.16}
# response = <Response [200]>
# Found 64 entries
# Retrieved 64 entries with timestamps [1563863243.22, 1563863309.956, 1563863401.912, 1563863545.365, 1563863846, 1563864126.918, 1563864147, 1563864446, 1563864651.912, 1563864746]...
# About to retrieve data for ucb-sdb-android-2 from 1563890192.119 -> 1563890205.16
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563890192.119, 'end_time': 1563890205.16}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563890192.029]...
# About to retrieve data for ucb-sdb-android-2 from 1563863242.745 -> 1563890205.16
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/filtered_location'], 'start_time': 1563863242.745, 'end_time': 1563890205.16}
# response = <Response [200]>
# Found 0 entries
# Retrieved 0 entries with timestamps []...
# About to retrieve data for ucb-sdb-android-2 from 1563944837.097 -> 1563973569.17
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563944837.097, 'end_time': 1563973569.17}
# response = <Response [200]>
# Found 38 entries
# Retrieved 38 entries with timestamps [1563944837.348, 1563945073.492, 1563945139.147, 1563945441.294, 1563945524.375, 1563945741.369, 1563946042.384, 1563946245.313, 1563946343.303, 1563946644.32]...
# ...
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['statemachine/transition'], 'start_time': 1566326171.842, 'end_time': 1566365176.313}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1563764643.841, 'end_time': 1563788093.89}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1563863242.745, 'end_time': 1563890205.16}
# response = <Response [200]>
# Found 2 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1563944837.097, 'end_time': 1563973569.17}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1564443147.669, 'end_time': 1564468646.02}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1564474182.091, 'end_time': 1564515413.202}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1564550657.986, 'end_time': 1564577879.533}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1565459518.792, 'end_time': 1565497182.525}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1566326188.776, 'end_time': 1566365199.723}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1563764686.301, 'end_time': 1563788105.544}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1563863272.656, 'end_time': 1563890214.77}
# response = <Response [200]>
# Found 2 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1563944862.98, 'end_time': 1563973599.147}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1564443166.388, 'end_time': 1564468671.403}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1564474191.646, 'end_time': 1564515433.591}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1564550670.614, 'end_time': 1564577888.013}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1565459530.106, 'end_time': 1565497200.84}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1566326206.045, 'end_time': 1566365226.053}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1563764729.726, 'end_time': 1563788112.969}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1563863286.928, 'end_time': 1563890220.992}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1563944882.313, 'end_time': 1563973623.433}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1564443181.446, 'end_time': 1564468681.838}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1564474204.118, 'end_time': 1564515446.726}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1564550690.075, 'end_time': 1564577897.905}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1565459546.897, 'end_time': 1565497217.501}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1566326223.286, 'end_time': 1566365244.737}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# Processing data for ios phones
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1563764432.001042, 'end_time': 1563788038.733817}
# response = <Response [200]>
# Found 15 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1563863188.598661, 'end_time': 1563890158.048438}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1563944726.909893, 'end_time': 1563973423.3017302}
# response = <Response [200]>
# Found 21 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1564443051.118357, 'end_time': 1564468553.824141}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1564474123.936163, 'end_time': 1564515317.5011601}
# response = <Response [200]>
# Found 27 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1564550585.184926, 'end_time': 1564577823.817019}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1565459445.018568, 'end_time': 1565497082.7905369}
# response = <Response [200]>
# Found 27 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1566326069.359354, 'end_time': 1566365108.456779}
# response = <Response [200]>
# Found 27 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1563764493.97196, 'end_time': 1563788050.872571}
# response = <Response [200]>
# Found 15 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1563863200.2893429, 'end_time': 1563890167.611793}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1563944748.4612122, 'end_time': 1563973443.5124102}
# response = <Response [200]>
# Found 21 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1564443070.914775, 'end_time': 1564468570.2842422}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1564474133.11743, 'end_time': 1564515336.478229}
# response = <Response [200]>
# Found 27 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1564550599.708209, 'end_time': 1564577837.754926}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1565459463.64622, 'end_time': 1565497103.782407}
# response = <Response [200]>
# Found 27 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1566326095.941084, 'end_time': 1566365123.160764}
# response = <Response [200]>
# Found 30 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1563764533.214622, 'end_time': 1563788061.999584}
# response = <Response [200]>
# Found 15 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1563863211.0520248, 'end_time': 1563890178.148947}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1563944770.673845, 'end_time': 1563973484.065419}
# response = <Response [200]>
# Found 21 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1564443090.27934, 'end_time': 1564468589.342068}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1564474143.693054, 'end_time': 1564515362.49302}
# response = <Response [200]>
# Found 27 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1564550613.085412, 'end_time': 1564577848.093852}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1565459478.577074, 'end_time': 1565497123.246423}
# response = <Response [200]>
# Found 27 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1566326117.702869, 'end_time': 1566365139.9554238}
# response = <Response [200]>
# Found 27 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1563764579.704987, 'end_time': 1563788072.625461}
# response = <Response [200]>
# Found 15 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1563863221.463701, 'end_time': 1563890192.1354408}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1563944788.946683, 'end_time': 1563973524.094161}
# response = <Response [200]>
# Found 21 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1564443113.994324, 'end_time': 1564468605.239407}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1564474155.932115, 'end_time': 1564515377.928055}
# response = <Response [200]>
# Found 27 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1564550627.6688051, 'end_time': 1564577863.398086}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1565459490.136774, 'end_time': 1565497135.015895}
# response = <Response [200]>
# Found 27 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1566326146.542737, 'end_time': 1566365158.8372478}
# response = <Response [200]>
# Found 27 entries
# transition has not been processed, creating ts -> fmt_time
# Processing data for android phones
# Processing data for ios phones
# -------------------- About to select trip specific ranges --------------------
# Filling label ucb-sdb-android-1 for OS android
# Filling label ucb-sdb-android-2 for OS android
# Filling label ucb-sdb-android-3 for OS android
# Filling label ucb-sdb-android-4 for OS android
# Filling label ucb-sdb-ios-1 for OS ios
# Filling label ucb-sdb-ios-2 for OS ios
# Filling label ucb-sdb-ios-3 for OS ios
# Filling label ucb-sdb-ios-4 for OS ios
# -------------------- Done populating information from server --------------------

# %%
import importlib
importlib.reload(ezpv)
# Out:
# <module 'emeval.viz.phone_view' from '/Users/shankari/e-mission/e-mission-eval-public-data/emeval/viz/phone_view.py'>

# %% [markdown]
# This validation fails because we forgot to multiply the filter_time by 1000 before setting it.
# So we set the value to 1 ms when we meant to set it to 1 sec.
# This is not a super bad issue since:
# - it only affects android
# - due to built-in throttling the data is actually returned only at 1sec frequency or even less anyway
# - we don't use this to model anything else, we just use it to help choose regimes for further testing, and for checking that the drain is consistent
#
# We had fixed this bug before the medium frequency collection (phew!) so that does validate properly

# %%
# pv_hf.validate()
pv_mf.validate()
# Out:
# -------------------- About to validate calibration settings --------------------
# Processing data for android phones
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['config/sensor_config'], 'start_time': 1563764613.222, 'end_time': 1563788085.749}
# response = <Response [200]>
# Found 1 entries
# best_high_accuracy_medium_freq_stationary_0 -> [100]
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['config/sensor_config'], 'start_time': 1563863231.367, 'end_time': 1563890199.48}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_0 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['config/sensor_config'], 'start_time': 1563944815.921, 'end_time': 1563973553.057}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_1 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['config/sensor_config'], 'start_time': 1564443134.955, 'end_time': 1564468618.167}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_2 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['config/sensor_config'], 'start_time': 1564474170.237, 'end_time': 1564515390.942}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_1 -> [100, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['config/sensor_config'], 'start_time': 1564550647.975, 'end_time': 1564577871.628}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_2 -> [100, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['config/sensor_config'], 'start_time': 1565459507.694, 'end_time': 1565497156.436}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_3 -> [100, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['config/sensor_config'], 'start_time': 1566326171.842, 'end_time': 1566365176.313}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_3 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['config/sensor_config'], 'start_time': 1563764643.841, 'end_time': 1563788093.89}
# response = <Response [200]>
# Found 1 entries
# best_high_accuracy_medium_freq_stationary_0 -> [100]
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['config/sensor_config'], 'start_time': 1563863242.745, 'end_time': 1563890205.16}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_0 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['config/sensor_config'], 'start_time': 1563944837.097, 'end_time': 1563973569.17}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_1 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['config/sensor_config'], 'start_time': 1564443147.669, 'end_time': 1564468646.02}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_2 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['config/sensor_config'], 'start_time': 1564474182.091, 'end_time': 1564515413.202}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_1 -> [100, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['config/sensor_config'], 'start_time': 1564550657.986, 'end_time': 1564577879.533}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_2 -> [100, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['config/sensor_config'], 'start_time': 1565459518.792, 'end_time': 1565497182.525}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_3 -> [100, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['config/sensor_config'], 'start_time': 1566326188.776, 'end_time': 1566365199.723}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_3 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['config/sensor_config'], 'start_time': 1563764686.301, 'end_time': 1563788105.544}
# response = <Response [200]>
# Found 1 entries
# best_high_accuracy_medium_freq_stationary_0 -> [100]
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['config/sensor_config'], 'start_time': 1563863272.656, 'end_time': 1563890214.77}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_0 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['config/sensor_config'], 'start_time': 1563944862.98, 'end_time': 1563973599.147}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_1 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['config/sensor_config'], 'start_time': 1564443166.388, 'end_time': 1564468671.403}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_2 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['config/sensor_config'], 'start_time': 1564474191.646, 'end_time': 1564515433.591}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_1 -> [100, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['config/sensor_config'], 'start_time': 1564550670.614, 'end_time': 1564577888.013}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_2 -> [100, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['config/sensor_config'], 'start_time': 1565459530.106, 'end_time': 1565497200.84}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_3 -> [100, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['config/sensor_config'], 'start_time': 1566326206.045, 'end_time': 1566365226.053}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_3 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['config/sensor_config'], 'start_time': 1563764729.726, 'end_time': 1563788112.969}
# response = <Response [200]>
# Found 1 entries
# best_high_accuracy_medium_freq_stationary_0 -> [100]
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['config/sensor_config'], 'start_time': 1563863286.928, 'end_time': 1563890220.992}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_0 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['config/sensor_config'], 'start_time': 1563944882.313, 'end_time': 1563973623.433}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_1 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['config/sensor_config'], 'start_time': 1564443181.446, 'end_time': 1564468681.838}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_2 -> [102, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['config/sensor_config'], 'start_time': 1564474204.118, 'end_time': 1564515446.726}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_1 -> [100, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['config/sensor_config'], 'start_time': 1564550690.075, 'end_time': 1564577897.905}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_2 -> [100, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['config/sensor_config'], 'start_time': 1565459546.897, 'end_time': 1565497217.501}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_3 -> [100, 105]
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['config/sensor_config'], 'start_time': 1566326223.286, 'end_time': 1566365244.737}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_3 -> [102, 105]
# Processing data for ios phones
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['config/sensor_config'], 'start_time': 1563764432.001042, 'end_time': 1563788038.733817}
# response = <Response [200]>
# Found 1 entries
# best_high_accuracy_medium_freq_stationary_0 -> [-1]
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['config/sensor_config'], 'start_time': 1563863188.598661, 'end_time': 1563890158.048438}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_0 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['config/sensor_config'], 'start_time': 1563944726.909893, 'end_time': 1563973423.3017302}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_1 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['config/sensor_config'], 'start_time': 1564443051.118357, 'end_time': 1564468553.824141}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_2 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['config/sensor_config'], 'start_time': 1564474123.936163, 'end_time': 1564515317.5011601}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_1 -> [-1, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['config/sensor_config'], 'start_time': 1564550585.184926, 'end_time': 1564577823.817019}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_2 -> [-1, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['config/sensor_config'], 'start_time': 1565459445.018568, 'end_time': 1565497082.7905369}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_3 -> [-1, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['config/sensor_config'], 'start_time': 1566326069.359354, 'end_time': 1566365108.456779}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_3 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['config/sensor_config'], 'start_time': 1563764493.97196, 'end_time': 1563788050.872571}
# response = <Response [200]>
# Found 1 entries
# best_high_accuracy_medium_freq_stationary_0 -> [-1]
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['config/sensor_config'], 'start_time': 1563863200.2893429, 'end_time': 1563890167.611793}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_0 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['config/sensor_config'], 'start_time': 1563944748.4612122, 'end_time': 1563973443.5124102}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_1 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['config/sensor_config'], 'start_time': 1564443070.914775, 'end_time': 1564468570.2842422}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_2 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['config/sensor_config'], 'start_time': 1564474133.11743, 'end_time': 1564515336.478229}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_1 -> [-1, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['config/sensor_config'], 'start_time': 1564550599.708209, 'end_time': 1564577837.754926}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_2 -> [-1, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['config/sensor_config'], 'start_time': 1565459463.64622, 'end_time': 1565497103.782407}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_3 -> [-1, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['config/sensor_config'], 'start_time': 1566326095.941084, 'end_time': 1566365123.160764}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_3 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['config/sensor_config'], 'start_time': 1563764533.214622, 'end_time': 1563788061.999584}
# Got ConnectionError error ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer')), retrying
# response = <Response [200]>
# Found 1 entries
# best_high_accuracy_medium_freq_stationary_0 -> [-1]
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['config/sensor_config'], 'start_time': 1563863211.0520248, 'end_time': 1563890178.148947}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_0 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['config/sensor_config'], 'start_time': 1563944770.673845, 'end_time': 1563973484.065419}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_1 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['config/sensor_config'], 'start_time': 1564443090.27934, 'end_time': 1564468589.342068}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_2 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['config/sensor_config'], 'start_time': 1564474143.693054, 'end_time': 1564515362.49302}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_1 -> [-1, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['config/sensor_config'], 'start_time': 1564550613.085412, 'end_time': 1564577848.093852}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_2 -> [-1, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['config/sensor_config'], 'start_time': 1565459478.577074, 'end_time': 1565497123.246423}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_3 -> [-1, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['config/sensor_config'], 'start_time': 1566326117.702869, 'end_time': 1566365139.9554238}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_3 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['config/sensor_config'], 'start_time': 1563764579.704987, 'end_time': 1563788072.625461}
# response = <Response [200]>
# Found 1 entries
# best_high_accuracy_medium_freq_stationary_0 -> [-1]
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['config/sensor_config'], 'start_time': 1563863221.463701, 'end_time': 1563890192.1354408}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_0 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['config/sensor_config'], 'start_time': 1563944788.946683, 'end_time': 1563973524.094161}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_1 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['config/sensor_config'], 'start_time': 1564443113.994324, 'end_time': 1564468605.239407}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_2 -> [100, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['config/sensor_config'], 'start_time': 1564474155.932115, 'end_time': 1564515377.928055}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_1 -> [-1, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['config/sensor_config'], 'start_time': 1564550627.6688051, 'end_time': 1564577863.398086}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_2 -> [-1, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['config/sensor_config'], 'start_time': 1565459490.136774, 'end_time': 1565497135.015895}
# response = <Response [200]>
# Found 2 entries
# best_high_accuracy_medium_freq_stationary_3 -> [-1, 3000]
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['config/sensor_config'], 'start_time': 1566326146.542737, 'end_time': 1566365158.8372478}
# response = <Response [200]>
# Found 2 entries
# 100m_balanced_accuracy_medium_freq_stationary_3 -> [100, 3000]
# -------------------- About to validate evaluation settings --------------------
# -------------------- About to validate calibration range durations --------------------
# Processing data for android phones
# Processing data for ios phones
#                            100m_balanced_accuracy_medium_freq_stationary_0  \
# android_ucb-sdb-android-1                                     26968.113000
# android_ucb-sdb-android-2                                     26962.415000
# android_ucb-sdb-android-3                                     26942.114000
# android_ucb-sdb-android-4                                     26934.064000
# ios_ucb-sdb-ios-1                                             26969.449777
# ios_ucb-sdb-ios-2                                             26967.322450
# ios_ucb-sdb-ios-3                                             26967.096922
# ios_ucb-sdb-ios-4                                             26970.671740
#
#                            100m_balanced_accuracy_medium_freq_stationary_1  \
# android_ucb-sdb-android-1                                     28737.136000
# android_ucb-sdb-android-2                                     28732.073000
# android_ucb-sdb-android-3                                     28736.167000
# android_ucb-sdb-android-4                                     28741.120000
# ios_ucb-sdb-ios-1                                             28696.391837
# ios_ucb-sdb-ios-2                                             28695.051198
# ios_ucb-sdb-ios-3                                             28713.391574
# ios_ucb-sdb-ios-4                                             28735.147478
#
#                            100m_balanced_accuracy_medium_freq_stationary_2  \
# android_ucb-sdb-android-1                                     25483.212000
# android_ucb-sdb-android-2                                     25498.351000
# android_ucb-sdb-android-3                                     25505.015000
# android_ucb-sdb-android-4                                     25500.392000
# ios_ucb-sdb-ios-1                                             25502.705784
# ios_ucb-sdb-ios-2                                             25499.369467
# ios_ucb-sdb-ios-3                                             25499.062728
# ios_ucb-sdb-ios-4                                             25491.245083
#
#                            100m_balanced_accuracy_medium_freq_stationary_3  \
# android_ucb-sdb-android-1                                     39004.471000
# android_ucb-sdb-android-2                                     39010.947000
# android_ucb-sdb-android-3                                     39020.008000
# android_ucb-sdb-android-4                                     39021.451000
# ios_ucb-sdb-ios-1                                             39039.097425
# ios_ucb-sdb-ios-2                                             39027.219680
# ios_ucb-sdb-ios-3                                             39022.252555
# ios_ucb-sdb-ios-4                                             39012.294511
#
#                            best_high_accuracy_medium_freq_stationary_0  \
# android_ucb-sdb-android-1                                 23472.527000
# android_ucb-sdb-android-2                                 23450.049000
# android_ucb-sdb-android-3                                 23419.243000
# android_ucb-sdb-android-4                                 23383.243000
# ios_ucb-sdb-ios-1                                         23606.732775
# ios_ucb-sdb-ios-2                                         23556.900611
# ios_ucb-sdb-ios-3                                         23528.784962
# ios_ucb-sdb-ios-4                                         23492.920474
#
#                            best_high_accuracy_medium_freq_stationary_1  \
# android_ucb-sdb-android-1                                 41220.705000
# android_ucb-sdb-android-2                                 41231.111000
# android_ucb-sdb-android-3                                 41241.945000
# android_ucb-sdb-android-4                                 41242.608000
# ios_ucb-sdb-ios-1                                         41193.564997
# ios_ucb-sdb-ios-2                                         41203.360799
# ios_ucb-sdb-ios-3                                         41218.799966
# ios_ucb-sdb-ios-4                                         41221.995940
#
#                            best_high_accuracy_medium_freq_stationary_2  \
# android_ucb-sdb-android-1                                 27223.653000
# android_ucb-sdb-android-2                                 27221.547000
# android_ucb-sdb-android-3                                 27217.399000
# android_ucb-sdb-android-4                                 27207.830000
# ios_ucb-sdb-ios-1                                         27238.632093
# ios_ucb-sdb-ios-2                                         27238.046717
# ios_ucb-sdb-ios-3                                         27235.008440
# ios_ucb-sdb-ios-4                                         27235.729281
#
#                            best_high_accuracy_medium_freq_stationary_3
# android_ucb-sdb-android-1                                 37648.742000
# android_ucb-sdb-android-2                                 37663.733000
# android_ucb-sdb-android-3                                 37670.734000
# android_ucb-sdb-android-4                                 37670.604000
# ios_ucb-sdb-ios-1                                         37637.771969
# ios_ucb-sdb-ios-2                                         37640.136187
# ios_ucb-sdb-ios-3                                         37644.669349
# ios_ucb-sdb-ios-4                                         37644.879121
# For 100m_balanced_accuracy_medium_freq_stationary_0, duration_variation = [0.9033137559890747, -4.794685959815979, -25.095686078071594, -33.14568603038788, 2.2400909662246704, 0.11276400089263916, -0.11276400089263916, 3.462053656578064]
# For 100m_balanced_accuracy_medium_freq_stationary_1, duration_variation = [3.525760769844055, -1.5372389554977417, 2.5567609071731567, 7.5097609758377075, -37.2184020280838, -38.559041142463684, -20.21866524219513, 1.5372389554977417]
# For 100m_balanced_accuracy_medium_freq_stationary_2, duration_variation = [-16.00409746170044, -0.8650975227355957, 5.79890251159668, 1.1759023666381836, 3.4896864891052246, 0.15336966514587402, -0.15336966514587402, -7.971014499664307]
# For 100m_balanced_accuracy_medium_freq_stationary_3, duration_variation = [-16.25849997997284, -9.78249990940094, -0.721500039100647, 0.721500039100647, 18.36792504787445, 6.490180134773254, 1.5230549573898315, -8.434989094734192]
# For best_high_accuracy_medium_freq_stationary_0, duration_variation = [-10.196736931800842, -32.674737095832825, -63.48073732852936, -99.48073709011078, 124.00903809070587, 74.17687380313873, 46.061224818229675, 10.196736931800842]
# For best_high_accuracy_medium_freq_stationary_1, duration_variation = [-0.6454700231552124, 9.76052987575531, 20.59453022480011, 21.257530093193054, -27.785472750663757, -17.989670872688293, -2.5505038499832153, 0.6454700231552124]
# For best_high_accuracy_medium_freq_stationary_2, duration_variation = [-5.677719950675964, -7.783720135688782, -11.93172013759613, -21.500720143318176, 9.30137288570404, 8.715996861457825, 5.677719950675964, 6.398560881614685]
# For best_high_accuracy_medium_freq_stationary_3, duration_variation = [1.9314396381378174, 16.922439575195312, 23.923439502716064, 23.793439388275146, -9.038591623306274, -6.674373388290405, -2.14121150970459, -1.9314396381378174]
# -------------------- About to validate evaluation range durations --------------------
# Processing data for android phones
# Processing data for ios phones
# Empty DataFrame
# Columns: []
# Index: [android_ucb-sdb-android-1, android_ucb-sdb-android-2, android_ucb-sdb-android-3, android_ucb-sdb-android-4, ios_ucb-sdb-ios-1, ios_ucb-sdb-ios-2, ios_ucb-sdb-ios-3, ios_ucb-sdb-ios-4]

# %%
ev_hf = eiev.EvaluationView()
ev_hf.from_view_multiple_runs(pv_hf, "")
# Out:
# Processing data for android phones
# Processing data for ios phones

# %%
ev_mf = eiev.EvaluationView()
ev_mf.from_view_multiple_runs(pv_mf, "")
# Out:
# Processing data for android phones
# Processing data for ios phones

# %% [markdown]
# ##  Convert the battery drain into a dataframe
#
# This is similar to the eval dataframe, but subtly different

# %%
a2q_map = {"100m": 0, "lowpwr": 0, "10m": 1, "balanced": 1, "best": 2, "high": 2}
f2q_map = {"medium": 1, "high": 2}

# %%
def get_battery_drain_entries(pv):
    battery_entry_list = []
    for phone_os, phone_map in pv.map().items():
        print(15 * "=*")
        print(phone_os, phone_map.keys())
        for phone_label, phone_detail_map in phone_map.items():
            print(4 * ' ', 15 * "-*")
            print(4 * ' ', phone_label, phone_detail_map.keys())
            # this spec does not have any calibration ranges, but evaluation ranges are actually cooler
            for r in phone_detail_map["calibration_ranges"]:
                print(8 * ' ', 30 * "=")
                print(8 * ' ',r.keys())
                print(8 * ' ',r["trip_id"], r["trip_run"])
                bcs = r["battery_df"]["battery_level_pct"]
                delta_battery = bcs.iloc[0] - bcs.iloc[-1]
                if "medium_freq" or "high_frequency" in r["trip_id"]:
                    cc = r["trip_id"].split("_")
                    config_map = {"accuracy_str": cc[0] if phone_os == "ios" else cc[1],
                                  "frequency_str": cc[3],
                    }
                    config_map["accuracy"] = a2q_map[config_map["accuracy_str"]]
                    config_map["frequency"] = f2q_map[config_map["frequency_str"]]
                print("Battery starts at %d, ends at %d, drain = %d" % (bcs.iloc[0], bcs.iloc[-1], delta_battery))
                battery_entry = {"phone_os": phone_os, "phone_label": phone_label, "config": r["trip_id"],
                                 "run": r["trip_run"], "duration": r["duration"],
                                 "battery_drain_observed": delta_battery}
                battery_entry.update(config_map)
                battery_entry_list.append(battery_entry)
    return battery_entry_list

# %%
battery_entries_list = []
battery_entries_list.extend(get_battery_drain_entries(pv_hf))
battery_entries_list.extend(get_battery_drain_entries(pv_mf))
battery_drain_df = pd.DataFrame(battery_entries_list)
# Out:
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# android dict_keys(['ucb-sdb-android-1', 'ucb-sdb-android-2', 'ucb-sdb-android-3', 'ucb-sdb-android-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 75, drain = 25
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 74, drain = 26
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 73, drain = 27
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# Battery starts at 100, ends at 74, drain = 26
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 90, drain = 10
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 92, drain = 8
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 88, drain = 12
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 90, drain = 10
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 92, drain = 8
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 90, drain = 10
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 78, drain = 22
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 73, drain = 27
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 77, drain = 23
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# Battery starts at 100, ends at 76, drain = 24
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 90, drain = 10
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 92, drain = 8
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 88, drain = 12
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 93, drain = 7
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 92, drain = 8
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 89, drain = 11
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 81, drain = 19
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 77, drain = 23
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 72, drain = 28
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# Battery starts at 100, ends at 73, drain = 27
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 89, drain = 11
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 91, drain = 9
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 88, drain = 12
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 91, drain = 9
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 92, drain = 8
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 88, drain = 12
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-4 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 82, drain = 18
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 72, drain = 28
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 81, drain = 19
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# Battery starts at 100, ends at 78, drain = 22
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 92, drain = 8
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 90, drain = 10
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 87, drain = 13
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 91, drain = 9
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 89, drain = 11
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 82, drain = 18
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# ios dict_keys(['ucb-sdb-ios-1', 'ucb-sdb-ios-2', 'ucb-sdb-ios-3', 'ucb-sdb-ios-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 46, drain = 53
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 30, drain = 69
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 27, drain = 72
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# Battery starts at 100, ends at 40, drain = 59
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 40, drain = 59
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 52, drain = 47
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 50, drain = 49
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 86, drain = 13
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 89, drain = 10
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 80, drain = 19
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 50, drain = 50
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 40, drain = 59
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 41, drain = 58
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# Battery starts at 100, ends at 46, drain = 53
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 46, drain = 53
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 60, drain = 39
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 56, drain = 43
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 87, drain = 12
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 88, drain = 11
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 80, drain = 19
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 28, drain = 71
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 28, drain = 71
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 28, drain = 71
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# Battery starts at 100, ends at 38, drain = 61
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 43, drain = 56
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 56, drain = 43
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 55, drain = 44
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 85, drain = 14
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 86, drain = 13
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 62, drain = 37
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-4 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 43, drain = 56
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 25, drain = 74
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 20, drain = 79
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# Battery starts at 100, ends at 36, drain = 63
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 49, drain = 50
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 52, drain = 47
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 50, drain = 50
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# Battery starts at 100, ends at 85, drain = 14
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# Battery starts at 100, ends at 87, drain = 12
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# Battery starts at 100, ends at 77, drain = 22
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# android dict_keys(['ucb-sdb-android-1', 'ucb-sdb-android-2', 'ucb-sdb-android-3', 'ucb-sdb-android-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_0 0
# Battery starts at 100, ends at 96, drain = 4
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_0 0
# Battery starts at 100, ends at 93, drain = 7
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_1 1
# Battery starts at 100, ends at 93, drain = 7
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_2 2
# Battery starts at 100, ends at 95, drain = 5
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_1 1
# Battery starts at 100, ends at 89, drain = 11
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_2 2
# Battery starts at 100, ends at 93, drain = 7
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_3 3
# Battery starts at 100, ends at 92, drain = 8
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_3 3
# Battery starts at 100, ends at 91, drain = 9
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_0 0
# Battery starts at 100, ends at 96, drain = 4
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_0 0
# Battery starts at 100, ends at 93, drain = 7
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_1 1
# Battery starts at 100, ends at 93, drain = 7
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_2 2
# Battery starts at 100, ends at 94, drain = 6
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_1 1
# Battery starts at 100, ends at 89, drain = 11
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_2 2
# Battery starts at 100, ends at 92, drain = 8
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_3 3
# Battery starts at 100, ends at 92, drain = 8
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_3 3
# Battery starts at 100, ends at 92, drain = 8
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_0 0
# Battery starts at 100, ends at 94, drain = 6
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_0 0
# Battery starts at 100, ends at 92, drain = 8
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_1 1
# Battery starts at 100, ends at 93, drain = 7
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_2 2
# Battery starts at 100, ends at 94, drain = 6
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_1 1
# Battery starts at 100, ends at 90, drain = 10
#          ==============================
# ...
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_3 3
# Battery starts at 100, ends at 94, drain = 6
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_3 3
# Battery starts at 100, ends at 94, drain = 6
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# ios dict_keys(['ucb-sdb-ios-1', 'ucb-sdb-ios-2', 'ucb-sdb-ios-3', 'ucb-sdb-ios-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_0 0
# Battery starts at 100, ends at 75, drain = 24
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_0 0
# Battery starts at 100, ends at 92, drain = 7
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_1 1
# Battery starts at 100, ends at 91, drain = 8
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_2 2
# Battery starts at 100, ends at 92, drain = 7
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_1 1
# Battery starts at 100, ends at 55, drain = 44
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_2 2
# Battery starts at 100, ends at 70, drain = 29
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_3 3
# Battery starts at 100, ends at 50, drain = 49
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_3 3
# Battery starts at 100, ends at 74, drain = 25
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_0 0
# Battery starts at 100, ends at 82, drain = 17
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_0 0
# Battery starts at 100, ends at 92, drain = 7
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_1 1
# Battery starts at 100, ends at 93, drain = 6
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_2 2
# Battery starts at 100, ends at 93, drain = 6
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_1 1
# Battery starts at 100, ends at 63, drain = 36
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_2 2
# Battery starts at 100, ends at 77, drain = 22
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_3 3
# Battery starts at 100, ends at 64, drain = 35
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_3 3
# Battery starts at 100, ends at 83, drain = 16
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_0 0
# Battery starts at 100, ends at 76, drain = 23
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_0 0
# Battery starts at 100, ends at 87, drain = 12
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_1 1
# Battery starts at 100, ends at 86, drain = 13
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_2 2
# Battery starts at 100, ends at 81, drain = 18
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_1 1
# Battery starts at 100, ends at 55, drain = 44
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_2 2
# Battery starts at 100, ends at 72, drain = 27
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_3 3
# Battery starts at 99, ends at 51, drain = 47
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_3 3
# Battery starts at 99, ends at 70, drain = 28
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-4 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_0 0
# Battery starts at 100, ends at 75, drain = 24
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_0 0
# Battery starts at 100, ends at 91, drain = 8
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_1 1
# Battery starts at 100, ends at 89, drain = 10
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_2 2
# Battery starts at 100, ends at 91, drain = 8
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_1 1
# Battery starts at 100, ends at 52, drain = 47
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_2 2
# Battery starts at 100, ends at 70, drain = 29
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_3 3
# Battery starts at 98, ends at 49, drain = 49
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_3 3
# Battery starts at 94, ends at 73, drain = 21

# %%
battery_drain_df.head()
# Out:
#    accuracy accuracy_str  battery_drain_observed  \
# 0         2         high                    25.0
# 1         2         high                    26.0
# 2         2         high                    27.0
# 3         2         high                    26.0
# 4         1     balanced                    10.0
#
#                                               config  duration  frequency  \
# 0     best_high_accuracy_high_frequency_stationary_0   48602.0          2
# 1     best_high_accuracy_high_frequency_stationary_1   61527.0          2
# 2     best_high_accuracy_high_frequency_stationary_2   65632.0          2
# 3     best_high_accuracy_high_frequency_stationary_3   56641.0          2
# 4  10m_balanced_accuracy_high_frequency_stationary_0   52652.0          2
#
#   frequency_str        phone_label phone_os  run
# 0          high  ucb-sdb-android-1  android    0
# 1          high  ucb-sdb-android-1  android    1
# 2          high  ucb-sdb-android-1  android    2
# 3          high  ucb-sdb-android-1  android    3
# 4          high  ucb-sdb-android-1  android    0

# %% [markdown]
# ## Normalize
#
# It turns out that the calibration ranges have had very different durations. So if we want to really standardize them, we need to calculate the drain for the same duration. But what should that duration be? (min, max, mean)? For now, we pick the mean duration and because the points are coarse, use curve fitting to ensure that we have a point at that mean duration

# %%
print("mean = %s hours, min = %s" % (battery_drain_df.duration.mean() / (60*60), battery_drain_df.duration.min() / (60*60)))
battery_drain_df.duration.describe()
# Out:
# mean = 11.51841214074489 hours, min = 6.495345277786255
# count      144.000000
# mean     41466.283707
# std      12547.050782
# min      23383.243000
# 25%      28734.378859
# 50%      41325.804000
# 75%      52650.500000
# max      65659.000000
# Name: duration, dtype: float64

# %%
def explore_interpolated_battery_drain_at_duration(pv, hr_from_start, i = 0):
    bad_extrapolations = []
    for phone_os, phone_map in pv.map().items():
        print(15 * "=*")
        print(phone_os, phone_map.keys())
        for phone_label, phone_detail_map in phone_map.items():
            print(4 * ' ', 15 * "-*")
            print(4 * ' ', phone_label, phone_detail_map.keys())
            for r in phone_detail_map["calibration_ranges"]:
                print(8 * ' ', 30 * "=")
                print(8 * ' ',r.keys())
                print(8 * ' ',i, r["trip_id"], r["trip_run"])
                battery_df = r["battery_df"]
                battery_fn = sci.interp1d(battery_df.hr, battery_df.battery_level_pct, fill_value="extrapolate")
                hr_range = pd.Series(np.arange(battery_df.hr.min(), hr_from_start, 60 / (60 * 60))) # 1 minute
                
                interp_battery_level = pd.Series(battery_fn(hr_range))
                changes = interp_battery_level.diff()
                extrapolated_changes = changes[hr_range > battery_df.hr.max()]
                print(len(extrapolated_changes), np.count_nonzero(extrapolated_changes))
                print("Extrapolating from %s -> %s, added %d more points" % (battery_df.hr.max(), hr_from_start, len(extrapolated_changes)))
                if np.count_nonzero(extrapolated_changes) < 0.1 * len(extrapolated_changes):
                    print("WARNING: BAD EXTRAPOLATION")
                    bad_extrapolations.append(phone_label+"_"+r["trip_id"])
                axes_flat[i].plot(battery_df.hr, battery_df.battery_level_pct, color="green")
                axes_flat[i].plot(hr_range, interp_battery_level, color="red")
                axes_flat[i].set_title(phone_label+"_"+r["trip_id"])
                i = i+1
                
    return (i, bad_extrapolations)

# %% [markdown]
# ### Trying to use the mean of the durations, which will require some extrapolation

# %%
row_count = int(len(battery_drain_df) / 3) + 1
ifig, axes_array = plt.subplots(nrows=row_count, ncols=3, figsize=(20, 120), sharex=True, sharey=True)
axes_flat = axes_array.flatten()
all_be = []
(i, be) = explore_interpolated_battery_drain_at_duration(pv_hf, 12)
all_be.extend(be)
(i, be) = explore_interpolated_battery_drain_at_duration(pv_mf, 12, i)
all_be.extend(be)
all_be
# Out:
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# android dict_keys(['ucb-sdb-android-1', 'ucb-sdb-android-2', 'ucb-sdb-android-3', 'ucb-sdb-android-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          0 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.498125555581517 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          1 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 17.088379722237587 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          2 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 18.230365833308962 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          3 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 15.731736944450272 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          4 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 14.043885833356116 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          5 10m_balanced_accuracy_high_frequency_stationary_1 1
# 29 1
# Extrapolating from 11.502462500002649 -> 12, added 29 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          6 10m_balanced_accuracy_high_frequency_stationary_2 2
# 5 1
# Extrapolating from 11.907108055551847 -> 12, added 5 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          7 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 6 1
# Extrapolating from 11.886542777750227 -> 12, added 6 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          8 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 199 199
# Extrapolating from 8.682198333276643 -> 12, added 199 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          9 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.814498611092567 -> 12, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.49737972219785 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          11 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 17.0932408333487 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          12 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.361134166651302 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          13 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 15.736159166693687 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          14 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 14.624623888863457 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          15 10m_balanced_accuracy_high_frequency_stationary_1 1
# 29 1
# Extrapolating from 11.500974722239706 -> 12, added 29 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          16 10m_balanced_accuracy_high_frequency_stationary_2 2
# 5 1
# Extrapolating from 11.905499444471465 -> 12, added 5 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          17 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 243 1
# Extrapolating from 7.948053888877233 -> 12, added 243 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          18 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 198 198
# Extrapolating from 8.686896388861868 -> 12, added 198 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          19 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.814684722224872 -> 12, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          20 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.500068888862927 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          21 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 14.067187777757646 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          22 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 18.23671083331108 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          23 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 15.088655555579397 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          24 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.941046666635406 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          25 10m_balanced_accuracy_high_frequency_stationary_1 1
# 29 1
# Extrapolating from 11.507792222234938 -> 12, added 29 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          26 10m_balanced_accuracy_high_frequency_stationary_2 2
# 5 1
# Extrapolating from 11.902277499967152 -> 12, added 5 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          27 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 234 1
# Extrapolating from 8.08435333331426 -> 12, added 234 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          28 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 198 198
# Extrapolating from 8.697577222188313 -> 12, added 198 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          29 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.818691111140781 -> 12, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-4 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          30 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.496322499977218 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          31 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 17.09900972220633 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          32 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 13.64355555554231 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          33 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 15.745849999984106 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          34 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 14.040876944462457 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          35 10m_balanced_accuracy_high_frequency_stationary_1 1
# 29 1
# Extrapolating from 11.507233888904254 -> 12, added 29 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          36 10m_balanced_accuracy_high_frequency_stationary_2 2
# 5 1
# Extrapolating from 11.902532777786256 -> 12, added 5 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          37 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 37 1
# Extrapolating from 11.371133888893658 -> 12, added 37 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          38 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 197 197
# Extrapolating from 8.705315833356645 -> 12, added 197 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          39 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.819372222224871 -> 12, added 0 more points
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# ios dict_keys(['ucb-sdb-ios-1', 'ucb-sdb-ios-2', 'ucb-sdb-ios-3', 'ucb-sdb-ios-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          40 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.07243064529366 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          41 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 16.940984596676298 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          42 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 17.23742698278692 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          43 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 14.77369592030843 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          44 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 14.348824674950706 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          45 10m_balanced_accuracy_high_frequency_stationary_1 1
# 46 1
# Extrapolating from 11.22411902387937 -> 12, added 46 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          46 10m_balanced_accuracy_high_frequency_stationary_2 2
# 34 1
# Extrapolating from 11.429518936342664 -> 12, added 34 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          47 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 47 1
# Extrapolating from 11.206751536130906 -> 12, added 47 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          48 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 199 0
# Extrapolating from 8.667382423347897 -> 12, added 199 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          49 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.798938638634151 -> 12, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          50 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.387402730517918 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          51 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 16.945419379207824 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          52 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 17.22674541917112 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          53 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 14.766585088306003 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          54 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 14.34165147225062 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          55 10m_balanced_accuracy_high_frequency_stationary_1 1
# 46 1
# Extrapolating from 11.218273564179738 -> 12, added 46 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          56 10m_balanced_accuracy_high_frequency_stationary_2 2
# 34 1
# Extrapolating from 11.425283285843001 -> 12, added 34 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          57 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 47 1
# Extrapolating from 11.202229738632838 -> 12, added 47 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          58 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 199 0
# Extrapolating from 8.67221999221378 -> 12, added 199 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          59 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.803305121130414 -> 12, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          60 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.396071379714542 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          61 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 16.936899935801822 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          62 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 18.22163706752989 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          63 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 14.75936669588089 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          64 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 14.3365294222037 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          65 10m_balanced_accuracy_high_frequency_stationary_1 1
# 47 1
# Extrapolating from 11.209692164990637 -> 12, added 47 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          66 10m_balanced_accuracy_high_frequency_stationary_2 2
# 34 1
# Extrapolating from 11.420036435789532 -> 12, added 34 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          67 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 48 1
# Extrapolating from 11.197441310286521 -> 12, added 48 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          68 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 199 0
# Extrapolating from 8.67930715309249 -> 12, added 199 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          69 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.807746624747912 -> 12, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-4 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          70 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.019113233354357 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          71 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 16.929278302457597 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          72 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 18.216916818618774 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          73 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 14.752027172512479 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          74 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 14.331047121683756 -> 12, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          75 10m_balanced_accuracy_high_frequency_stationary_1 1
# 47 1
# Extrapolating from 11.205694982475706 -> 12, added 47 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          76 10m_balanced_accuracy_high_frequency_stationary_2 2
# 36 1
# Extrapolating from 11.397702835003535 -> 12, added 36 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          77 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 48 1
# Extrapolating from 11.192593916124768 -> 12, added 48 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          78 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 199 0
# Extrapolating from 8.681376445558335 -> 12, added 199 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          79 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.808684716423352 -> 12, added 0 more points
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# android dict_keys(['ucb-sdb-android-1', 'ucb-sdb-android-2', 'ucb-sdb-android-3', 'ucb-sdb-android-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          80 best_high_accuracy_medium_freq_stationary_0 0
# 328 328
# Extrapolating from 6.5201400000519225 -> 12, added 328 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          81 100m_balanced_accuracy_medium_freq_stationary_0 0
# 270 270
# Extrapolating from 7.491127222180366 -> 12, added 270 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          82 100m_balanced_accuracy_medium_freq_stationary_1 1
# 241 0
# Extrapolating from 7.982525555557674 -> 12, added 241 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          83 100m_balanced_accuracy_medium_freq_stationary_2 2
# 295 1
# Extrapolating from 7.078653888901075 -> 12, added 295 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          84 best_high_accuracy_medium_freq_stationary_1 1
# 32 32
# Extrapolating from 11.450180277758175 -> 12, added 32 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          85 best_high_accuracy_medium_freq_stationary_2 2
# 266 1
# Extrapolating from 7.562115000022782 -> 12, added 266 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          86 best_high_accuracy_medium_freq_stationary_3 3
# 92 1
# Extrapolating from 10.457973611089919 -> 12, added 92 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          87 100m_balanced_accuracy_medium_freq_stationary_3 3
# 69 0
# Extrapolating from 10.834559722211626 -> 12, added 69 more points
# WARNING: BAD EXTRAPOLATION
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          88 best_high_accuracy_medium_freq_stationary_0 0
# 329 1
# Extrapolating from 6.513889999985695 -> 12, added 329 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          89 100m_balanced_accuracy_medium_freq_stationary_0 0
# 270 270
# Extrapolating from 7.489546666675143 -> 12, added 270 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          90 100m_balanced_accuracy_medium_freq_stationary_1 1
# 241 0
# Extrapolating from 7.981120000018014 -> 12, added 241 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          91 100m_balanced_accuracy_medium_freq_stationary_2 2
# 295 1
# Extrapolating from 7.082855833371481 -> 12, added 295 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          92 best_high_accuracy_medium_freq_stationary_1 1
# 32 32
# Extrapolating from 11.453069999946488 -> 12, added 32 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          93 best_high_accuracy_medium_freq_stationary_2 2
# 266 1
# Extrapolating from 7.5615280555354225 -> 12, added 266 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
# ...
#          122 100m_balanced_accuracy_medium_freq_stationary_1 1
# 241 0
# Extrapolating from 7.970798551109102 -> 12, added 241 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          123 100m_balanced_accuracy_medium_freq_stationary_2 2
# 295 1
# Extrapolating from 7.083090979788039 -> 12, added 295 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          124 best_high_accuracy_medium_freq_stationary_1 1
# 33 1
# Extrapolating from 11.445317491094272 -> 12, added 33 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          125 best_high_accuracy_medium_freq_stationary_2 2
# 266 1
# Extrapolating from 7.566074211332533 -> 12, added 266 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          126 best_high_accuracy_medium_freq_stationary_3 3
# 92 1
# Extrapolating from 10.45554954191049 -> 12, added 92 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          127 100m_balanced_accuracy_medium_freq_stationary_3 3
# 69 1
# Extrapolating from 10.840834358665678 -> 12, added 69 more points
# WARNING: BAD EXTRAPOLATION
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          128 best_high_accuracy_medium_freq_stationary_0 0
# 327 327
# Extrapolating from 6.535768008629481 -> 12, added 327 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          129 100m_balanced_accuracy_medium_freq_stationary_0 0
# 270 1
# Extrapolating from 7.490807160867585 -> 12, added 270 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          130 100m_balanced_accuracy_medium_freq_stationary_1 1
# 241 0
# Extrapolating from 7.975897428923183 -> 12, added 241 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          131 100m_balanced_accuracy_medium_freq_stationary_2 2
# 295 1
# Extrapolating from 7.083024351133241 -> 12, added 295 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          132 best_high_accuracy_medium_freq_stationary_1 1
# 33 1
# Extrapolating from 11.449623101353644 -> 12, added 33 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          133 best_high_accuracy_medium_freq_stationary_2 2
# 266 1
# Extrapolating from 7.565235720872879 -> 12, added 266 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          134 best_high_accuracy_medium_freq_stationary_3 3
# 92 1
# Extrapolating from 10.456792466110654 -> 12, added 92 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          135 100m_balanced_accuracy_medium_freq_stationary_3 3
# 69 1
# Extrapolating from 10.839462397760816 -> 12, added 69 more points
# WARNING: BAD EXTRAPOLATION
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-4 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          136 best_high_accuracy_medium_freq_stationary_0 0
# 328 328
# Extrapolating from 6.525805333587859 -> 12, added 328 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          137 100m_balanced_accuracy_medium_freq_stationary_0 0
# 270 1
# Extrapolating from 7.491791477534506 -> 12, added 270 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          138 100m_balanced_accuracy_medium_freq_stationary_1 1
# 241 0
# Extrapolating from 7.981931114196778 -> 12, added 241 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          139 100m_balanced_accuracy_medium_freq_stationary_2 2
# 295 1
# Extrapolating from 7.0808437975247704 -> 12, added 295 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          140 best_high_accuracy_medium_freq_stationary_1 1
# 32 1
# Extrapolating from 11.450508624977536 -> 12, added 32 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          141 best_high_accuracy_medium_freq_stationary_2 2
# 266 1
# Extrapolating from 7.565410946077771 -> 12, added 266 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          142 best_high_accuracy_medium_freq_stationary_3 3
# 92 1
# Extrapolating from 10.456845763325692 -> 12, added 92 more points
# WARNING: BAD EXTRAPOLATION
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          143 100m_balanced_accuracy_medium_freq_stationary_3 3
# 69 1
# Extrapolating from 10.836675482193629 -> 12, added 69 more points
# WARNING: BAD EXTRAPOLATION
# ['ucb-sdb-android-1_10m_balanced_accuracy_high_frequency_stationary_1',
#  'ucb-sdb-android-2_10m_balanced_accuracy_high_frequency_stationary_1',
#  'ucb-sdb-android-2_100m_lowpwr_accuracy_high_frequency_stationary_0',
#  'ucb-sdb-android-3_10m_balanced_accuracy_high_frequency_stationary_1',
#  'ucb-sdb-android-3_100m_lowpwr_accuracy_high_frequency_stationary_0',
#  'ucb-sdb-android-4_10m_balanced_accuracy_high_frequency_stationary_1',
#  'ucb-sdb-android-4_100m_lowpwr_accuracy_high_frequency_stationary_0',
#  'ucb-sdb-ios-1_10m_balanced_accuracy_high_frequency_stationary_1',
#  'ucb-sdb-ios-1_10m_balanced_accuracy_high_frequency_stationary_2',
#  'ucb-sdb-ios-1_100m_lowpwr_accuracy_high_frequency_stationary_0',
#  'ucb-sdb-ios-1_100m_lowpwr_accuracy_high_frequency_stationary_1',
#  'ucb-sdb-ios-2_10m_balanced_accuracy_high_frequency_stationary_1',
#  'ucb-sdb-ios-2_10m_balanced_accuracy_high_frequency_stationary_2',
#  'ucb-sdb-ios-2_100m_lowpwr_accuracy_high_frequency_stationary_0',
#  'ucb-sdb-ios-2_100m_lowpwr_accuracy_high_frequency_stationary_1',
#  'ucb-sdb-ios-3_10m_balanced_accuracy_high_frequency_stationary_1',
#  'ucb-sdb-ios-3_10m_balanced_accuracy_high_frequency_stationary_2',
#  'ucb-sdb-ios-3_100m_lowpwr_accuracy_high_frequency_stationary_0',
#  'ucb-sdb-ios-3_100m_lowpwr_accuracy_high_frequency_stationary_1',
#  'ucb-sdb-ios-4_10m_balanced_accuracy_high_frequency_stationary_1',
#  'ucb-sdb-ios-4_10m_balanced_accuracy_high_frequency_stationary_2',
#  'ucb-sdb-ios-4_100m_lowpwr_accuracy_high_frequency_stationary_0',
#  'ucb-sdb-ios-4_100m_lowpwr_accuracy_high_frequency_stationary_1',
#  'ucb-sdb-android-1_100m_balanced_accuracy_medium_freq_stationary_1',
#  'ucb-sdb-android-1_100m_balanced_accuracy_medium_freq_stationary_2',
#  'ucb-sdb-android-1_best_high_accuracy_medium_freq_stationary_2',
#  'ucb-sdb-android-1_best_high_accuracy_medium_freq_stationary_3',
#  'ucb-sdb-android-1_100m_balanced_accuracy_medium_freq_stationary_3',
#  'ucb-sdb-android-2_best_high_accuracy_medium_freq_stationary_0',
#  'ucb-sdb-android-2_100m_balanced_accuracy_medium_freq_stationary_1',
#  'ucb-sdb-android-2_100m_balanced_accuracy_medium_freq_stationary_2',
#  'ucb-sdb-android-2_best_high_accuracy_medium_freq_stationary_2',
#  'ucb-sdb-android-2_best_high_accuracy_medium_freq_stationary_3',
#  'ucb-sdb-android-2_100m_balanced_accuracy_medium_freq_stationary_3',
#  'ucb-sdb-android-3_best_high_accuracy_medium_freq_stationary_0',
#  'ucb-sdb-android-3_100m_balanced_accuracy_medium_freq_stationary_1',
#  'ucb-sdb-android-3_best_high_accuracy_medium_freq_stationary_3',
#  'ucb-sdb-android-4_best_high_accuracy_medium_freq_stationary_0',
#  'ucb-sdb-android-4_100m_balanced_accuracy_medium_freq_stationary_1',
#  'ucb-sdb-android-4_100m_balanced_accuracy_medium_freq_stationary_2',
#  'ucb-sdb-android-4_best_high_accuracy_medium_freq_stationary_1',
#  'ucb-sdb-android-4_best_high_accuracy_medium_freq_stationary_2',
#  'ucb-sdb-android-4_best_high_accuracy_medium_freq_stationary_3',
#  'ucb-sdb-android-4_100m_balanced_accuracy_medium_freq_stationary_3',
#  'ucb-sdb-ios-1_100m_balanced_accuracy_medium_freq_stationary_0',
#  'ucb-sdb-ios-1_100m_balanced_accuracy_medium_freq_stationary_1',
#  'ucb-sdb-ios-1_100m_balanced_accuracy_medium_freq_stationary_2',
#  'ucb-sdb-ios-1_best_high_accuracy_medium_freq_stationary_1',
#  'ucb-sdb-ios-1_best_high_accuracy_medium_freq_stationary_2',
#  'ucb-sdb-ios-1_best_high_accuracy_medium_freq_stationary_3',
#  'ucb-sdb-ios-1_100m_balanced_accuracy_medium_freq_stationary_3',
#  'ucb-sdb-ios-2_100m_balanced_accuracy_medium_freq_stationary_0',
#  'ucb-sdb-ios-2_100m_balanced_accuracy_medium_freq_stationary_1',
#  'ucb-sdb-ios-2_100m_balanced_accuracy_medium_freq_stationary_2',
#  'ucb-sdb-ios-2_best_high_accuracy_medium_freq_stationary_1',
#  'ucb-sdb-ios-2_best_high_accuracy_medium_freq_stationary_2',
#  'ucb-sdb-ios-2_best_high_accuracy_medium_freq_stationary_3',
#  'ucb-sdb-ios-2_100m_balanced_accuracy_medium_freq_stationary_3',
#  'ucb-sdb-ios-3_100m_balanced_accuracy_medium_freq_stationary_0',
#  'ucb-sdb-ios-3_100m_balanced_accuracy_medium_freq_stationary_1',
#  'ucb-sdb-ios-3_100m_balanced_accuracy_medium_freq_stationary_2',
#  'ucb-sdb-ios-3_best_high_accuracy_medium_freq_stationary_1',
#  'ucb-sdb-ios-3_best_high_accuracy_medium_freq_stationary_2',
#  'ucb-sdb-ios-3_best_high_accuracy_medium_freq_stationary_3',
#  'ucb-sdb-ios-3_100m_balanced_accuracy_medium_freq_stationary_3',
#  'ucb-sdb-ios-4_100m_balanced_accuracy_medium_freq_stationary_0',
#  'ucb-sdb-ios-4_100m_balanced_accuracy_medium_freq_stationary_1',
#  'ucb-sdb-ios-4_100m_balanced_accuracy_medium_freq_stationary_2',
#  'ucb-sdb-ios-4_best_high_accuracy_medium_freq_stationary_1',
#  'ucb-sdb-ios-4_best_high_accuracy_medium_freq_stationary_2',
#  'ucb-sdb-ios-4_best_high_accuracy_medium_freq_stationary_3',
#  'ucb-sdb-ios-4_100m_balanced_accuracy_medium_freq_stationary_3']

# %%
len(all_be)
# Out:
# 72

# %% [markdown]
# We can see from the graphs here that some extrapolations just don't work well. I am not sure if this is because there are too few points or something else weird in the spline code. For example, `100m_lowpwr_accuracy_high_frequency_stationary_0` bottoms out at `93%`

# %% [markdown]
# #### Detailed exploration

# %%
battery_df = [r for r in pv_hf.map()["android"]["ucb-sdb-android-2"]["calibration_ranges"] if r["trip_id"] == "100m_lowpwr_accuracy_high_frequency_stationary_0"][0]["battery_df"]

# %%
battery_df.hr.max()
# Out:
# 7.948053888877233

# %%
                battery_fn = sci.interp1d(battery_df.hr, battery_df.battery_level_pct, fill_value="extrapolate")
                hr_range = pd.Series(np.arange(battery_df.hr.min(), 12, 60 / (60 * 60))) # 1 minute
                interp_battery_level = pd.Series(battery_fn(hr_range))
                changes = interp_battery_level.diff(); changes.tail()
                extrapolated_changes = changes[hr_range > battery_df.hr.max()]; extrapolated_changes.tail()
                print("Extrapolating from %s -> %s, added %d more points" % (battery_df.hr.max(), 12, len(extrapolated_changes)))
                print(len(extrapolated_changes), np.count_nonzero(extrapolated_changes))
# Out:
# Extrapolating from 7.948053888877233 -> 12, added 243 more points
# 243 1

# %% [markdown]
# By adding a simple similar check, we can see that a 45/116 curves have bad extrapolations. So we can't really use extrapolation in this case

# %% [markdown]
# ### Switching to the min of the durations, which will give us less data

# %%
row_count = int(len(battery_drain_df) / 3) + 1
ifig, axes_array = plt.subplots(nrows=row_count, ncols=3, figsize=(20, 120), sharex=True, sharey=True)
axes_flat = axes_array.flatten()
all_be = []
(i, be) = explore_interpolated_battery_drain_at_duration(pv_hf, 5.9993)
all_be.extend(be)
(i, be) = explore_interpolated_battery_drain_at_duration(pv_mf, 5.9993, i)
all_be.extend(be)
print(len(all_be))
all_be
# Out:
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# android dict_keys(['ucb-sdb-android-1', 'ucb-sdb-android-2', 'ucb-sdb-android-3', 'ucb-sdb-android-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          0 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.498125555581517 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          1 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 17.088379722237587 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          2 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 18.230365833308962 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          3 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 15.731736944450272 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          4 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 14.043885833356116 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          5 10m_balanced_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 11.502462500002649 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          6 10m_balanced_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 11.907108055551847 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          7 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 11.886542777750227 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          8 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 8.682198333276643 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          9 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.814498611092567 -> 5.9993, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.49737972219785 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          11 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 17.0932408333487 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          12 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.361134166651302 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          13 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 15.736159166693687 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          14 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 14.624623888863457 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          15 10m_balanced_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 11.500974722239706 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          16 10m_balanced_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 11.905499444471465 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          17 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 7.948053888877233 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          18 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 8.686896388861868 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          19 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.814684722224872 -> 5.9993, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          20 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.500068888862927 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          21 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 14.067187777757646 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          22 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 18.23671083331108 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          23 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 15.088655555579397 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          24 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.941046666635406 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          25 10m_balanced_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 11.507792222234938 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          26 10m_balanced_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 11.902277499967152 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          27 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 8.08435333331426 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          28 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 8.697577222188313 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          29 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.818691111140781 -> 5.9993, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-4 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          30 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.496322499977218 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          31 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 17.09900972220633 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          32 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 13.64355555554231 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          33 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 15.745849999984106 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          34 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 14.040876944462457 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          35 10m_balanced_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 11.507233888904254 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          36 10m_balanced_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 11.902532777786256 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          37 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 11.371133888893658 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          38 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 8.705315833356645 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          39 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.819372222224871 -> 5.9993, added 0 more points
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# ios dict_keys(['ucb-sdb-ios-1', 'ucb-sdb-ios-2', 'ucb-sdb-ios-3', 'ucb-sdb-ios-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          40 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.07243064529366 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          41 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 16.940984596676298 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          42 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 17.23742698278692 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          43 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 14.77369592030843 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          44 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 14.348824674950706 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          45 10m_balanced_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 11.22411902387937 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          46 10m_balanced_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 11.429518936342664 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          47 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 11.206751536130906 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          48 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 8.667382423347897 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          49 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.798938638634151 -> 5.9993, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          50 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.387402730517918 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          51 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 16.945419379207824 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          52 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 17.22674541917112 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          53 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 14.766585088306003 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          54 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 14.34165147225062 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          55 10m_balanced_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 11.218273564179738 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          56 10m_balanced_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 11.425283285843001 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          57 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 11.202229738632838 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          58 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 8.67221999221378 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          59 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.803305121130414 -> 5.9993, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          60 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.396071379714542 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          61 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 16.936899935801822 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          62 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 18.22163706752989 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          63 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 14.75936669588089 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          64 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 14.3365294222037 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          65 10m_balanced_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 11.209692164990637 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          66 10m_balanced_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 11.420036435789532 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          67 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 11.197441310286521 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          68 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 8.67930715309249 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          69 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.807746624747912 -> 5.9993, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-4 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          70 best_high_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 13.019113233354357 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          71 best_high_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 16.929278302457597 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          72 best_high_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 18.216916818618774 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          73 best_high_accuracy_high_frequency_stationary_3 3
# 0 0
# Extrapolating from 14.752027172512479 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          74 10m_balanced_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 14.331047121683756 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          75 10m_balanced_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 11.205694982475706 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          76 10m_balanced_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 11.397702835003535 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          77 100m_lowpwr_accuracy_high_frequency_stationary_0 0
# 0 0
# Extrapolating from 11.192593916124768 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          78 100m_lowpwr_accuracy_high_frequency_stationary_1 1
# 0 0
# Extrapolating from 8.681376445558335 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          79 100m_lowpwr_accuracy_high_frequency_stationary_2 2
# 0 0
# Extrapolating from 14.808684716423352 -> 5.9993, added 0 more points
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# android dict_keys(['ucb-sdb-android-1', 'ucb-sdb-android-2', 'ucb-sdb-android-3', 'ucb-sdb-android-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          80 best_high_accuracy_medium_freq_stationary_0 0
# 0 0
# Extrapolating from 6.5201400000519225 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          81 100m_balanced_accuracy_medium_freq_stationary_0 0
# 0 0
# Extrapolating from 7.491127222180366 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          82 100m_balanced_accuracy_medium_freq_stationary_1 1
# 0 0
# Extrapolating from 7.982525555557674 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          83 100m_balanced_accuracy_medium_freq_stationary_2 2
# 0 0
# Extrapolating from 7.078653888901075 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          84 best_high_accuracy_medium_freq_stationary_1 1
# 0 0
# Extrapolating from 11.450180277758175 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          85 best_high_accuracy_medium_freq_stationary_2 2
# 0 0
# Extrapolating from 7.562115000022782 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          86 best_high_accuracy_medium_freq_stationary_3 3
# 0 0
# Extrapolating from 10.457973611089919 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          87 100m_balanced_accuracy_medium_freq_stationary_3 3
# 0 0
# Extrapolating from 10.834559722211626 -> 5.9993, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          88 best_high_accuracy_medium_freq_stationary_0 0
# 0 0
# Extrapolating from 6.513889999985695 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          89 100m_balanced_accuracy_medium_freq_stationary_0 0
# 0 0
# Extrapolating from 7.489546666675143 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          90 100m_balanced_accuracy_medium_freq_stationary_1 1
# 0 0
# Extrapolating from 7.981120000018014 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          91 100m_balanced_accuracy_medium_freq_stationary_2 2
# 0 0
# Extrapolating from 7.082855833371481 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          92 best_high_accuracy_medium_freq_stationary_1 1
# 0 0
# Extrapolating from 11.453069999946488 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          93 best_high_accuracy_medium_freq_stationary_2 2
# 0 0
# Extrapolating from 7.5615280555354225 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          94 best_high_accuracy_medium_freq_stationary_3 3
# 0 0
# Extrapolating from 10.462137499981456 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
# ...
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          112 best_high_accuracy_medium_freq_stationary_0 0
# 0 0
# Extrapolating from 6.557420085602336 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          113 100m_balanced_accuracy_medium_freq_stationary_0 0
# 0 0
# Extrapolating from 7.491461619734764 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          114 100m_balanced_accuracy_medium_freq_stationary_1 1
# 0 0
# Extrapolating from 7.971158867478371 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          115 100m_balanced_accuracy_medium_freq_stationary_2 2
# 0 0
# Extrapolating from 7.0840345780717 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          116 best_high_accuracy_medium_freq_stationary_1 1
# 0 0
# Extrapolating from 11.442585229741203 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          117 best_high_accuracy_medium_freq_stationary_2 2
# 0 0
# Extrapolating from 7.566233150826561 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          118 best_high_accuracy_medium_freq_stationary_3 3
# 0 0
# Extrapolating from 10.454880657460954 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          119 100m_balanced_accuracy_medium_freq_stationary_3 3
# 0 0
# Extrapolating from 10.84414417054918 -> 5.9993, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          120 best_high_accuracy_medium_freq_stationary_0 0
# 0 0
# Extrapolating from 6.543577901389864 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          121 100m_balanced_accuracy_medium_freq_stationary_0 0
# 0 0
# Extrapolating from 7.490864061117172 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          122 100m_balanced_accuracy_medium_freq_stationary_1 1
# 0 0
# Extrapolating from 7.970798551109102 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          123 100m_balanced_accuracy_medium_freq_stationary_2 2
# 0 0
# Extrapolating from 7.083090979788039 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          124 best_high_accuracy_medium_freq_stationary_1 1
# 0 0
# Extrapolating from 11.445317491094272 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          125 best_high_accuracy_medium_freq_stationary_2 2
# 0 0
# Extrapolating from 7.566074211332533 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          126 best_high_accuracy_medium_freq_stationary_3 3
# 0 0
# Extrapolating from 10.45554954191049 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          127 100m_balanced_accuracy_medium_freq_stationary_3 3
# 0 0
# Extrapolating from 10.840834358665678 -> 5.9993, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          128 best_high_accuracy_medium_freq_stationary_0 0
# 0 0
# Extrapolating from 6.535768008629481 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          129 100m_balanced_accuracy_medium_freq_stationary_0 0
# 0 0
# Extrapolating from 7.490807160867585 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          130 100m_balanced_accuracy_medium_freq_stationary_1 1
# 0 0
# Extrapolating from 7.975897428923183 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          131 100m_balanced_accuracy_medium_freq_stationary_2 2
# 0 0
# Extrapolating from 7.083024351133241 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          132 best_high_accuracy_medium_freq_stationary_1 1
# 0 0
# Extrapolating from 11.449623101353644 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          133 best_high_accuracy_medium_freq_stationary_2 2
# 0 0
# Extrapolating from 7.565235720872879 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          134 best_high_accuracy_medium_freq_stationary_3 3
# 0 0
# Extrapolating from 10.456792466110654 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          135 100m_balanced_accuracy_medium_freq_stationary_3 3
# 0 0
# Extrapolating from 10.839462397760816 -> 5.9993, added 0 more points
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-4 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          136 best_high_accuracy_medium_freq_stationary_0 0
# 0 0
# Extrapolating from 6.525805333587859 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          137 100m_balanced_accuracy_medium_freq_stationary_0 0
# 0 0
# Extrapolating from 7.491791477534506 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          138 100m_balanced_accuracy_medium_freq_stationary_1 1
# 0 0
# Extrapolating from 7.981931114196778 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          139 100m_balanced_accuracy_medium_freq_stationary_2 2
# 0 0
# Extrapolating from 7.0808437975247704 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          140 best_high_accuracy_medium_freq_stationary_1 1
# 0 0
# Extrapolating from 11.450508624977536 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          141 best_high_accuracy_medium_freq_stationary_2 2
# 0 0
# Extrapolating from 7.565410946077771 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          142 best_high_accuracy_medium_freq_stationary_3 3
# 0 0
# Extrapolating from 10.456845763325692 -> 5.9993, added 0 more points
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          143 100m_balanced_accuracy_medium_freq_stationary_3 3
# 0 0
# Extrapolating from 10.836675482193629 -> 5.9993, added 0 more points
# 0
# []

# %%
battery_df = [r for r in pv_hf.map()["android"]["ucb-sdb-android-2"]["calibration_ranges"] if r["trip_id"] == "best_high_accuracy_high_frequency_stationary_0"][0]["battery_df"]
battery_fn = sci.interp1d(battery_df.hr, battery_df.battery_level_pct, fill_value="extrapolate")
hr_range = pd.Series(np.arange(battery_df.hr.min(), 12, 60 / (60 * 60))) # 1 minute
interp_battery_level = pd.Series(battery_fn(hr_range))
changes = interp_battery_level.diff(); changes.tail()
extrapolated_changes = changes[hr_range > battery_df.hr.max()]; extrapolated_changes.tail()
print("Extrapolating from %s -> %s, added %d more points" % (battery_df.hr.max(), 12, len(extrapolated_changes)))
print(len(extrapolated_changes), np.count_nonzero(extrapolated_changes))
# Out:
# Extrapolating from 13.49737972219785 -> 12, added 0 more points
# 0 0

# %%
ifig, ax = plt.subplots(nrows=1, ncols=1, figsize=(16,8))
ax.plot(battery_df.hr, battery_df.battery_level_pct, color="green")
ax.plot(hr_range, interp_battery_level, color="red")

# %% [markdown]
# ## Now to actually interpolate based on the min

# %%
def get_interpolated_battery_drain_at_duration(pv, hr_from_start):
    interpolated_battery_levels = []
    for phone_os, phone_map in pv.map().items():
        print(15 * "=*")
        print(phone_os, phone_map.keys())
        for phone_label, phone_detail_map in phone_map.items():
            print(4 * ' ', 15 * "-*")
            print(4 * ' ', phone_label, phone_detail_map.keys())
            for r in phone_detail_map["calibration_ranges"]:
                print(8 * ' ', 30 * "=")
                print(8 * ' ',r.keys())
                print(8 * ' ',r["trip_id"], r["trip_run"])
                battery_df = r["battery_df"]
                battery_fn = sci.interp1d(battery_df.hr, battery_df.battery_level_pct, fill_value="extrapolate")
                level_at_hr_from_start = battery_fn(hr_from_start)
                print("observed delta = %s at %s, predicted delta = %s at %s" % 
                      (battery_df.battery_level_pct.iloc[-1], battery_df.hr.max(),
                       level_at_hr_from_start, hr_from_start))
                interpolated_battery_levels.append((battery_df.battery_level_pct.iloc[0] - level_at_hr_from_start))
    return interpolated_battery_levels

# %%
all_interpolated_battery_levels = []
all_interpolated_battery_levels.extend(get_interpolated_battery_drain_at_duration(pv_hf, battery_drain_df.duration.min()/(60 * 60)))
all_interpolated_battery_levels.extend(get_interpolated_battery_drain_at_duration(pv_mf, battery_drain_df.duration.min()/(60 * 60)))
battery_drain_df["battery_drain"] = all_interpolated_battery_levels
# Out:
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# android dict_keys(['ucb-sdb-android-1', 'ucb-sdb-android-2', 'ucb-sdb-android-3', 'ucb-sdb-android-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# observed delta = 75 at 13.498125555581517, predicted delta = 87.06312256253044 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# observed delta = 74 at 17.088379722237587, predicted delta = 87.09717101965978 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# observed delta = 73 at 18.230365833308962, predicted delta = 86.052924239096 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# observed delta = 74 at 15.731736944450272, predicted delta = 85.53380635729548 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# observed delta = 90 at 14.043885833356116, predicted delta = 94.1354149270659 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# observed delta = 92 at 11.502462500002649, predicted delta = 95.02363967968145 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# observed delta = 88 at 11.907108055551847, predicted delta = 92.58940329255759 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# observed delta = 90 at 11.886542777750227, predicted delta = 93.90405427914637 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# observed delta = 92 at 8.682198333276643, predicted delta = 94.51606884802837 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# observed delta = 90 at 14.814498611092567, predicted delta = 95.68760500313101 at 6.495345277786255
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# observed delta = 78 at 13.49737972219785, predicted delta = 85.93852558503079 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# observed delta = 73 at 17.0932408333487, predicted delta = 86.96234443142386 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# observed delta = 77 at 14.361134166651302, predicted delta = 86.18652761954927 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# observed delta = 76 at 15.736159166693687, predicted delta = 86.43210370822901 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# observed delta = 90 at 14.624623888863457, predicted delta = 94.79408769655734 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# observed delta = 92 at 11.500974722239706, predicted delta = 95.19703586616511 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# observed delta = 88 at 11.905499444471465, predicted delta = 92.7914524602626 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# observed delta = 93 at 7.948053888877233, predicted delta = 94.44346241144056 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# observed delta = 92 at 8.686896388861868, predicted delta = 94.6325916288819 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# observed delta = 89 at 14.814684722224872, predicted delta = 94.07707245604894 at 6.495345277786255
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# observed delta = 81 at 13.500068888862927, predicted delta = 87.74247673450536 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# observed delta = 77 at 14.067187777757646, predicted delta = 86.08634306846452 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# observed delta = 72 at 18.23671083331108, predicted delta = 85.17793417375903 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# observed delta = 73 at 15.088655555579397, predicted delta = 82.6141566901805 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# observed delta = 89 at 13.941046666635406, predicted delta = 94.34764526073255 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# observed delta = 91 at 11.507792222234938, predicted delta = 95.01926390307945 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# observed delta = 88 at 11.902277499967152, predicted delta = 92.64058052486868 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# observed delta = 91 at 8.08435333331426, predicted delta = 93.30061559429173 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# observed delta = 92 at 8.697577222188313, predicted delta = 94.44707801882335 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# observed delta = 88 at 14.818691111140781, predicted delta = 93.50243217249418 at 6.495345277786255
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-4 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# observed delta = 82 at 13.496322499977218, predicted delta = 88.58177594197242 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# observed delta = 72 at 17.09900972220633, predicted delta = 86.23512593832697 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# observed delta = 81 at 13.64355555554231, predicted delta = 88.19263379306376 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# observed delta = 78 at 15.745849999984106, predicted delta = 87.81181130179752 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# observed delta = 92 at 14.040876944462457, predicted delta = 95.76234128341993 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# observed delta = 90 at 11.507233888904254, predicted delta = 93.74040057397794 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# observed delta = 87 at 11.902532777786256, predicted delta = 91.84766508046658 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# observed delta = 91 at 11.371133888893658, predicted delta = 95.15204107926098 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# observed delta = 89 at 8.705315833356645, predicted delta = 91.35184844622084 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# observed delta = 82 at 14.819372222224871, predicted delta = 91.0359018766706 at 6.495345277786255
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# ios dict_keys(['ucb-sdb-ios-1', 'ucb-sdb-ios-2', 'ucb-sdb-ios-3', 'ucb-sdb-ios-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# observed delta = 46.99999988079071 at 13.07243064529366, predicted delta = 76.30628093826799 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# observed delta = 30.000001192092896 at 16.940984596676298, predicted delta = 77.22574668039414 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# observed delta = 27.000001072883606 at 17.23742698278692, predicted delta = 75.70940144310275 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# observed delta = 40.99999964237213 at 14.77369592030843, predicted delta = 78.11450404888309 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# observed delta = 40.99999964237213 at 14.348824674950706, predicted delta = 76.41457616148813 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# observed delta = 52.99999713897705 at 11.22411902387937, predicted delta = 74.6429824201003 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# observed delta = 50.999999046325684 at 11.429518936342664, predicted delta = 73.73710970447382 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# observed delta = 86.00000143051147 at 11.206751536130906, predicted delta = 92.71118646012964 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# observed delta = 89.99999761581421 at 8.667382423347897, predicted delta = 93.3408567480163 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# observed delta = 80.0000011920929 at 14.798938638634151, predicted delta = 94.02086712986923 at 6.495345277786255
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# observed delta = 50.0 at 13.387402730517918, predicted delta = 77.96808428398091 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# observed delta = 40.00000059604645 at 16.945419379207824, predicted delta = 79.75617178746535 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# observed delta = 41.999998688697815 at 17.22674541917112, predicted delta = 80.19537440034783 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# observed delta = 46.99999988079071 at 14.766585088306003, predicted delta = 80.0852300730637 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# observed delta = 46.00000083446503 at 14.34165147225062, predicted delta = 80.23140187614912 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# observed delta = 60.00000238418579 at 11.218273564179738, predicted delta = 78.89039237066908 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# observed delta = 56.00000023841858 at 11.425283285843001, predicted delta = 77.65048043989806 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# observed delta = 87.99999952316284 at 11.202229738632838, predicted delta = 95.41354835057588 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# observed delta = 88.99999856948853 at 8.67221999221378, predicted delta = 92.16692600279576 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# observed delta = 80.0000011920929 at 14.803305121130414, predicted delta = 92.0340460547325 at 6.495345277786255
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# observed delta = 28.00000011920929 at 13.396071379714542, predicted delta = 68.250278702708 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# observed delta = 28.00000011920929 at 16.936899935801822, predicted delta = 75.72405195091547 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# observed delta = 28.999999165534973 at 18.22163706752989, predicted delta = 76.90586035087529 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# observed delta = 38.999998569488525 at 14.75936669588089, predicted delta = 76.05689024047066 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# observed delta = 43.00000071525574 at 14.3365294222037, predicted delta = 77.36443864526107 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# observed delta = 56.00000023841858 at 11.209692164990637, predicted delta = 76.57097334688099 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# observed delta = 55.000001192092896 at 11.420036435789532, predicted delta = 77.6241033263063 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# observed delta = 85.00000238418579 at 11.197441310286521, predicted delta = 92.70218312356593 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# observed delta = 86.00000143051147 at 8.67930715309249, predicted delta = 92.3272846787304 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# observed delta = 62.99999952316284 at 14.807746624747912, predicted delta = 89.0431926395038 at 6.495345277786255
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-4 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_0 0
# observed delta = 43.00000071525574 at 13.019113233354357, predicted delta = 73.6161693419451 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_1 1
# observed delta = 25.999999046325684 at 16.929278302457597, predicted delta = 75.11594106282557 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_2 2
# observed delta = 20.999999344348907 at 18.216916818618774, predicted delta = 75.60911937766558 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_high_frequency_stationary_3 3
# observed delta = 36.000001430511475 at 14.752027172512479, predicted delta = 75.29587697673368 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_0 0
# observed delta = 49.000000953674316 at 14.331047121683756, predicted delta = 80.34267965978437 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_1 1
# observed delta = 52.99999713897705 at 11.205694982475706, predicted delta = 74.54983689340115 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          10m_balanced_accuracy_high_frequency_stationary_2 2
# observed delta = 50.0 at 11.397702835003535, predicted delta = 73.52793607348586 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_0 0
# observed delta = 85.00000238418579 at 11.192593916124768, predicted delta = 93.39382808035205 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_1 1
# observed delta = 87.99999952316284 at 8.681376445558335, predicted delta = 92.33547188811305 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_lowpwr_accuracy_high_frequency_stationary_2 2
# observed delta = 77.99999713897705 at 14.808684716423352, predicted delta = 93.01147261085195 at 6.495345277786255
# =*=*=*=*=*=*=*=*=*=*=*=*=*=*=*
# android dict_keys(['ucb-sdb-android-1', 'ucb-sdb-android-2', 'ucb-sdb-android-3', 'ucb-sdb-android-4'])
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-1 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_0 0
# observed delta = 96 at 6.5201400000519225, predicted delta = 96.0189847343594 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_0 0
# observed delta = 93 at 7.491127222180366, predicted delta = 94.18011945623536 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_1 1
# observed delta = 93 at 7.982525555557674, predicted delta = 94.07182664438888 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_2 2
# observed delta = 95 at 7.078653888901075, predicted delta = 95.35985675171305 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_1 1
# observed delta = 89 at 11.450180277758175, predicted delta = 94.87052633980889 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_2 2
# observed delta = 93 at 7.562115000022782, predicted delta = 93.60180165885554 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_3 3
# observed delta = 92 at 10.457973611089919, predicted delta = 93.72553363466254 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_3 3
# observed delta = 91 at 10.834559722211626, predicted delta = 94.75810442692352 at 6.495345277786255
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-android-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_0 0
# observed delta = 96 at 6.513889999985695, predicted delta = 96.0142229862876 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_0 0
# observed delta = 93 at 7.489546666675143, predicted delta = 94.19464878678971 at 6.495345277786255
# ...
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_1 1
# observed delta = 91.00000262260437 at 7.971158867478371, predicted delta = 93.83012236789529 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_2 2
# observed delta = 92.00000166893005 at 7.0840345780717, predicted delta = 92.98626677818574 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_1 1
# observed delta = 55.000001192092896 at 11.442585229741203, predicted delta = 76.80077125597188 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_2 2
# observed delta = 70.99999785423279 at 7.566233150826561, predicted delta = 75.60307571074695 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_3 3
# observed delta = 50.999999046325684 at 10.454880657460954, predicted delta = 70.30053787396015 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_3 3
# observed delta = 74.00000095367432 at 10.84414417054918, predicted delta = 82.86261214471766 at 6.495345277786255
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-2 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_0 0
# observed delta = 82.99999833106995 at 6.543577901389864, predicted delta = 83.1697267892283 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_0 0
# observed delta = 92.00000166893005 at 7.490864061117172, predicted delta = 95.1215083212514 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_1 1
# observed delta = 93.00000071525574 at 7.970798551109102, predicted delta = 94.81758620934602 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_2 2
# observed delta = 93.99999976158142 at 7.083090979788039, predicted delta = 94.97703764215125 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_1 1
# observed delta = 63.999998569488525 at 11.445317491094272, predicted delta = 82.42977222735554 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_2 2
# observed delta = 77.99999713897705 at 7.566074211332533, predicted delta = 81.34969016540097 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_3 3
# observed delta = 64.99999761581421 at 10.45554954191049, predicted delta = 77.61827749568131 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_3 3
# observed delta = 83.99999737739563 at 10.840834358665678, predicted delta = 90.85354745044451 at 6.495345277786255
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-3 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_0 0
# observed delta = 76.99999809265137 at 6.535768008629481, predicted delta = 77.14142166530411 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_0 0
# observed delta = 87.99999952316284 at 7.490807160867585, predicted delta = 90.11569207177135 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_1 1
# observed delta = 86.00000143051147 at 7.975897428923183, predicted delta = 89.20786391579753 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_2 2
# observed delta = 81.99999928474426 at 7.083024351133241, predicted delta = 83.93691820710035 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_1 1
# observed delta = 55.000001192092896 at 11.449623101353644, predicted delta = 77.41801821466017 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_2 2
# observed delta = 72.00000286102295 at 7.565235720872879, predicted delta = 76.45135443680105 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_3 3
# observed delta = 51.99999809265137 at 10.456792466110654, predicted delta = 70.25201238723234 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_3 3
# observed delta = 70.99999785423279 at 10.839462397760816, predicted delta = 82.75287884030148 at 6.495345277786255
#      -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#      ucb-sdb-ios-4 dict_keys(['role', 'transitions', 'calibration_transitions', 'calibration_ranges', 'evaluation_transitions', 'evaluation_ranges'])
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_0 0
# observed delta = 75.99999904632568 at 6.525805333587859, predicted delta = 76.15911261528571 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_0 0
# observed delta = 91.00000262260437 at 7.491791477534506, predicted delta = 93.0551099304246 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_1 1
# observed delta = 89.99999761581421 at 7.981931114196778, predicted delta = 92.39780584077133 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_2 2
# observed delta = 91.00000262260437 at 7.0808437975247704, predicted delta = 91.96075538663808 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_1 1
# observed delta = 52.99999713897705 at 11.450508624977536, predicted delta = 76.4120939340768 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_2 2
# observed delta = 70.99999785423279 at 7.565410946077771, predicted delta = 75.43644675681396 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          best_high_accuracy_medium_freq_stationary_3 3
# observed delta = 49.000000953674316 at 10.456845763325692, predicted delta = 67.23794233392499 at 6.495345277786255
#          ==============================
#          dict_keys(['trip_id', 'trip_id_base', 'trip_run', 'start_ts', 'end_ts', 'duration', 'battery_entries', 'battery_df', 'location_entries', 'filtered_location_entries', 'location_df', 'filtered_location_df', 'motion_activity_entries', 'motion_activity_df', 'transition_entries', 'transition_df'])
#          100m_balanced_accuracy_medium_freq_stationary_3 3
# observed delta = 73.00000190734863 at 10.836675482193629, predicted delta = 81.81968127823829 at 6.495345277786255

# %%
battery_drain_df["phone_idx"] = battery_drain_df.phone_label.apply(lambda l: l.split("-")[-1])

# %%
battery_drain_df.head()
# Out:
#    accuracy accuracy_str  battery_drain_observed  \
# 0         2         high                    25.0
# 1         2         high                    26.0
# 2         2         high                    27.0
# 3         2         high                    26.0
# 4         1     balanced                    10.0
#
#                                               config  duration  frequency  \
# 0     best_high_accuracy_high_frequency_stationary_0   48602.0          2
# 1     best_high_accuracy_high_frequency_stationary_1   61527.0          2
# 2     best_high_accuracy_high_frequency_stationary_2   65632.0          2
# 3     best_high_accuracy_high_frequency_stationary_3   56641.0          2
# 4  10m_balanced_accuracy_high_frequency_stationary_0   52652.0          2
#
#   frequency_str        phone_label phone_os  run  battery_drain phone_idx
# 0          high  ucb-sdb-android-1  android    0      12.936877         1
# 1          high  ucb-sdb-android-1  android    1      12.902829         1
# 2          high  ucb-sdb-android-1  android    2      13.947076         1
# 3          high  ucb-sdb-android-1  android    3      14.466194         1
# 4          high  ucb-sdb-android-1  android    0       5.864585         1

# %%
battery_drain_df.replace("balanced", "balpwr", inplace=True)
battery_drain_df.replace("medium", "med", inplace=True)

# %%
ifig, ax_array = plt.subplots(nrows=1,ncols=2,figsize=(12,3), sharex=False, sharey=True)
battery_drain_df.query("phone_os == 'android'").boxplot(ax=ax_array[0], column=["battery_drain"], by=["accuracy_str", "frequency_str"])
battery_drain_df.query("phone_os == 'ios'").boxplot(ax=ax_array[1], column=["battery_drain"], by=["accuracy_str", "frequency_str"])
for ax in ax_array:
    ax.set_xlabel("[accuracy, frequency]")

ax_array[0].set_title("android")
ax_array[1].set_title("ios")
ax_array[0].set_ylabel("Battery drain (%)")
ifig.suptitle("Drain for various accuracy/frequency combinations")

# ifig.tight_layout()
# Out:
# /Users/shankari/OSS/anaconda/envs/emissioneval/lib/python3.6/site-packages/numpy/core/fromnumeric.py:56: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# /Users/shankari/OSS/anaconda/envs/emissioneval/lib/python3.6/site-packages/numpy/core/fromnumeric.py:56: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# Text(0.5, 0.98, 'Drain for various accuracy/frequency combinations')

# %%
ifig, ax_array = plt.subplots(nrows=2,ncols=2,figsize=(10,5), sharex=True, sharey=True)
battery_drain_df.query("(phone_os == 'android' & accuracy==2 & frequency==2)").boxplot(ax=ax_array[0][0], column=["battery_drain"], by=["phone_idx"])
battery_drain_df.query("(phone_os == 'ios' & (accuracy != 0))").boxplot(ax=ax_array[0][1], column=["battery_drain"], by=["phone_idx"])
battery_drain_df.query("(phone_os == 'android' & (accuracy!=2 | frequency!=2))").boxplot(ax=ax_array[1][0], column=["battery_drain"], by=["phone_idx"])
battery_drain_df.query("(phone_os == 'ios' & (accuracy == 0))").boxplot(ax=ax_array[1][1], column=["battery_drain"], by=["phone_idx"])

ax_array[0][0].set_title("High power, high frequency (android)")
ax_array[0][0].set_xlabel("")
ax_array[0][1].set_title("High/10m accuracy (ios)")
ax_array[0][1].set_xlabel("")
ax_array[0][0].set_ylabel("Battery drain (%)")
ax_array[1][0].set_title("Medium accuracy/frequency (android)")
ax_array[1][1].set_title("Medium accuracy (ios)")
ax_array[1][0].set_ylabel("Battery drain (%)")

ifig.suptitle("Difference in power drain across phones for adjustment")
# Out:
# Text(0.5, 0.98, 'Difference in power drain across phones for adjustment')

# %%
battery_drain_df.query("(phone_os == 'ios' & (accuracy != 0))").groupby("phone_idx").battery_drain.median()
# Out:
# phone_idx
# 1    23.739051
# 2    19.914770
# 3    23.429027
# 4    24.704123
# Name: battery_drain, dtype: float64

# %%
battery_drain_df.query("(phone_os == 'ios' & (accuracy == 0))").groupby("phone_idx").battery_drain.median()
# Out:
# phone_idx
# 1     6.659143
# 2     5.182414
# 3    10.792136
# 4     7.602194
# Name: battery_drain, dtype: float64

# %%
ifig, ax_array = plt.subplots(nrows=2,ncols=1,figsize=(16,8), sharex=False, sharey=True, )
battery_drain_df.query("phone_os == 'android'").boxplot(ax=ax_array[0], column=["battery_drain"], by=["accuracy", "frequency", "phone_idx"])
battery_drain_df.query("phone_os == 'ios'").boxplot(ax=ax_array[1], column=["battery_drain"], by=["accuracy", "frequency", "phone_idx"])

for ax in ax_array:
    ax.set_title("")
    ax.set_ylabel("Battery drain")

ax_array[0].set_title("accuracy = {0: lowpwr, 1: balanced, 2: high}, frequency = {1: medium, 2: high}")
ax_array[1].set_title("accuracy = {0: 100m, 1: 10m, 2: high}, frequency = {1: medium, 2: high}")
ifig.tight_layout(pad=3)
# Out:
# /Users/shankari/OSS/anaconda/envs/emissioneval/lib/python3.6/site-packages/numpy/core/fromnumeric.py:56: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# /Users/shankari/OSS/anaconda/envs/emissioneval/lib/python3.6/site-packages/numpy/core/fromnumeric.py:56: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
battery_drain_df.query("phone_os == 'ios' & accuracy == 1 & frequency == 2 & phone_label == 'ucb-sdb-ios-4'").battery_drain.describe()
# Out:
# count     3.000000
# mean     23.859849
# std       3.675188
# min      19.657320
# 25%      22.553742
# 50%      25.450163
# 75%      25.961114
# max      26.472064
# Name: battery_drain, dtype: float64

# %%
ifig, ax_array = plt.subplots(nrows=2,ncols=1,figsize=(16,8), sharex=False, sharey=True)
battery_drain_df.query("phone_os == 'android'").boxplot(ax=ax_array[0], column=["battery_drain"], by=["accuracy", "frequency", "phone_idx"])
battery_drain_df.query("phone_os == 'ios'").boxplot(ax=ax_array[1], column=["battery_drain"], by=["accuracy", "frequency", "phone_idx"])

for ax in ax_array:
    ax.set_title("")
    ax.set_ylabel("Battery drain")

ax_array[0].set_title("accuracy = {0: lowpwr, 1: balanced, 2: high}, frequency = {1: medium, 2: high}")
ax_array[1].set_title("accuracy = {0: 100m, 1: 10m, 2: high}, frequency = {1: medium, 2: high}")
# Out:
# /Users/shankari/OSS/anaconda/envs/emissioneval/lib/python3.6/site-packages/numpy/core/fromnumeric.py:56: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# /Users/shankari/OSS/anaconda/envs/emissioneval/lib/python3.6/site-packages/numpy/core/fromnumeric.py:56: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# Text(0.5, 1.0, 'accuracy = {0: 100m, 1: 10m, 2: high}, frequency = {1: medium, 2: high}')

# %%
ifig, ax_array = plt.subplots(nrows=2,ncols=2,figsize=(16,8), sharex=False, sharey=True)
battery_drain_df.query("phone_os == 'android' & accuracy==2 & frequency==2").boxplot(ax=ax_array[0][0], column=["battery_drain"], by=["run"])
battery_drain_df.query("phone_os == 'ios' & accuracy==2 & frequency==2").boxplot(ax=ax_array[1][0], column=["battery_drain"], by=["run"])
battery_drain_df.query("phone_os == 'android' & accuracy==2 & frequency==2").boxplot(ax=ax_array[0][1], column=["battery_drain"], by=["phone_idx"])
battery_drain_df.query("phone_os == 'ios' & accuracy==2 & frequency==2").boxplot(ax=ax_array[1][1], column=["battery_drain"], by=["phone_idx"])

# for ax in ax_array:
#     ax.set_title("")
#     ax.set_ylabel("Battery drain")

ifig.tight_layout(pad=2)
