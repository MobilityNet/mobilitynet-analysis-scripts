# %% [markdown]
# This notebook demonstrates the result of the first round of data collection, collected in the San Francisco Bay Area by @shankari. The round had several shortcomings, some of which were addressed during the data collection and some of which were fixed before starting the second round of data collection.

# %% [markdown]
# ## Import all the dependencies

# %%
# for reading and validating data
import emeval.input.spec_details as eisd
import emeval.input.phone_view as eipv
import emeval.input.eval_view as eiev

# %%
# Visualization helpers
import emeval.viz.phone_view as ezpv
import emeval.viz.eval_view as ezev

# %%
# For plots
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# For maps
import branca.element as bre

# %%
# For displaying dates
import arrow

# %% [markdown]
# ## Load and validate data
#
# The first issue to note is that we actually have two specs here. The first spec is the checked in `evaluation.spec.sample`, which defines calibration for both stationary and moving instances, and some evaluation trips. However, while starting with the calibration, we noticed some inconsistencies between the power curves. So in order to be more consistent, I defined a second, calibration-only spec `examples/calibration.only.json`, which essentially repeats the calibration experiments multiple times.
#
# After that, I returned to the first set of experiments for the moving calibration and the evaluation.

# %%
DATASTORE_URL = "http://cardshark.cs.berkeley.edu"
AUTHOR_EMAIL = "shankari@eecs.berkeley.edu"
sdmco1 = eisd.SpecDetails(DATASTORE_URL, AUTHOR_EMAIL, "sfba_med_freq_calibration_only")
# Out:
# About to retrieve messages using {'user': 'shankari@eecs.berkeley.edu', 'key_list': ['config/evaluation_spec'], 'start_time': 0, 'end_time': 1564174699}
# response = <Response [200]>
# Found 9 entries
# After iterating over 9 entries, entry found
# Found spec = Calibration for medium frequencies only, trial #1
# Evaluation ran from 2019-07-17T17:00:00-07:00 -> 2019-07-28T17:00:00-07:00

# %%
import importlib
importlib.reload(ezev)
# Out:
# <module 'emeval.viz.eval_view' from '/Users/shankari/e-mission/e-mission-eval-public-data/emeval/viz/eval_view.py'>

# %%
pvmco1 = eipv.PhoneView(sdmco1)
# Out:
# -------------------- About to read transitions from server --------------------
# Reading data for android phones
# Loading transitions for phone ucb-sdb-android-1
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563408000, 'end_time': 1564358400}
# response = <Response [200]>
# Found 37 entries
# Loading transitions for phone ucb-sdb-android-2
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563408000, 'end_time': 1564358400}
# response = <Response [200]>
# Found 27 entries
# Loading transitions for phone ucb-sdb-android-3
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563408000, 'end_time': 1564358400}
# response = <Response [200]>
# Found 29 entries
# Loading transitions for phone ucb-sdb-android-4
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563408000, 'end_time': 1564358400}
# response = <Response [200]>
# Found 27 entries
# Reading data for ios phones
# Loading transitions for phone ucb-sdb-ios-1
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563408000, 'end_time': 1564358400}
# response = <Response [200]>
# Found 250 entries
# Loading transitions for phone ucb-sdb-ios-2
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563408000, 'end_time': 1564358400}
# response = <Response [200]>
# Found 25 entries
# Loading transitions for phone ucb-sdb-ios-3
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563408000, 'end_time': 1564358400}
# response = <Response [200]>
# Found 24 entries
# Loading transitions for phone ucb-sdb-ios-4
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['manual/evaluation_transition'], 'start_time': 1563408000, 'end_time': 1564358400}
# response = <Response [200]>
# Found 25 entries
# -------------------- About to fill calibration ranges --------------------
# Processing data for android phones
# Processing transitions for phone ucb-sdb-android-1
# Filtered 37 total -> 12 calibration transitions
# Processing transitions for phone ucb-sdb-android-2
# Filtered 27 total -> 12 calibration transitions
# Processing transitions for phone ucb-sdb-android-3
# Filtered 29 total -> 12 calibration transitions
# Processing transitions for phone ucb-sdb-android-4
# Filtered 27 total -> 12 calibration transitions
# Processing data for ios phones
# Processing transitions for phone ucb-sdb-ios-1
# Filtered 250 total -> 12 calibration transitions
# Processing transitions for phone ucb-sdb-ios-2
# Filtered 25 total -> 12 calibration transitions
# Processing transitions for phone ucb-sdb-ios-3
# Filtered 24 total -> 12 calibration transitions
# Processing transitions for phone ucb-sdb-ios-4
# Filtered 25 total -> 12 calibration transitions
# Processing data for android phones
# ---------- ucb-sdb-android-1
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563678069.846, 1563678069.847)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563699745.832, 1563699745.856)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563699745.832, 1563699745.922)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563723197.975, 1563723198.019)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563764613.22, 1563764613.222)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563788085.722, 1563788085.749)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563788085.722, 1563788085.765)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563811841.763, 1563811841.83)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563863231.363, 1563863231.367)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563890199.422, 1563890199.48)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563944815.917, 1563944815.921)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563973553.011, 1563973553.057)
# All ranges are complete, nothing to change
# {'high_accuracy_stationary_2', 'high_accuracy_stationary_1', 'medium_accuracy_stationary_1', 'high_accuracy_stationary_0', 'medium_accuracy_stationary_2', 'medium_accuracy_stationary_0'}
# Found 6 ranges of duration [21676.009000062943, 23452.09700012207, 23472.527000188828, 23756.064999818802, 26968.112999916077, 28737.135999917984] for phone ucb-sdb-android-1
# ---------- ucb-sdb-android-2
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563678102.451, 1563678102.453)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563699755.377, 1563699755.407)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563699755.378, 1563699755.418)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563723238.379, 1563723238.421)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563764643.839, 1563764643.841)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563788093.839, 1563788093.89)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563788093.839, 1563788093.912)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563811869.957, 1563811870.005)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563863242.739, 1563863242.745)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563890205.11, 1563890205.16)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563944837.095, 1563944837.097)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563973569.127, 1563973569.17)
# All ranges are complete, nothing to change
# {'high_accuracy_stationary_2', 'high_accuracy_stationary_1', 'medium_accuracy_stationary_1', 'high_accuracy_stationary_0', 'medium_accuracy_stationary_2', 'medium_accuracy_stationary_0'}
# Found 6 ranges of duration [21652.953999996185, 23483.00300002098, 23450.049000024796, 23776.09300017357, 26962.41500020027, 28732.073000192642] for phone ucb-sdb-android-2
# ---------- ucb-sdb-android-3
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563678138.478, 1563678138.481)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563699770.132, 1563699770.145)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563699770.132, 1563699770.158)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563723262.754, 1563723262.853)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563764686.3, 1563764686.301)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563788105.529, 1563788105.544)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563788105.53, 1563788105.567)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563811900.638, 1563811900.716)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563863272.654, 1563863272.656)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563890214.712, 1563890214.77)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563944862.978, 1563944862.98)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563973599.101, 1563973599.147)
# All ranges are complete, nothing to change
# {'high_accuracy_stationary_2', 'high_accuracy_stationary_1', 'medium_accuracy_stationary_1', 'high_accuracy_stationary_0', 'medium_accuracy_stationary_2', 'medium_accuracy_stationary_0'}
# Found 6 ranges of duration [21631.664000034332, 23492.694999933243, 23419.2429997921, 23795.149000167847, 26942.114000082016, 28736.167000055313] for phone ucb-sdb-android-3
# ---------- ucb-sdb-android-4
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563678172.407, 1563678172.409)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563699770.132, 1563699770.145)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563699770.132, 1563699770.158)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563723280.624, 1563723280.659)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563764729.725, 1563764729.726)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563788112.947, 1563788112.969)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563788112.948, 1563788112.982)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563811918.356, 1563811918.395)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563863286.924, 1563863286.928)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563890220.941, 1563890220.992)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563944882.312, 1563944882.313)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563973623.388, 1563973623.433)
# All ranges are complete, nothing to change
# {'high_accuracy_stationary_2', 'high_accuracy_stationary_1', 'medium_accuracy_stationary_1', 'high_accuracy_stationary_0', 'medium_accuracy_stationary_2', 'medium_accuracy_stationary_0'}
# Found 6 ranges of duration [21597.736000061035, 23510.50099992752, 23383.243000030518, 23805.412999868393, 26934.0640001297, 28741.120000123978] for phone ucb-sdb-android-4
# Processing data for ios phones
# ---------- ucb-sdb-ios-1
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563677924.865, 1563677924.975976)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563699690.367, 1563699690.424344)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563699690.368, 1563699690.439348)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563723120.932, 1563723121.389519)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563764431.854, 1563764432.001042)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563788038.663, 1563788038.733817)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563788038.663, 1563788038.751368)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563811760.461, 1563811760.9548712)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563863188.466, 1563863188.598661)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563890157.577, 1563890158.048438)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563944726.821, 1563944726.909893)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563973422.83, 1563973423.3017302)
# All ranges are complete, nothing to change
# {'high_accuracy_stationary_2', 'high_accuracy_stationary_1', 'medium_accuracy_stationary_1', 'high_accuracy_stationary_0', 'medium_accuracy_stationary_2', 'medium_accuracy_stationary_0'}
# Found 6 ranges of duration [21765.44836807251, 23430.950170993805, 23606.732775211334, 23722.203503131866, 26969.449777126312, 28696.391837120056] for phone ucb-sdb-ios-1
# ---------- ucb-sdb-ios-2
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563677969.589, 1563677969.681895)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563699714.093, 1563699714.155782)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563699714.094, 1563699714.171499)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563723133.653, 1563723134.096898)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563764493.88, 1563764493.97196)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563788050.809, 1563788050.872571)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563788050.809, 1563788050.884784)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563811785.152, 1563811785.615035)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563863200.198, 1563863200.2893429)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563890167.144, 1563890167.611793)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563944748.355, 1563944748.4612122)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563973443.111, 1563973443.5124102)
# All ranges are complete, nothing to change
# {'high_accuracy_stationary_2', 'high_accuracy_stationary_1', 'medium_accuracy_stationary_1', 'high_accuracy_stationary_0', 'medium_accuracy_stationary_2', 'medium_accuracy_stationary_0'}
# Found 6 ranges of duration [21744.473886966705, 23419.925399065018, 23556.900610923767, 23734.730251073837, 26967.32245016098, 28695.051198005676] for phone ucb-sdb-ios-2
# ---------- ucb-sdb-ios-3
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563678000.921, 1563678001.0133371)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563699728.174, 1563699728.2465448)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563699728.175, 1563699728.266931)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563723141.563, 1563723141.958624)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563764533.076, 1563764533.214622)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563788061.933, 1563788061.999584)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563788061.933, 1563788062.0158339)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563811802.202, 1563811802.696847)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563863210.89, 1563863211.0520248)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563890177.684, 1563890178.148947)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563944770.573, 1563944770.673845)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563973483.636, 1563973484.065419)
# All ranges are complete, nothing to change
# {'high_accuracy_stationary_2', 'high_accuracy_stationary_1', 'medium_accuracy_stationary_1', 'high_accuracy_stationary_0', 'medium_accuracy_stationary_2', 'medium_accuracy_stationary_0'}
# Found 6 ranges of duration [21727.233207702637, 23413.691692829132, 23528.784961938858, 23740.6810131073, 26967.096922159195, 28713.391573905945] for phone ucb-sdb-ios-3
# ---------- ucb-sdb-ios-4
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563678039.163, 1563678039.2650728)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_0', 1563699736.025, 1563699736.081699)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563699736.026, 1563699736.09885)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_1', 1563723147.778, 1563723148.195827)
# ('START_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563764579.569, 1563764579.704987)
# ('STOP_CALIBRATION_PERIOD', 'high_accuracy_stationary_2', 1563788072.553, 1563788072.625461)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563788072.553, 1563788072.643384)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_0', 1563811819.584, 1563811820.0272322)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563863221.315, 1563863221.463701)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_1', 1563890191.622, 1563890192.1354408)
# ('START_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563944788.843, 1563944788.946683)
# ('STOP_CALIBRATION_PERIOD', 'medium_accuracy_stationary_2', 1563973523.655, 1563973524.094161)
# All ranges are complete, nothing to change
# {'high_accuracy_stationary_2', 'high_accuracy_stationary_1', 'medium_accuracy_stationary_1', 'high_accuracy_stationary_0', 'medium_accuracy_stationary_2', 'medium_accuracy_stationary_0'}
# Found 6 ranges of duration [21696.81662607193, 23412.096976995468, 23492.92047405243, 23747.383848190308, 26970.671739816666, 28735.147478103638] for phone ucb-sdb-ios-4
# -------------------- About to fill evaluation ranges --------------------
# Processing data for android phones
# Processing transitions for phone ucb-sdb-android-1
# Filtered 37 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-2
# Filtered 27 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-3
# Filtered 29 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-android-4
# Filtered 27 total -> 0 calibration transitions
# Processing data for ios phones
# Processing transitions for phone ucb-sdb-ios-1
# Filtered 250 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-ios-2
# Filtered 25 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-ios-3
# Filtered 24 total -> 0 calibration transitions
# Processing transitions for phone ucb-sdb-ios-4
# Filtered 25 total -> 0 calibration transitions
# Processing data for android phones
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-android-1
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-android-2
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-android-3
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-android-4
# Processing data for ios phones
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-ios-1
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-ios-2
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-ios-3
#
# All ranges are complete, nothing to change
# set()
# Found 0 ranges for phone ucb-sdb-ios-4
# Processing data for android phones
# Processing data for ios phones
# -------------------- About to fill evaluation trips --------------------
# Processing data for android phones
# Processing data for ios phones
# Lengths (accuracy, power, eval) = (2, 2, 2)
# keys (accuracy, power, eval) = (dict_keys(['android', 'ios']), dict_keys(['android', 'ios']), dict_keys(['android', 'ios']))
# eval_phone_keys (android, ios) = (dict_keys(['ucb-sdb-android-2', 'ucb-sdb-android-3']), dict_keys(['ucb-sdb-ios-2', 'ucb-sdb-ios-3']))
# dict_keys(['ucb-sdb-android-1', 'ucb-sdb-android-2', 'ucb-sdb-android-3', 'ucb-sdb-android-4'])
# Found accuracy control, skipping copy
# dict_keys(['ucb-sdb-ios-1', 'ucb-sdb-ios-2', 'ucb-sdb-ios-3', 'ucb-sdb-ios-4'])
# Found accuracy control, skipping copy
# -------------------- About to fill in battery information --------------------
# Processing data for android phones
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1563678069.847, 'end_time': 1563699745.856}
# response = <Response [200]>
# Found 9 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1563699745.922, 'end_time': 1563723198.019}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1563764613.222, 'end_time': 1563788085.749}
# response = <Response [200]>
# Found 10 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1563788085.765, 'end_time': 1563811841.83}
# response = <Response [200]>
# Found 14 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1563863231.367, 'end_time': 1563890199.48}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/battery'], 'start_time': 1563944815.921, 'end_time': 1563973553.057}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1563678102.453, 'end_time': 1563699755.407}
# response = <Response [200]>
# Found 15 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1563699755.418, 'end_time': 1563723238.421}
# response = <Response [200]>
# Found 10 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1563764643.841, 'end_time': 1563788093.89}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1563788093.912, 'end_time': 1563811870.005}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1563863242.745, 'end_time': 1563890205.16}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/battery'], 'start_time': 1563944837.097, 'end_time': 1563973569.17}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1563678138.481, 'end_time': 1563699770.145}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1563699770.158, 'end_time': 1563723262.853}
# response = <Response [200]>
# Found 10 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1563764686.301, 'end_time': 1563788105.544}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1563788105.567, 'end_time': 1563811900.716}
# response = <Response [200]>
# Found 9 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1563863272.656, 'end_time': 1563890214.77}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/battery'], 'start_time': 1563944862.98, 'end_time': 1563973599.147}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1563678172.409, 'end_time': 1563699770.145}
# response = <Response [200]>
# Found 8 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1563699770.158, 'end_time': 1563723280.659}
# response = <Response [200]>
# Found 12 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1563764729.726, 'end_time': 1563788112.969}
# response = <Response [200]>
# Found 13 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1563788112.982, 'end_time': 1563811918.395}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1563863286.928, 'end_time': 1563890220.992}
# response = <Response [200]>
# Found 11 entries
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/battery'], 'start_time': 1563944882.313, 'end_time': 1563973623.433}
# response = <Response [200]>
# Found 11 entries
# Processing data for ios phones
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1563677924.975976, 'end_time': 1563699690.424344}
# response = <Response [200]>
# Found 24 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1563699690.439348, 'end_time': 1563723121.389519}
# response = <Response [200]>
# Found 22 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1563764432.001042, 'end_time': 1563788038.733817}
# response = <Response [200]>
# Found 17 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1563788038.751368, 'end_time': 1563811760.9548712}
# response = <Response [200]>
# Found 24 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1563863188.598661, 'end_time': 1563890158.048438}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/battery'], 'start_time': 1563944726.909893, 'end_time': 1563973423.3017302}
# response = <Response [200]>
# Found 23 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1563677969.681895, 'end_time': 1563699714.155782}
# response = <Response [200]>
# Found 24 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1563699714.171499, 'end_time': 1563723134.096898}
# response = <Response [200]>
# Found 22 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1563764493.97196, 'end_time': 1563788050.872571}
# response = <Response [200]>
# Found 17 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1563788050.884784, 'end_time': 1563811785.615035}
# response = <Response [200]>
# Found 24 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1563863200.2893429, 'end_time': 1563890167.611793}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['background/battery'], 'start_time': 1563944748.4612122, 'end_time': 1563973443.5124102}
# response = <Response [200]>
# Found 23 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1563678001.0133371, 'end_time': 1563699728.2465448}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1563699728.266931, 'end_time': 1563723141.958624}
# response = <Response [200]>
# Found 22 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1563764533.214622, 'end_time': 1563788061.999584}
# response = <Response [200]>
# Found 17 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1563788062.0158339, 'end_time': 1563811802.696847}
# response = <Response [200]>
# Found 24 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1563863211.0520248, 'end_time': 1563890178.148947}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['background/battery'], 'start_time': 1563944770.673845, 'end_time': 1563973484.065419}
# response = <Response [200]>
# Found 23 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1563678039.2650728, 'end_time': 1563699736.081699}
# response = <Response [200]>
# Found 19 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1563699736.09885, 'end_time': 1563723148.195827}
# response = <Response [200]>
# Found 22 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1563764579.704987, 'end_time': 1563788072.625461}
# response = <Response [200]>
# Found 17 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1563788072.643384, 'end_time': 1563811820.0272322}
# response = <Response [200]>
# Found 24 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1563863221.463701, 'end_time': 1563890192.1354408}
# response = <Response [200]>
# Found 21 entries
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/battery'], 'start_time': 1563944788.946683, 'end_time': 1563973524.094161}
# response = <Response [200]>
# Found 23 entries
# Processing data for android phones
# Processing data for ios phones
# -------------------- About to fill in location information --------------------
# Processing data for android phones
# About to retrieve data for ucb-sdb-android-1 from 1563678069.847 -> 1563699745.856
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563678069.847, 'end_time': 1563699745.856}
# response = <Response [200]>
# Found 176 entries
# Retrieved 176 entries with timestamps [1563678070.162, 1563678102.064, 1563678133, 1563678164, 1563678193, 1563678198.833, 1563678223, 1563678253, 1563678284, 1563678314]...
# About to retrieve data for ucb-sdb-android-1 from 1563699740.952 -> 1563699745.856
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563699740.952, 'end_time': 1563699745.856}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563699740.952]...
# About to retrieve data for ucb-sdb-android-1 from 1563699745.922 -> 1563723198.019
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563699745.922, 'end_time': 1563723198.019}
# response = <Response [200]>
# Found 184 entries
# Retrieved 184 entries with timestamps [1563699747.152, 1563699775.953, 1563699781, 1563699807.745, 1563699837.783, 1563699867.794, 1563699898.527, 1563699931, 1563699961, 1563699991]...
# About to retrieve data for ucb-sdb-android-1 from 1563723194.14 -> 1563723198.019
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563723194.14, 'end_time': 1563723198.019}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563723194.14]...
# About to retrieve data for ucb-sdb-android-1 from 1563764613.222 -> 1563788085.749
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563764613.222, 'end_time': 1563788085.749}
# response = <Response [200]>
# Found 168 entries
# Retrieved 168 entries with timestamps [1563764613.606, 1563764644.291, 1563764674.987, 1563764705.957, 1563764736.179, 1563764766, 1563764796, 1563764825.861, 1563764855.919, 1563764886]...
# About to retrieve data for ucb-sdb-android-1 from 1563788084 -> 1563788085.749
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563788084, 'end_time': 1563788085.749}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563788084]...
# About to retrieve data for ucb-sdb-android-1 from 1563788085.765 -> 1563811841.83
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563788085.765, 'end_time': 1563811841.83}
# response = <Response [200]>
# Found 30 entries
# Retrieved 30 entries with timestamps [1563788086.766, 1563788110.888, 1563788206.822, 1563788408.915, 1563788467.836, 1563788712.762, 1563789014.743, 1563789079.8, 1563789315.767, 1563789616.794]...
# About to retrieve data for ucb-sdb-android-1 from 1563811838.053 -> 1563811841.83
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563811838.053, 'end_time': 1563811841.83}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563811838.053]...
# About to retrieve data for ucb-sdb-android-1 from 1563863231.367 -> 1563890199.48
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563863231.367, 'end_time': 1563890199.48}
# response = <Response [200]>
# Found 47 entries
# Retrieved 47 entries with timestamps [1563863232.6, 1563863346.246, 1563863401.187, 1563863537.206, 1563863648.247, 1563863949.236, 1563864068.216, 1563864250.291, 1563864518.245, 1563864551.187]...
# About to retrieve data for ucb-sdb-android-1 from 1563890196.885 -> 1563890199.48
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563890196.885, 'end_time': 1563890199.48}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563890196.885]...
# About to retrieve data for ucb-sdb-android-1 from 1563944815.921 -> 1563973553.057
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563944815.921, 'end_time': 1563973553.057}
# response = <Response [200]>
# Found 33 entries
# Retrieved 33 entries with timestamps [1563944816.22, 1563944861.652, 1563944934.133, 1563945032.645, 1563945117.603, 1563945418.65, 1563945718.715, 1563945775.632, 1563946018.824, 1563946320.353]...
# About to retrieve data for ucb-sdb-android-1 from 1563973528.77 -> 1563973553.057
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['background/location'], 'start_time': 1563973528.77, 'end_time': 1563973553.057}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563973528.77]...
# About to retrieve data for ucb-sdb-android-2 from 1563678102.453 -> 1563699755.407
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563678102.453, 'end_time': 1563699755.407}
# response = <Response [200]>
# Found 168 entries
# Retrieved 168 entries with timestamps [1563678102.65, 1563678133.408, 1563678164.155, 1563678196, 1563678227, 1563678257, 1563678287, 1563678317, 1563678347, 1563678377]...
# About to retrieve data for ucb-sdb-android-2 from 1563699751.537 -> 1563699755.407
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563699751.537, 'end_time': 1563699755.407}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563699751.537]...
# About to retrieve data for ucb-sdb-android-2 from 1563699755.418 -> 1563723238.421
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563699755.418, 'end_time': 1563723238.421}
# response = <Response [200]>
# Found 177 entries
# Retrieved 177 entries with timestamps [1563699756.78, 1563699785.509, 1563699792, 1563699815.55, 1563699847.002, 1563699877.475, 1563699908.35, 1563699941, 1563699971, 1563700001]...
# About to retrieve data for ucb-sdb-android-2 from 1563723235.893 -> 1563723238.421
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563723235.893, 'end_time': 1563723238.421}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563723235.893]...
# About to retrieve data for ucb-sdb-android-2 from 1563764643.841 -> 1563788093.89
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563764643.841, 'end_time': 1563788093.89}
# response = <Response [200]>
# Found 169 entries
# Retrieved 169 entries with timestamps [1563764645.1, 1563764679, 1563764710, 1563764739, 1563764766.674, 1563764797.422, 1563764827.862, 1563764859, 1563764889, 1563764919]...
# About to retrieve data for ucb-sdb-android-2 from 1563788090.985 -> 1563788093.89
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563788090.985, 'end_time': 1563788093.89}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563788090.985]...
# About to retrieve data for ucb-sdb-android-2 from 1563788093.912 -> 1563811870.005
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563788093.912, 'end_time': 1563811870.005}
# response = <Response [200]>
# Found 30 entries
# Retrieved 30 entries with timestamps [1563788095.204, 1563788122.477, 1563788195.43, 1563788423.451, 1563788725.43, 1563789025.746, 1563789327.396, 1563789628.459, 1563789751.409, 1563789877.433]...
# About to retrieve data for ucb-sdb-android-2 from 1563811866.707 -> 1563811870.005
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563811866.707, 'end_time': 1563811870.005}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563811866.707]...
# About to retrieve data for ucb-sdb-android-2 from 1563863242.745 -> 1563890205.16
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563863242.745, 'end_time': 1563890205.16}
# response = <Response [200]>
# Found 64 entries
# Retrieved 64 entries with timestamps [1563863243.22, 1563863309.956, 1563863401.912, 1563863545.365, 1563863846, 1563864126.918, 1563864147, 1563864446, 1563864651.912, 1563864746]...
# About to retrieve data for ucb-sdb-android-2 from 1563890192.029 -> 1563890205.16
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563890192.029, 'end_time': 1563890205.16}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563890192.029]...
# About to retrieve data for ucb-sdb-android-2 from 1563944837.097 -> 1563973569.17
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563944837.097, 'end_time': 1563973569.17}
# response = <Response [200]>
# Found 38 entries
# Retrieved 38 entries with timestamps [1563944837.348, 1563945073.492, 1563945139.147, 1563945441.294, 1563945524.375, 1563945741.369, 1563946042.384, 1563946245.313, 1563946343.303, 1563946644.32]...
# About to retrieve data for ucb-sdb-android-2 from 1563973566.991 -> 1563973569.17
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['background/location'], 'start_time': 1563973566.991, 'end_time': 1563973569.17}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563973566.991]...
# About to retrieve data for ucb-sdb-android-3 from 1563678138.481 -> 1563699770.145
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1563678138.481, 'end_time': 1563699770.145}
# response = <Response [200]>
# Found 2 entries
# Retrieved 2 entries with timestamps [1563682569.815, 1563685733.276]...
# About to retrieve data for ucb-sdb-android-3 from 1563685733.276 -> 1563699770.145
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1563685733.276, 'end_time': 1563699770.145}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563685733.276]...
# About to retrieve data for ucb-sdb-android-3 from 1563699770.158 -> 1563723262.853
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1563699770.158, 'end_time': 1563723262.853}
# response = <Response [200]>
# Found 178 entries
# Retrieved 178 entries with timestamps [1563699771.539, 1563699771.703, 1563699782, 1563699803.328, 1563699833.73, 1563699864.099, 1563699895, 1563699926, 1563699955, 1563699985]...
# About to retrieve data for ucb-sdb-android-3 from 1563723260.504 -> 1563723262.853
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1563723260.504, 'end_time': 1563723262.853}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563723260.504]...
# About to retrieve data for ucb-sdb-android-3 from 1563764686.301 -> 1563788105.544
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1563764686.301, 'end_time': 1563788105.544}
# response = <Response [200]>
# Found 177 entries
# Retrieved 177 entries with timestamps [1563764687.564, 1563764718.355, 1563764748.423, 1563764778.472, 1563764809.178, 1563764841, 1563764871, 1563764901, 1563764931, 1563764961]...
# About to retrieve data for ucb-sdb-android-3 from 1563788101.669 -> 1563788105.544
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1563788101.669, 'end_time': 1563788105.544}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563788101.669]...
# About to retrieve data for ucb-sdb-android-3 from 1563788105.567 -> 1563811900.716
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1563788105.567, 'end_time': 1563811900.716}
# response = <Response [200]>
# Found 43 entries
# Retrieved 43 entries with timestamps [1563788106.992, 1563788136.896, 1563788289.681, 1563788331.77, 1563788438.028, 1563788562.839, 1563788642.903, 1563788738.869, 1563788793.881, 1563789025.861]...
# About to retrieve data for ucb-sdb-android-3 from 1563811898.388 -> 1563811900.716
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1563811898.388, 'end_time': 1563811900.716}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563811898.388]...
# About to retrieve data for ucb-sdb-android-3 from 1563863272.656 -> 1563890214.77
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1563863272.656, 'end_time': 1563890214.77}
# response = <Response [200]>
# Found 46 entries
# Retrieved 46 entries with timestamps [1563863273.008, 1563863312.361, 1563863401.309, 1563863536.846, 1563863613.301, 1563863826.334, 1563863914.465, 1563864215.292, 1563864515.359, 1563864650.317]...
# About to retrieve data for ucb-sdb-android-3 from 1563890212.939 -> 1563890214.77
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1563890212.939, 'end_time': 1563890214.77}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563890212.939]...
# About to retrieve data for ucb-sdb-android-3 from 1563944862.98 -> 1563973599.147
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1563944862.98, 'end_time': 1563973599.147}
# response = <Response [200]>
# Found 43 entries
# Retrieved 43 entries with timestamps [1563944863.16, 1563945118.244, 1563945166, 1563945236.617, 1563945276.576, 1563945466, 1563945766, 1563946052.145, 1563946065, 1563946366]...
# About to retrieve data for ucb-sdb-android-3 from 1563973595.632 -> 1563973599.147
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['background/location'], 'start_time': 1563973595.632, 'end_time': 1563973599.147}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563973595.632]...
# About to retrieve data for ucb-sdb-android-4 from 1563678172.409 -> 1563699770.145
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1563678172.409, 'end_time': 1563699770.145}
# response = <Response [200]>
# Found 184 entries
# Retrieved 184 entries with timestamps [1563678172.616, 1563678203.446, 1563678233.544, 1563678263.549, 1563678294.234, 1563678327, 1563678357, 1563678387, 1563678416, 1563678446]...
# About to retrieve data for ucb-sdb-android-4 from 1563692388 -> 1563699770.145
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1563692388, 'end_time': 1563699770.145}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563692388]...
# About to retrieve data for ucb-sdb-android-4 from 1563699770.158 -> 1563723280.659
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1563699770.158, 'end_time': 1563723280.659}
# response = <Response [200]>
# Found 177 entries
# Retrieved 177 entries with timestamps [1563699778.517, 1563699783.003, 1563699813.726, 1563699843.844, 1563699874.665, 1563699906, 1563699935, 1563699965.399, 1563699996, 1563700026]...
# About to retrieve data for ucb-sdb-android-4 from 1563723278.612 -> 1563723280.659
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1563723278.612, 'end_time': 1563723280.659}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563723278.612]...
# About to retrieve data for ucb-sdb-android-4 from 1563764729.726 -> 1563788112.969
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1563764729.726, 'end_time': 1563788112.969}
# response = <Response [200]>
# Found 186 entries
# Retrieved 186 entries with timestamps [1563764730.978, 1563764761.839, 1563764791.872, 1563764823.176, 1563764855, 1563764885, 1563764916, 1563764946, 1563764976, 1563764981.108]...
# About to retrieve data for ucb-sdb-android-4 from 1563788109.602 -> 1563788112.969
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1563788109.602, 'end_time': 1563788112.969}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563788109.602]...
# About to retrieve data for ucb-sdb-android-4 from 1563788112.982 -> 1563811918.395
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1563788112.982, 'end_time': 1563811918.395}
# response = <Response [200]>
# Found 29 entries
# Retrieved 29 entries with timestamps [1563788114.181, 1563788143.927, 1563788395.582, 1563788445.944, 1563788644.929, 1563788748, 1563789049.943, 1563789350.923, 1563789600.956, 1563789651.965]...
# About to retrieve data for ucb-sdb-android-4 from 1563811916.122 -> 1563811918.395
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1563811916.122, 'end_time': 1563811918.395}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563811916.122]...
# About to retrieve data for ucb-sdb-android-4 from 1563863286.928 -> 1563890220.992
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1563863286.928, 'end_time': 1563890220.992}
# response = <Response [200]>
# Found 44 entries
# Retrieved 44 entries with timestamps [1563863287.122, 1563863292.935, 1563863401.382, 1563863535.398, 1563863594.388, 1563863895.449, 1563864086.35, 1563864197.366, 1563864498.394, 1563864637.361]...
# About to retrieve data for ucb-sdb-android-4 from 1563890218.773 -> 1563890220.992
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1563890218.773, 'end_time': 1563890220.992}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563890218.773]...
# About to retrieve data for ucb-sdb-android-4 from 1563944882.313 -> 1563973623.433
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1563944882.313, 'end_time': 1563973623.433}
# response = <Response [200]>
# Found 35 entries
# Retrieved 35 entries with timestamps [1563944884, 1563944987.097, 1563945187, 1563945217.618, 1563945487, 1563945787, 1563945828.079, 1563946087, 1563946176.15, 1563946314.089]...
# About to retrieve data for ucb-sdb-android-4 from 1563973620.581 -> 1563973623.433
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['background/location'], 'start_time': 1563973620.581, 'end_time': 1563973623.433}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563973620.581]...
# Processing data for ios phones
# About to retrieve data for ucb-sdb-ios-1 from 1563677924.975976 -> 1563699690.424344
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['background/location'], 'start_time': 1563677924.975976, 'end_time': 1563699690.424344}
# response = <Response [200]>
# Found 5 entries
# Retrieved 5 entries with timestamps [1563652670.362842, 1563677925.4896479, 1563677927.959566, 1563695713.9969468, 1563695789.9991722]...
# About to retrieve data for ucb-sdb-ios-1 from 1563695789.9991722 -> 1563699690.424344
# ...
# Found 12 entries
# Retrieved 12 entries with timestamps [1563788081.6224961, 1563789603.789357, 1563793204.233365, 1563797003.508827, 1563800415.9129891, 1563804015.150463, 1563807801.4100618, 1563811203.7005138, 1563811797.7827616, 1563811801.6248157]...
# About to retrieve data for ucb-sdb-ios-4 from 1563811819.8356628 -> 1563811820.0272322
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/motion_activity'], 'start_time': 1563811819.8356628, 'end_time': 1563811820.0272322}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563811819.8356628]...
# About to retrieve data for ucb-sdb-ios-4 from 1563863221.463701 -> 1563890192.1354408
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/motion_activity'], 'start_time': 1563863221.463701, 'end_time': 1563890192.1354408}
# response = <Response [200]>
# Found 20 entries
# Retrieved 20 entries with timestamps [1563863228.3080573, 1563863250.072441, 1563863254.5538874, 1563865203.155762, 1563868803.624126, 1563872402.9744449, 1563876003.5641232, 1563879604.330411, 1563883203.580286, 1563886803.0217528]...
# About to retrieve data for ucb-sdb-ios-4 from 1563890191.899808 -> 1563890192.1354408
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/motion_activity'], 'start_time': 1563890191.899808, 'end_time': 1563890192.1354408}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563890191.899808]...
# About to retrieve data for ucb-sdb-ios-4 from 1563944788.946683 -> 1563973524.094161
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/motion_activity'], 'start_time': 1563944788.946683, 'end_time': 1563973524.094161}
# response = <Response [200]>
# Found 13 entries
# Retrieved 13 entries with timestamps [1563944797.6587574, 1563948015.4280171, 1563951609.503269, 1563955203.6004128, 1563958802.974998, 1563962403.6370301, 1563966004.213104, 1563969603.6269422, 1563973215.8156729, 1563973499.9782963]...
# About to retrieve data for ucb-sdb-ios-4 from 1563973523.97451 -> 1563973524.094161
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['background/motion_activity'], 'start_time': 1563973523.97451, 'end_time': 1563973524.094161}
# response = <Response [200]>
# Found 1 entries
# Retrieved 1 entries with timestamps [1563973523.97451]...
# Processing data for android phones
# Processing data for ios phones
# -------------------- About to fill in transition information --------------------
# Processing data for android phones
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['statemachine/transition'], 'start_time': 1563678069.847, 'end_time': 1563699745.856}
# response = <Response [200]>
# Found 2 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['statemachine/transition'], 'start_time': 1563699745.922, 'end_time': 1563723198.019}
# response = <Response [200]>
# Found 4 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['statemachine/transition'], 'start_time': 1563764613.222, 'end_time': 1563788085.749}
# response = <Response [200]>
# Found 2 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['statemachine/transition'], 'start_time': 1563788085.765, 'end_time': 1563811841.83}
# response = <Response [200]>
# Found 4 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['statemachine/transition'], 'start_time': 1563863231.367, 'end_time': 1563890199.48}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['statemachine/transition'], 'start_time': 1563944815.921, 'end_time': 1563973553.057}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1563678102.453, 'end_time': 1563699755.407}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1563699755.418, 'end_time': 1563723238.421}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1563764643.841, 'end_time': 1563788093.89}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1563788093.912, 'end_time': 1563811870.005}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1563863242.745, 'end_time': 1563890205.16}
# response = <Response [200]>
# Found 2 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-2', 'key_list': ['statemachine/transition'], 'start_time': 1563944837.097, 'end_time': 1563973569.17}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1563678138.481, 'end_time': 1563699770.145}
# response = <Response [200]>
# Found 2 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1563699770.158, 'end_time': 1563723262.853}
# response = <Response [200]>
# Found 4 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1563764686.301, 'end_time': 1563788105.544}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1563788105.567, 'end_time': 1563811900.716}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1563863272.656, 'end_time': 1563890214.77}
# response = <Response [200]>
# Found 2 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-3', 'key_list': ['statemachine/transition'], 'start_time': 1563944862.98, 'end_time': 1563973599.147}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1563678172.409, 'end_time': 1563699770.145}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1563699770.158, 'end_time': 1563723280.659}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1563764729.726, 'end_time': 1563788112.969}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1563788112.982, 'end_time': 1563811918.395}
# response = <Response [200]>
# Found 3 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1563863286.928, 'end_time': 1563890220.992}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-android-4', 'key_list': ['statemachine/transition'], 'start_time': 1563944882.313, 'end_time': 1563973623.433}
# response = <Response [200]>
# Found 1 entries
# transition has not been processed, creating ts -> fmt_time
# Processing data for ios phones
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1563677924.975976, 'end_time': 1563699690.424344}
# response = <Response [200]>
# Found 22 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1563699690.439348, 'end_time': 1563723121.389519}
# response = <Response [200]>
# Found 20 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1563764432.001042, 'end_time': 1563788038.733817}
# response = <Response [200]>
# Found 15 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1563788038.751368, 'end_time': 1563811760.9548712}
# response = <Response [200]>
# Found 22 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1563863188.598661, 'end_time': 1563890158.048438}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-1', 'key_list': ['statemachine/transition'], 'start_time': 1563944726.909893, 'end_time': 1563973423.3017302}
# response = <Response [200]>
# Found 21 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1563677969.681895, 'end_time': 1563699714.155782}
# response = <Response [200]>
# Found 22 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1563699714.171499, 'end_time': 1563723134.096898}
# response = <Response [200]>
# Found 20 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1563764493.97196, 'end_time': 1563788050.872571}
# response = <Response [200]>
# Found 15 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1563788050.884784, 'end_time': 1563811785.615035}
# response = <Response [200]>
# Found 22 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1563863200.2893429, 'end_time': 1563890167.611793}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-2', 'key_list': ['statemachine/transition'], 'start_time': 1563944748.4612122, 'end_time': 1563973443.5124102}
# response = <Response [200]>
# Found 21 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1563678001.0133371, 'end_time': 1563699728.2465448}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1563699728.266931, 'end_time': 1563723141.958624}
# response = <Response [200]>
# Found 20 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1563764533.214622, 'end_time': 1563788061.999584}
# response = <Response [200]>
# Found 15 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1563788062.0158339, 'end_time': 1563811802.696847}
# response = <Response [200]>
# Found 22 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1563863211.0520248, 'end_time': 1563890178.148947}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-3', 'key_list': ['statemachine/transition'], 'start_time': 1563944770.673845, 'end_time': 1563973484.065419}
# response = <Response [200]>
# Found 21 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1563678039.2650728, 'end_time': 1563699736.081699}
# response = <Response [200]>
# Found 17 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1563699736.09885, 'end_time': 1563723148.195827}
# response = <Response [200]>
# Found 20 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1563764579.704987, 'end_time': 1563788072.625461}
# response = <Response [200]>
# Found 15 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1563788072.643384, 'end_time': 1563811820.0272322}
# response = <Response [200]>
# Found 22 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1563863221.463701, 'end_time': 1563890192.1354408}
# response = <Response [200]>
# Found 19 entries
# transition has not been processed, creating ts -> fmt_time
# About to retrieve messages using {'user': 'ucb-sdb-ios-4', 'key_list': ['statemachine/transition'], 'start_time': 1563944788.946683, 'end_time': 1563973524.094161}
# response = <Response [200]>
# Found 21 entries
# transition has not been processed, creating ts -> fmt_time
# Processing data for android phones
# Processing data for ios phones
# -------------------- About to select trip specific ranges --------------------
# Filling label ucb-sdb-android-1 for OS android
# Filling label ucb-sdb-android-2 for OS android
# Filling label ucb-sdb-android-3 for OS android
# Filling label ucb-sdb-android-4 for OS android
# Filling label ucb-sdb-ios-1 for OS ios
# Filling label ucb-sdb-ios-2 for OS ios
# Filling label ucb-sdb-ios-3 for OS ios
# Filling label ucb-sdb-ios-4 for OS ios
# -------------------- Done populating information from server --------------------

# %% [markdown]
# ### Issue #1: Multiple and missing transitions
#
# While exploring the data after the collection was done, there were still inconsistencies in the transitions pushed to the server - there were a bunch of duplicate transitions, and two of the phones were missing start transitions for the second trip.

# %%
# Commented out because this fails
# pvt3.validate()

# %%
pvmco1.validate()
# Out:
# -------------------- About to validate calibration settings --------------------
# Processing data for android phones
# About to retrieve messages using {'user': 'ucb-sdb-android-1', 'key_list': ['config/sensor_config'], 'start_time': 1563678069.847, 'end_time': 1563699745.856}
# response = <Response [200]>
# Found 1 entries
# high_accuracy_stationary_0_0 -> [100]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-a980db743a85> in <module>()
# ----> 1 pvmco1.validate()
#
# /Users/shankari/e-mission/e-mission-eval-public-data/emeval/input/phone_view.py in validate(self)
#      68     def validate(self):
#      69         print(20 * "-", "About to validate calibration settings", 20 * "-")
# ---> 70         evpv.validate_calibration_settings(self)
#      71         print(20 * "-", "About to validate evaluation settings", 20 * "-")
#      72         evpv.validate_evaluation_settings(self)
#
# /Users/shankari/e-mission/e-mission-eval-public-data/emeval/validate/phone_view.py in validate_calibration_settings(phone_view)
#     109                 # assert len(config_during_test_entries) == 1, "Out of band configuration? Found %d config changes" % len(config_during_test_entries)
#     110                 config_during_test = config_during_test_entries[0]["data"]
# --> 111                 expected_config = expected_config_map[r["trip_id"]]
#     112                 # print(config_during_test, expected_config)
#     113                 _validate_filter(phoneOS, config_during_test, expected_config)
#
# KeyError: 'high_accuracy_stationary_0_0'

# %%
evmco1 = eiev.EvaluationView()
evmco1.from_view_multiple_runs(pvmco1, "")

# %% [markdown]
# ## Now for the results (calibration, phone view)!

# %% [markdown]
# ### Battery drain over time (moving calibration)
#
# Again, the moving calibration runs were not very useful in terms of battery drain, since there were too few points to be useful. We actually have more points on android, but we have almost nothing for the iOS medium accuracy runs.
#
# Part of this is inherent in the definition of moving calibration, since it is unlikely that we will move for 10-15 hours at a time to collect the kind of data we have in the stationary case. And if our trip lasts for an hour, but we only read the battery level once an hour, we will end up with close to no data.
#
# But with some native code changes, I think we can do better wrt at least recording the battery reading at the trip start and end.

# %%
(ifig, [android_ax, ios_ax]) = plt.subplots(ncols=1, nrows=2, figsize=(12,12))

ezpv.plot_all_power_drain(ios_ax, pvmco1.map()["ios"], "calibration", "high")
ios_ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))
ezpv.plot_all_power_drain(android_ax, pvmco1.map()["android"], "calibration", "high")
android_ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
(ifig, [android_ax, ios_ax]) = plt.subplots(ncols=1, nrows=2, figsize=(12,12))

ezpv.plot_all_power_drain(ios_ax, pvmco1.map()["ios"], "calibration", "medium")
ios_ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))
ezpv.plot_all_power_drain(android_ax, pvmco1.map()["android"], "calibration", "medium")
android_ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
(ifig, axes) = plt.subplots(ncols=0, nrows=0, figsize=(12,3))

ezpv.plot_separate_power_drain(ifig, pvmco1.map()["ios"], 4, "calibration", "stationary")
# android_ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))
(ifig, axes) = plt.subplots(ncols=0, nrows=0, figsize=(12,3))

ezpv.plot_separate_power_drain(ifig, pvmco1.map()["android"], 4, "calibration", "stationary")
# android_ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
(ifig, axes) = plt.subplots(ncols=0, nrows=0, figsize=(16,4))

ezev.plot_separate_power_drain_multiple_runs(ifig, 2, evmco1.map("calibration")["ios"], "")
android_ax.legend(loc="upper center", bbox_to_anchor=(1, 0.5))
(ifig, axes) = plt.subplots(ncols=0, nrows=0, figsize=(16,4))

ezev.plot_separate_power_drain_multiple_runs(ifig, 2, evmco1.map("calibration")["android"], "")
android_ax.legend(loc="upper center", bbox_to_anchor=(1, 0.5))

# %%
importlib.reload(ezev)

# %%
def display_transitions_ranges_values(ax, phone_map, range_key, trip_id_pattern, offset_hr=1):
    for phone_label, phone_details in phone_map.items():
        curr_calibration_ranges = phone_details["{}_ranges".format(range_key)]
        sel_calibration_ranges = [cr for cr in curr_calibration_ranges if trip_id_pattern in cr["trip_id"]]
        for r in sel_calibration_ranges:
            battery_df = r["battery_df"]
            start_level = battery_df.battery_level_pct.iloc[0]
            battery_df["battery_change_from_start"] = battery_df.battery_level_pct - start_level
            battery_df["hr_new"] = battery_df.hr + offset_hr
            ret_axes = battery_df.plot(x="hr_new", y="battery_change_from_start", ax=ax, label=phone_label+"_"+r["trip_id"], ylim=(0, -100), sharey=True)

# %%
(ifig, [android_ax, ios_ax]) = plt.subplots(ncols=1, nrows=2, figsize=(6,12))

display_transitions_ranges_values(ios_ax, pvmco1.map()["ios"], "calibration", "high_accuracy_stationary_0", 0)
display_transitions_ranges_values(ios_ax, pvmco1.map()["ios"], "calibration", "high_accuracy_stationary_1", 1)
display_transitions_ranges_values(ios_ax, pvmco1.map()["ios"], "calibration", "high_accuracy_stationary_2", 0)
display_transitions_ranges_values(ios_ax, pvmco1.map()["ios"], "calibration", "medium_accuracy_stationary_0", 1)
display_transitions_ranges_values(ios_ax, pvmco1.map()["ios"], "calibration", "medium_accuracy_stationary_1", 0)
display_transitions_ranges_values(ios_ax, pvmco1.map()["ios"], "calibration", "medium_accuracy_stationary_2", 0)
ios_ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))
display_transitions_ranges_values(android_ax, pvmco1.map()["android"], "calibration", "stationary", 0)
android_ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))
